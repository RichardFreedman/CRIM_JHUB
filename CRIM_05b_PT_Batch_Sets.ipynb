# %% [markdown]
# ## Presentation Types with Hidden Types
# ## Batch Output to CSV in Sets

# %%
import intervals
from intervals import * 
from intervals import main_objs
import intervals.visualizations as viz
import pandas as pd
import re
import altair as alt 
from ipywidgets import interact
from pandas.io.json import json_normalize
from pyvis.network import Network
from IPython.display import display
import requests
import os
import numpy as np
import itertools
from itertools import combinations
import networkx as nx
from community import community_louvain
from copy import deepcopy
MYDIR = ("saved_csv")
CHECK_FOLDER = os.path.isdir(MYDIR)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MYDIR)
    print("created folder : ", MYDIR)

else:
    print(MYDIR, "folder already exists.")
# Out:
# saved_csv folder already exists.

# %% [markdown]
# #### The following are special functions used by the classifier.  Don't change them.

# %% [markdown]
# ## Load one Piece Here
#
# * Note that you can load from CRIM, or put a file in the **Music_Files** folder in the Notebook.

# %%
git_prefix = 'https://raw.githubusercontent.com/CRIM-Project/CRIM-online/master/crim/static/mei/MEI_4.0/'

# just add the CRIM Piece ID here
mei_file = 'CRIM_Model_0001.mei'


url = git_prefix + mei_file
# piece = importScore('Music_Files/Senfl_Ave_forCRIM.mei_msg.mei')
piece = importScore(url)
# piece = importScore('Music_Files/CRIM_Mass_0007_4.mei')

print(piece.metadata)
# Out:
# Downloading remote score...
# Successfully imported https://raw.githubusercontent.com/CRIM-Project/CRIM-online/master/crim/static/mei/MEI_4.0/CRIM_Model_0001.mei
# {'title': 'Veni speciosam', 'composer': 'Lupi, Johannes'}

# %% [markdown]
# ## Run the Classifier Here
#
# - set the length of the soggetti with `melodic_ngram_length`
# - set the maximum difference between similar soggetti with `edit_distance_threshold`
# - for chromatic vs diatonic, compound, and directed data in soggetti, see `interval_settings`
# - to include all the hidden PENs and IDS (those found within longer Fugas, use `include_hidden_types == True`.
# - for faster (and simpler) listing of points of imitation without hidden forms, use `include_hidden_types == False`

# %% [markdown]
# ### Run Classifier on Several Pieces at Once
#
# Results are combined into a single dataframe

# %%
git_prefix = 'https://raw.githubusercontent.com/CRIM-Project/CRIM-online/master/crim/static/mei/MEI_4.0/'

# piece = importScore('Music_Files/CRIM_Mass_0007_4.mei')
piece_list =  ['CRIM_Mass_0005_3.mei',
             'CRIM_Mass_0005_4.mei',
             'CRIM_Mass_0005_5.mei',
             'CRIM_Model_0001.mei',
             'CRIM_Mass_0002_1.mei',
             'CRIM_Mass_0002_2.mei',
             'CRIM_Mass_0002_3.mei',
             'CRIM_Mass_0002_4.mei',
             'CRIM_Mass_0002_5.mei',
             'CRIM_Model_0015.mei',
             'CRIM_Mass_0013_1.mei',
             'CRIM_Mass_0013_2.mei',
             'CRIM_Mass_0013_3.mei',
             'CRIM_Mass_0013_4.mei',
             'CRIM_Mass_0013_5.mei',
             'CRIM_Model_0019.mei',
             'CRIM_Mass_0019_1.mei',
             'CRIM_Mass_0019_2.mei',
             'CRIM_Mass_0019_3.mei',
             'CRIM_Mass_0019_4.mei',
             'CRIM_Mass_0019_5.mei']

# %%
git_prefix = 'https://raw.githubusercontent.com/CRIM-Project/CRIM-online/master/crim/static/mei/MEI_4.0/'

piece_list = ['CRIM_Model_0019.mei',
             'CRIM_Mass_0019_1.mei',
             'CRIM_Mass_0019_2.mei',
             'CRIM_Mass_0019_3.mei',
             'CRIM_Mass_0019_4.mei',
             'CRIM_Mass_0019_5.mei']

# %%
mass_sets = [('CRIM_Mass_0019',
('CRIM_Model_0019.mei',
 'CRIM_Mass_0019_1.mei',
 'CRIM_Mass_0019_2.mei',
 'CRIM_Mass_0019_3.mei',
 'CRIM_Mass_0019_4.mei',
'CRIM_Mass_0019_5.mei'))]

git_prefix = 'https://raw.githubusercontent.com/CRIM-Project/CRIM-online/master/crim/static/mei/MEI_4.0/'

include_hidden_types = False
combine_unisons = True
melodic_ngram_length = 4
edit_distance_threshold = 0

for mass in mass_sets:
    final = pd.DataFrame()
    corpus_set = []
    csv_name = 'saved_csv/' + mass_sets[0][0] + '_' + 'P_Types'
    file_names = mass[1]
    for file in file_names:
        file_url = git_prefix + file 
        url = git_prefix + file


        piece = importScore(url)   
        nr = piece.getNoteRest(combineUnisons=combine_unisons)
        dur = piece.getDuration(df=nr)
        mel = piece.getMelodic(df=nr, kind='d', end=False)
        dur_ng = piece.getNgrams(df=dur, n=melodic_ngram_length)
        mel_ng = piece.getNgrams(df=mel, n=melodic_ngram_length)
        entries = piece.getEntries(mel_ng)

        output = classify_entries_as_presentation_types(piece, nr, dur_ng, entries, edit_distance_threshold, include_hidden_types)


        final = final.append(output, ignore_index=True)

final.to_csv(csv_name)
# Out:
# Memoized piece detected.
# Memoized piece detected.
# Memoized piece detected.
# Memoized piece detected.
# Memoized piece detected.
# Memoized piece detected.

# %%
final
# Out:
#                              Composer                               Title  \
# 0   Palestrina, Giovanni Pierluigi da                 Veni sponsa Christi
# 1   Palestrina, Giovanni Pierluigi da                 Veni sponsa Christi
# 2   Palestrina, Giovanni Pierluigi da                 Veni sponsa Christi
# 3   Palestrina, Giovanni Pierluigi da                 Veni sponsa Christi
# 4    Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Kyrie
# 5    Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Kyrie
# 6    Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Kyrie
# 7    Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Kyrie
# 8    Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Kyrie
# 9    Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Kyrie
# 10   Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Kyrie
# 11   Giovanni Pierluigi da Palestrina   Missa Veni sponsa Christi: Gloria
# 12   Giovanni Pierluigi da Palestrina   Missa Veni sponsa Christi: Gloria
# 13   Giovanni Pierluigi da Palestrina   Missa Veni sponsa Christi: Gloria
# 14   Giovanni Pierluigi da Palestrina   Missa Veni sponsa Christi: Gloria
# 15   Giovanni Pierluigi da Palestrina   Missa Veni sponsa Christi: Gloria
# 16   Giovanni Pierluigi da Palestrina   Missa Veni sponsa Christi: Gloria
# 17   Giovanni Pierluigi da Palestrina   Missa Veni sponsa Christi: Gloria
# 18   Giovanni Pierluigi da Palestrina   Missa Veni sponsa Christi: Gloria
# 19   Giovanni Pierluigi da Palestrina   Missa Veni sponsa Christi: Gloria
# 20   Giovanni Pierluigi da Palestrina   Missa Veni sponsa Christi: Gloria
# 21   Giovanni Pierluigi da Palestrina   Missa Veni sponsa Christi: Gloria
# 22   Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Credo
# 23   Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Credo
# 24   Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Credo
# 25   Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Credo
# 26   Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Credo
# 27   Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Credo
# 28   Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Credo
# 29   Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Credo
# 30   Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Credo
# 31   Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Credo
# 32   Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Credo
# 33   Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Credo
# 34   Giovanni Pierluigi da Palestrina    Missa Veni sponsa Christi: Credo
# 35   Giovanni Pierluigi da Palestrina  Missa Veni sponsa Christi: Sanctus
# 36   Giovanni Pierluigi da Palestrina  Missa Veni sponsa Christi: Sanctus
# 37   Giovanni Pierluigi da Palestrina  Missa Veni sponsa Christi: Sanctus
# 38   Giovanni Pierluigi da Palestrina  Missa Veni sponsa Christi: Sanctus
# 39   Giovanni Pierluigi da Palestrina  Missa Veni sponsa Christi: Sanctus
# 40   Giovanni Pierluigi da Palestrina  Missa Veni sponsa Christi: Sanctus
# 41   Giovanni Pierluigi da Palestrina  Missa Veni sponsa Christi: Sanctus
# 42   Giovanni Pierluigi da Palestrina  Missa Veni sponsa Christi: Sanctus
# 43   Giovanni Pierluigi da Palestrina  Missa Veni sponsa Christi: Sanctus
# 44   Giovanni Pierluigi da Palestrina  Missa Veni sponsa Christi: Sanctus
# 45   Giovanni Pierluigi da Palestrina  Missa Veni sponsa Christi: Sanctus
#
#     First_Offset                                     Measures_Beats  \
# 0            0.0  [1/1.0, 2/1.0, 6/1.0, 7/1.0, 11/3.0, 14/1.0, 1...
# 1          150.0  [19/4.0, 21/4.0, 22/4.0, 25/4.0, 27/4.0, 29/4....
# 2          298.0   [38/2.0, 38/4.0, 42/2.0, 44/1.0, 46/2.0, 48/4.0]
# 3          394.0  [50/2.0, 51/4.0, 53/2.0, 55/2.0, 56/4.0, 59/1....
# 4            0.0                       [1/1.0, 2/1.0, 6/1.0, 7/1.0]
# 5           78.0                   [10/4.0, 12/2.0, 14/2.0, 15/3.0]
# 6          160.0   [20/1.0, 24/1.0, 30/2.0, 33/1.0, 35/3.0, 39/3.0]
# 7          164.0  [20/3.0, 24/3.0, 27/2.0, 27/4.0, 30/4.0, 36/1....
# 8          372.0           [45/3.0, 47/3.0, 49/3.0, 51/4.0, 53/3.0]
# 9          458.0                   [56/2.0, 58/4.0, 61/3.0, 63/2.0]
# 10         510.0                                   [62/4.0, 64/2.0]
# 11           0.0                                     [1/1.0, 4/3.0]
# 12           4.0                                     [1/3.0, 5/1.0]
# 13          50.0                     [7/2.0, 7/4.0, 10/3.0, 12/3.0]
# 14         236.0   [30/3.0, 34/4.0, 35/2.0, 37/4.0, 39/2.0, 40/2.0]
# 15         352.0   [44/1.0, 45/1.0, 46/1.0, 47/1.0, 54/1.0, 55/2.0]
# 16         402.0                                           [50/2.0]
# 17         482.0                                   [60/2.0, 62/2.0]
# 18         522.0                                   [65/2.0, 68/2.0]
# 19         570.0                   [71/2.0, 73/2.0, 74/1.0, 78/3.0]
# 20         678.0                                   [84/4.0, 87/2.0]
# 21         706.0  [88/2.0, 89/2.0, 90/2.0, 91/2.0, 94/2.0, 95/1....
# 22           0.0               [1/1.0, 2/1.0, 6/3.0, 7/1.0, 10/1.0]
# 23          94.0           [12/4.0, 20/2.0, 28/2.0, 29/2.0, 32/2.0]
# 24          98.0                   [13/2.0, 14/2.0, 17/2.0, 18/2.0]
# 25         178.0                   [23/2.0, 23/4.0, 25/4.0, 26/2.0]
# 26         310.0                                   [39/4.0, 40/2.0]
# 27         572.0                                   [71/3.0, 72/3.0]
# 28         598.0                           [74/4.0, 75/2.0, 75/4.0]
# 29         658.0                                   [82/2.0, 82/4.0]
# 30         722.0  [90/2.0, 90/4.0, 92/2.0, 93/2.0, 94/2.0, 94/4....
# 31         848.0                                 [106/1.0, 107/1.0]
# 32         994.0                                 [124/2.0, 125/2.0]
# 33        1074.0                                 [134/2.0, 135/2.0]
# 34        1142.0               [142/4.0, 145/2.0, 147/3.0, 149/2.0]
# 35           0.0                      [1/1.0, 3/1.0, 7/3.0, 12/1.0]
# 36           2.0                [1/2.0, 3/2.0, 5/2.0, 7/4.0, 9/4.0]
# 37          26.0                                     [4/2.0, 8/4.0]
# 38         122.0                   [16/2.0, 18/4.0, 22/4.0, 24/4.0]
# 39         126.0                           [16/4.0, 19/2.0, 20/4.0]
# 40         224.0                           [28/1.0, 29/1.0, 32/3.0]
# 41         302.0  [37/4.0, 38/4.0, 39/4.0, 41/4.0, 45/2.0, 46/2....
# 42         480.0  [59/1.0, 60/1.0, 62/1.0, 63/2.0, 64/1.0, 67/1....
# 43         740.0           [81/1.0, 84/1.0, 88/1.0, 95/1.0, 97/1.0]
# 44         814.0                                   [89/2.0, 93/2.0]
# 45         922.0  [102/2.0, 103/2.0, 104/2.0, 104/2.0, 107/2.0, ...
#
#                               Melodic_Entry_Intervals  \
# 0                        [P-5, P-4, P-5, P8, P5, P-8]
# 1                   [P8, P-5, P-4, P-5, P8, P8, P-11]
# 2                            [P-5, P-5, P8, P8, P-11]
# 3                [P5, P-8, P4, P5, P-8, P8, P-4, P-5]
# 4                                     [P-5, P-4, P-5]
# 5                                     [P-4, P-5, P-4]
# 6                              [P-8, P1, P4, P-8, P5]
# 7                     [P-8, P8, P-8, P5, P4, P5, M-6]
# 8                                 [P8, P-8, P8, P-12]
# 9                                     [P-8, P-5, P12]
# 10                                               [P5]
# 11                                              [P-8]
# 12                                              [P-8]
# 13                                     [P5, P-12, P8]
# 14                            [P-4, P5, P-12, P5, P8]
# 15                            [P8, P-12, P8, P-8, P8]
# 16                                             [M-10]
# 17                                               [P1]
# 18                                               [P8]
# 19                                      [P5, P-8, P4]
# 20                                             [P-11]
# 21                         [P1, P-8, P5, M-9, P5, P8]
# 22                                [P-5, P-4, P-5, P8]
# 23                                  [P1, M-2, P5, P1]
# 24                                     [P-5, P-4, P8]
# 25                                     [P-5, P8, P-5]
# 26                                              [P-4]
# 27                                              [P-5]
# 28                                         [P-4, P-5]
# 29                                               [P4]
# 30                     [P-5, P12, M-9, P-5, P12, P-4]
# 31                                              [P-5]
# 32                                               [P4]
# 33                                               [P8]
# 34                                      [P1, P-8, P5]
# 35                                    [P-5, P-4, P-5]
# 36                                [P-5, P8, P-11, P8]
# 37                                               [P5]
# 38                                     [P8, P-4, P-5]
# 39                                          [P8, P-8]
# 40                                          [P-5, P8]
# 41      [P-8, P5, P4, P-5, P1, P-8, P12, P-8, P4, P5]
# 42  [P5, P-8, P-5, P12, P-5, P-4, P8, P-12, P8, P-...
# 43                             [P-5, P8, P1, P-4, P4]
# 44                                               [P8]
# 45                         [P1, P-5, P1, P8, P-8, P5]
#
#                                               Offsets          Soggetti  \
# 0          [0.0, 8.0, 40.0, 48.0, 84.0, 104.0, 128.0]    [-3, 3, 2, -2]
# 1   [150.0, 166.0, 174.0, 198.0, 214.0, 230.0, 250...    [-3, 2, 2, -2]
# 2          [298.0, 302.0, 330.0, 344.0, 362.0, 382.0]   [-3, 3, -2, -2]
# 3   [394.0, 406.0, 418.0, 434.0, 446.0, 464.0, 486...    [-2, 2, 3, -2]
# 4                              [0.0, 8.0, 40.0, 48.0]    [-3, 3, 2, -2]
# 5                          [78.0, 90.0, 106.0, 116.0]      [2, 2, 2, 2]
# 6          [160.0, 192.0, 242.0, 264.0, 284.0, 316.0]    [-3, 2, 2, -2]
# 7   [164.0, 196.0, 218.0, 222.0, 246.0, 288.0, 322...    [2, 2, -2, -3]
# 8                 [372.0, 388.0, 404.0, 422.0, 436.0]   [-3, 3, -2, -2]
# 9                        [458.0, 478.0, 500.0, 514.0]    [-2, 2, 3, -2]
# 10                                     [510.0, 522.0]     [-2, 2, 2, 2]
# 11                                        [0.0, 28.0]    [-3, 3, 2, -2]
# 12                                        [4.0, 32.0]    [-3, 2, 2, -5]
# 13                           [50.0, 54.0, 76.0, 92.0]   [-2, -3, 3, -2]
# 14         [236.0, 270.0, 274.0, 294.0, 306.0, 314.0]    [-2, 2, 3, -2]
# 15         [352.0, 360.0, 368.0, 376.0, 432.0, 442.0]    [-3, 3, 2, -2]
# 16                                     [402.0, 402.0]    [-3, 2, 2, -2]
# 17                                     [482.0, 498.0]    [-3, 2, 2, -2]
# 18                                     [522.0, 546.0]   [-3, 3, -2, -2]
# 19                       [570.0, 586.0, 592.0, 628.0]    [-2, 2, 3, -2]
# 20                                     [678.0, 698.0]   [-3, 3, -2, -2]
# 21  [706.0, 714.0, 722.0, 730.0, 754.0, 760.0, 770.0]    [-2, 2, 3, -2]
# 22                       [0.0, 8.0, 44.0, 48.0, 72.0]    [-3, 3, 2, -2]
# 23                 [94.0, 154.0, 218.0, 226.0, 250.0]    [-3, 2, 2, -2]
# 24                        [98.0, 106.0, 130.0, 138.0]   [-2, 2, -2, -2]
# 25                       [178.0, 182.0, 198.0, 202.0]   [-3, 3, -2, -2]
# 26                                     [310.0, 314.0]   [-2, -2, -2, 2]
# 27                                     [572.0, 580.0]    [2, -3, 2, -3]
# 28                              [598.0, 602.0, 606.0]  [-2, -2, -2, -2]
# 29                                     [658.0, 662.0]    [-2, -2, 3, 2]
# 30  [722.0, 726.0, 738.0, 746.0, 754.0, 758.0, 762.0]      [4, 2, 2, 2]
# 31                                     [848.0, 856.0]    [2, -3, -2, 2]
# 32                                    [994.0, 1002.0]    [-2, 2, -3, 2]
# 33                                   [1074.0, 1082.0]      [2, 2, 2, 2]
# 34                   [1142.0, 1162.0, 1180.0, 1194.0]    [-2, 2, 3, -2]
# 35                            [0.0, 16.0, 52.0, 88.0]    [-3, 3, 2, -2]
# 36                      [2.0, 18.0, 34.0, 54.0, 70.0]    [-2, 2, -3, 2]
# 37                                       [26.0, 62.0]     [2, 2, 2, -2]
# 38                       [122.0, 142.0, 174.0, 190.0]    [-3, 2, 2, -2]
# 39                              [126.0, 146.0, 158.0]     [-2, 2, 2, 2]
# 40                              [224.0, 232.0, 260.0]   [-3, 3, -2, -2]
# 41  [302.0, 310.0, 318.0, 334.0, 362.0, 370.0, 378...    [-2, 2, 3, -2]
# 42  [480.0, 488.0, 512.0, 512.0, 532.0, 540.0, 576...     [-3, 2, 2, 2]
# 43         [740.0, 740.0, 772.0, 804.0, 860.0, 880.0]    [-3, 3, 2, -2]
# 44                                     [814.0, 846.0]  [-2, -2, -2, -2]
# 45  [922.0, 930.0, 934.0, 938.0, 962.0, 978.0, 994.0]    [-3, 2, 2, -2]
#
#                                  Time_Entry_Intervals  \
# 0                  [8.0, 32.0, 8.0, 36.0, 20.0, 24.0]
# 1           [16.0, 8.0, 24.0, 16.0, 16.0, 20.0, 24.0]
# 2                       [4.0, 28.0, 14.0, 18.0, 20.0]
# 3     [12.0, 12.0, 16.0, 12.0, 18.0, 22.0, 4.0, 16.0]
# 4                                    [8.0, 32.0, 8.0]
# 5                                  [12.0, 16.0, 10.0]
# 6                      [32.0, 50.0, 22.0, 20.0, 32.0]
# 7            [32.0, 22.0, 4.0, 24.0, 42.0, 34.0, 4.0]
# 8                            [16.0, 16.0, 18.0, 14.0]
# 9                                  [20.0, 22.0, 14.0]
# 10                                             [12.0]
# 11                                             [28.0]
# 12                                             [28.0]
# 13                                  [4.0, 22.0, 16.0]
# 14                       [34.0, 4.0, 20.0, 12.0, 8.0]
# 15                        [8.0, 8.0, 8.0, 56.0, 10.0]
# 16                                              [0.0]
# 17                                             [16.0]
# 18                                             [24.0]
# 19                                  [16.0, 6.0, 36.0]
# 20                                             [20.0]
# 21                   [8.0, 8.0, 8.0, 24.0, 6.0, 10.0]
# 22                             [8.0, 36.0, 4.0, 24.0]
# 23                            [60.0, 64.0, 8.0, 24.0]
# 24                                   [8.0, 24.0, 8.0]
# 25                                   [4.0, 16.0, 4.0]
# 26                                              [4.0]
# 27                                              [8.0]
# 28                                         [4.0, 4.0]
# 29                                              [4.0]
# 30                    [4.0, 12.0, 8.0, 8.0, 4.0, 4.0]
# 31                                              [8.0]
# 32                                              [8.0]
# 33                                              [8.0]
# 34                                 [20.0, 18.0, 14.0]
# 35                                 [16.0, 36.0, 36.0]
# 36                           [16.0, 16.0, 20.0, 16.0]
# 37                                             [36.0]
# 38                                 [20.0, 32.0, 16.0]
# 39                                       [20.0, 12.0]
# 40                                        [8.0, 28.0]
# 41  [8.0, 8.0, 16.0, 28.0, 8.0, 8.0, 28.0, 8.0, 12...
# 42  [8.0, 24.0, 0.0, 20.0, 8.0, 36.0, 20.0, 4.0, 2...
# 43                      [0.0, 32.0, 32.0, 56.0, 20.0]
# 44                                             [32.0]
# 45                  [8.0, 4.0, 4.0, 24.0, 16.0, 16.0]
#
#                                                Voices Presentation_Type  \
# 0   [Cantus, Altus, Tenor, Bassus, Altus, Cantus, ...              FUGA
# 1   [Tenor, Cantus, Altus, Tenor, Bassus, Altus, C...              FUGA
# 2       [Altus, Tenor, Bassus, Altus, Cantus, Bassus]              FUGA
# 3   [Altus, Cantus, Bassus, Tenor, Altus, Bassus, ...              FUGA
# 4                      [Cantus, Altus, Tenor, Bassus]                ID
# 5                      [Cantus, Altus, Tenor, Bassus]              FUGA
# 6      [Cantus, Tenor, Bassus, Altus, Bassus, Bassus]              FUGA
# 7   [Altus, Bassus, Cantus, Tenor, Tenor, Altus, C...              FUGA
# 8              [Tenor, Cantus, Bassus, Altus, Bassus]              FUGA
# 9                     [Cantus, Tenor, Bassus, Cantus]              FUGA
# 10                                     [Tenor, Altus]              FUGA
# 11                                    [Cantus, Tenor]              FUGA
# 12                                    [Altus, Bassus]              FUGA
# 13                     [Altus, Cantus, Bassus, Altus]              FUGA
# 14     [Cantus, Altus, Cantus, Bassus, Tenor, Cantus]              FUGA
# 15      [Tenor, Cantus, Bassus, Altus, Bassus, Altus]              FUGA
# 16                                   [Cantus, Bassus]              FUGA
# 17                                     [Altus, Tenor]              FUGA
# 18                                   [Bassus, Cantus]              FUGA
# 19                    [Tenor, Cantus, Bassus, Bassus]              FUGA
# 20                                   [Cantus, Bassus]              FUGA
# 21  [Cantus, Altus, Bassus, Tenor, Bassus, Tenor, ...              FUGA
# 22              [Cantus, Altus, Tenor, Bassus, Altus]              FUGA
# 23               [Altus, Tenor, Tenor, Cantus, Altus]              FUGA
# 24                    [Cantus, Tenor, Bassus, Cantus]                ID
# 25                     [Tenor, Bassus, Cantus, Altus]                ID
# 26                                    [Cantus, Altus]              FUGA
# 27                                    [Tenor, Bassus]              FUGA
# 28                             [Cantus, Altus, Tenor]               PEN
# 29                                    [Altus, Cantus]              FUGA
# 30  [Tenor, Bassus, Cantus, Tenor, Bassus, Cantus,...              FUGA
# 31                                    [Tenor, Bassus]              FUGA
# 32                                    [Altus, Cantus]              FUGA
# 33                                    [Tenor, Cantus]              FUGA
# 34                     [Cantus, Altus, Bassus, Tenor]              FUGA
# 35                     [Cantus, Altus, Tenor, Bassus]              FUGA
# 36             [Tenor, Bassus, Cantus, Bassus, Altus]              FUGA
# 37                                    [Tenor, Cantus]              FUGA
# 38                     [Bassus, Altus, Tenor, Bassus]              FUGA
# 39                            [Tenor, Cantus, Bassus]              FUGA
# 40                             [Tenor, Bassus, Altus]              FUGA
# 41  [Altus, Bassus, Tenor, Altus, Altus, Tenor, Ba...              FUGA
# 42  [Altus, Cantus, Tenor, Bassus, Cantus, Altus, ...              FUGA
# 43      [Tenor, Bassus, Cantus, Altus, Altus, Cantus]              FUGA
# 44                                   [Bassus, Cantus]              FUGA
# 45  [Cantus, Altus, Bassus, Tenor, Cantus, Bassus,...              FUGA
#
#     Number_Entries  Flexed_Entries
# 0                7           False
# 1                8           False
# 2                6           False
# 3                9           False
# 4                4           False
# 5                4           False
# 6                6           False
# 7                8           False
# 8                5           False
# 9                4           False
# 10               2           False
# 11               2           False
# 12               2           False
# 13               4           False
# 14               6           False
# 15               6           False
# 16               2           False
# 17               2           False
# 18               2           False
# 19               4           False
# 20               2           False
# 21               7           False
# 22               5           False
# 23               5           False
# 24               4           False
# 25               4           False
# 26               2           False
# 27               2           False
# 28               3           False
# 29               2           False
# 30               7           False
# 31               2           False
# 32               2           False
# 33               2           False
# 34               4           False
# 35               4           False
# 36               5           False
# 37               2           False
# 38               4           False
# 39               3           False
# 40               3           False
# 41              11           False
# 42              14           False
# 43               6           False
# 44               2           False
# 45               7           False
