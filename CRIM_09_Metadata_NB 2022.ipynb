# %% [markdown]
# # Viewing CRIM Database Data

# %% [markdown]
# ### Load the data from CRIM

# %%
import requests
import pandas as pd
import json
from pandas.io.json import json_normalize
rel_data = requests.get('http://crimproject.org/data/relationships/').json()
obs_data = requests.get('https://crimproject.org/data/observations/').json()
people = requests.get('https://crimproject.org/data/people/').json()
pieces = requests.get('https://crimproject.org/data/pieces/').json()
voices = requests.get('https://crimproject.org/data/voices/').json()

# %% [markdown]
# #### What does **one piece** look like in JSON?
#
# `pieces[0]`

# %%
pieces[0]
# Out:
# {'url': 'https://crimproject.org/data/pieces/CRIM_Model_0001/',
#  'piece_id': 'CRIM_Model_0001',
#  'title': 'Vidi speciosam',
#  'full_title': 'Vidi speciosam',
#  'genre': {'url': 'https://crimproject.org/data/genres/motet/',
#   'name': 'Motet'},
#  'pdf_links': ['https://crimproject.org/pdf/CRIM_Model_0001.pdf'],
#  'mei_links': ['https://crimproject.org/mei/CRIM_Model_0001.mei'],
#  'composer': {'url': 'https://crimproject.org/data/people/CRIM_Person_0004/',
#   'name': 'Johannes Lupi'},
#  'date': '1538',
#  'date_sort': 1538,
#  'number_of_voices': 5,
#  'remarks': ''}

# %% [markdown]
# #### What kind of python object is it?
#
# `type(pieces[0])` is a dictionary, which is a list of key + value pairs

# %%
type(pieces[0])
# Out:
# dict

# %% [markdown]
# #### Import All the Pieces as a Pandas DataFrame
#
# `piece_df = pd.json_normalize(pieces)`
#
# `piece_df.head()`

# %%
piece_df = pd.json_normalize(pieces)
piece_df.head()
# Out:
#                                                  url         piece_id  \
# 0  https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0001
# 1  https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0002
# 2  https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0003
# 3  https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0004
# 4  https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0005
#
#                             title                      full_title  \
# 0                  Vidi speciosam                  Vidi speciosam
# 1                O gente brunette                O gente brunette
# 2   Missa IX (Cum iubilo) - Kyrie   Missa IX (Cum iubilo) - Kyrie
# 3  Missa IX (Cum iubilo) - Gloria  Missa IX (Cum iubilo) - Gloria
# 4                         Credo I                         Credo I
#
#                                            pdf_links  \
# 0  [https://crimproject.org/pdf/CRIM_Model_0001.pdf]
# 1  [https://crimproject.org/pdf/CRIM_Model_0002.pdf]
# 2  [https://crimproject.org/pdf/CRIM_Model_0003.pdf]
# 3  [https://crimproject.org/pdf/CRIM_Model_0004.pdf]
# 4  [https://crimproject.org/pdf/CRIM_Model_0005.pdf]
#
#                                            mei_links  date  date_sort  \
# 0  [https://crimproject.org/mei/CRIM_Model_0001.mei]  1538     1538.0
# 1  [https://crimproject.org/mei/CRIM_Model_0002.mei]  1548     1548.0
# 2  [https://crimproject.org/mei/CRIM_Model_0003.mei]  11xx     1100.0
# 3  [https://crimproject.org/mei/CRIM_Model_0004.mei]  10xx     1000.0
# 4  [https://crimproject.org/mei/CRIM_Model_0005.mei]  10xx     1000.0
#
#    number_of_voices                             remarks  \
# 0               5.0
# 1               4.0
# 2               1.0  In solemnitatibus et festis B.M.V.
# 3               1.0  In solemnitatibus et festis B.M.V.
# 4               1.0
#
#                                            genre.url         genre.name  \
# 0         https://crimproject.org/data/genres/motet/              Motet
# 1       https://crimproject.org/data/genres/chanson/            Chanson
# 2  https://crimproject.org/data/genres/ordinarium...  Ordinarium missae
# 3  https://crimproject.org/data/genres/ordinarium...  Ordinarium missae
# 4  https://crimproject.org/data/genres/ordinarium...  Ordinarium missae
#
#                                         composer.url    composer.name  \
# 0  https://crimproject.org/data/people/CRIM_Perso...    Johannes Lupi
# 1  https://crimproject.org/data/people/CRIM_Perso...  Thomas Champion
# 2  https://crimproject.org/data/people/CRIM_Perso...        Anonymous
# 3  https://crimproject.org/data/people/CRIM_Perso...        Anonymous
# 4  https://crimproject.org/data/people/CRIM_Perso...        Anonymous
#
#    composer
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %% [markdown]
# #### The Shape of this Dataframe
#
# `piece_df.shape`

# %%
piece_df.shape
# Out:
# (300, 15)

# %% [markdown]
# #### The Column Headings are the Keys from the Original JSON Dictionary
#
# `piece_df.columns.to_list()`

# %%
piece_df.columns.to_list()
# Out:
# ['url',
#  'piece_id',
#  'title',
#  'full_title',
#  'pdf_links',
#  'mei_links',
#  'date',
#  'date_sort',
#  'number_of_voices',
#  'remarks',
#  'genre.url',
#  'genre.name',
#  'composer.url',
#  'composer.name',
#  'composer']

# %% [markdown]
# #### Each Of These Columns is a Series
#
# `piece_df['composer.name']`

# %%
piece_df['composer.name']
# Out:
# 0        Johannes Lupi
# 1      Thomas Champion
# 2            Anonymous
# 3            Anonymous
# 4            Anonymous
#             ...
# 295     Claudio Merulo
# 296     Claudio Merulo
# 297     Claudio Merulo
# 298     Claudio Merulo
# 299     Claudio Merulo
# Name: composer.name, Length: 300, dtype: object

# %% [markdown]
# #### Applying a Method to A Column
#
# `piece_df['composer.name'].value_counts()`

# %%
piece_df['composer.name'].value_counts()
# Out:
# Giovanni Pierluigi da Palestrina    52
# Roland de Lassus                    28
# Francisco Guerrero                  20
# Claudin de Sermisy                  20
# Padovano, Annibale                  16
# Nicolle des Celliers de Hesdin      10
# Antoine de Févin                    10
# Cipriano de Rore                     8
# Victoria, Tomás Luis de              6
# Pierre de Manchicourt                6
# Anonymous                            6
# Loyset Piéton                        6
# Cristóbal de Morales                 6
# Nicolas Gombert                      6
# Jean Guyon                           5
# Mathurin Forestier                   5
# Leonhard Lechner                     5
# Claudio Merulo                       5
# Adrian Willaert                      5
# Dominique Phinot                     5
# Jean Hérissant                       5
# Pierre Colin                         5
# Josquin Des Prés                     5
# Mathieu Sohier                       5
# Pierre Clereau                       5
# Pierre Daulphin                      5
# Pere Riquet                          5
# Ippolito Baccusi                     5
# Nicolas De Marle                     5
# Verdelot, Philippe                   2
# Notker Balbulus                      2
# Pierre Sandrin                       2
# Le Heurteur, Guillaume               1
# Jacob Clemens non Papa               1
# Domenico Ferrabosco                  1
# Jean Lhéritier                       1
# Johannes Lupi                        1
# Giovan Leonardo Primavera            1
# Didier Lupi                          1
# Mantua, Jachet de                    1
# Pierre Passereau                     1
# Jean Mouton                          1
# Courtois, Jean                       1
# Pierre Cadéac                        1
# Thomas Champion                      1
# Richafort, Johannes                  1
# Lupus Hellinck                       1
# Name: composer.name, dtype: int64

# %% [markdown]
# #### Find a Particular Composer with "str.isin()"
#
# Note that the items must be presented as a **list**, even if there is only one!
#
# `pierres = piece_df['composer.name'].str.isin(['Pierre Colin', 'Pierre Sandrin'])`
# `piece_df[pierres]`

# %%
pierres = piece_df['composer.name'].isin(['Pierre Colin', 'Pierre Sandrin'])
piece_df[pierres]
# Out:
#                                                   url          piece_id  \
# 11  https://crimproject.org/data/pieces/CRIM_Model...   CRIM_Model_0012
# 32  https://crimproject.org/data/pieces/CRIM_Model...   CRIM_Model_0033
# 50  https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0001_1
# 51  https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0001_2
# 52  https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0001_3
# 53  https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0001_4
# 54  https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0001_5
#
#               title                    full_title  \
# 11  Voulant honneur               Voulant honneur
# 32   Doulce memoire                Doulce memoire
# 50            Kyrie      Missa Confitemini: Kyrie
# 51           Gloria     Missa Confitemini: Gloria
# 52            Credo      Missa Confitemini: Credo
# 53          Sanctus    Missa Confitemini: Sanctus
# 54        Agnus Dei  Missa Confitemini: Agnus Dei
#
#                                             pdf_links  \
# 11  [https://crimproject.org/pdf/CRIM_Model_0012.pdf]
# 32  [https://crimproject.org/pdf/CRIM_Model_0033.pdf]
# 50  [https://crimproject.org/pdf/CRIM_Mass_0001_1....
# 51  [https://crimproject.org/pdf/CRIM_Mass_0001_2....
# 52  [https://crimproject.org/pdf/CRIM_Mass_0001_3....
# 53  [https://crimproject.org/pdf/CRIM_Mass_0001_4....
# 54  [https://crimproject.org/pdf/CRIM_Mass_0001_5....
#
#                                             mei_links         date  date_sort  \
# 11  [https://crimproject.org/mei/CRIM_Model_0012.mei]         1545     1545.0
# 32  [https://crimproject.org/mei/CRIM_Model_0033.mei]  before 1538     1538.0
# 50  [https://crimproject.org/mei/CRIM_Mass_0001_1....         1556     1556.0
# 51  [https://crimproject.org/mei/CRIM_Mass_0001_2....         1556     1556.0
# 52  [https://crimproject.org/mei/CRIM_Mass_0001_3....         1556     1556.0
# 53  [https://crimproject.org/mei/CRIM_Mass_0001_4....         1556     1556.0
# 54  [https://crimproject.org/mei/CRIM_Mass_0001_5....         1556     1556.0
#
#     number_of_voices remarks                                     genre.url  \
# 11               4.0          https://crimproject.org/data/genres/chanson/
# 32               4.0          https://crimproject.org/data/genres/chanson/
# 50               4.0             https://crimproject.org/data/genres/mass/
# 51               4.0             https://crimproject.org/data/genres/mass/
# 52               4.0             https://crimproject.org/data/genres/mass/
# 53               4.0             https://crimproject.org/data/genres/mass/
# 54               4.0             https://crimproject.org/data/genres/mass/
#
#        genre.name                                       composer.url  \
# 11        Chanson  https://crimproject.org/data/people/CRIM_Perso...
# 32        Chanson  https://crimproject.org/data/people/CRIM_Perso...
# 50  Mass movement  https://crimproject.org/data/people/CRIM_Perso...
# 51  Mass movement  https://crimproject.org/data/people/CRIM_Perso...
# 52  Mass movement  https://crimproject.org/data/people/CRIM_Perso...
# 53  Mass movement  https://crimproject.org/data/people/CRIM_Perso...
# 54  Mass movement  https://crimproject.org/data/people/CRIM_Perso...
#
#      composer.name  composer
# 11  Pierre Sandrin       NaN
# 32  Pierre Sandrin       NaN
# 50    Pierre Colin       NaN
# 51    Pierre Colin       NaN
# 52    Pierre Colin       NaN
# 53    Pierre Colin       NaN
# 54    Pierre Colin       NaN

# %% [markdown]
# #### Search within Columns
#
# Here the search string can simply be in quotation marks.
#
# Including `na=False` ensures that null values will not create errors.  Instead they are recorded as False.
#
# `pierres = piece_df['composer.name'].str.contains('Pierre', na=False)`
#
# `piece_df[pierres].head()`

# %%
pierres = piece_df['composer.name'].str.contains('Pierre', na=False)
piece_df[pierres].head()
# Out:
#                                                   url         piece_id  \
# 8   https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0009
# 11  https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0012
# 12  https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0013
# 14  https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0015
# 32  https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0033
#
#                       title               full_title  \
# 8        Je suis déshéritée       Je suis déshéritée
# 11          Voulant honneur          Voulant honneur
# 12  Je n’en puis plus durer  Je n’en puis plus durer
# 14  Quo abiit dilectus tuus  Quo abiit dilectus tuus
# 32           Doulce memoire           Doulce memoire
#
#                                             pdf_links  \
# 8   [https://crimproject.org/pdf/CRIM_Model_0009.pdf]
# 11  [https://crimproject.org/pdf/CRIM_Model_0012.pdf]
# 12  [https://crimproject.org/pdf/CRIM_Model_0013.pdf]
# 14  [https://crimproject.org/pdf/CRIM_Model_0015.pdf]
# 32  [https://crimproject.org/pdf/CRIM_Model_0033.pdf]
#
#                                             mei_links         date  date_sort  \
# 8   [https://crimproject.org/mei/CRIM_Model_0009.mei]         1540     1540.0
# 11  [https://crimproject.org/mei/CRIM_Model_0012.mei]         1545     1545.0
# 12  [https://crimproject.org/mei/CRIM_Model_0013.mei]         1540     1540.0
# 14  [https://crimproject.org/mei/CRIM_Model_0015.mei]         1553     1553.0
# 32  [https://crimproject.org/mei/CRIM_Model_0033.mei]  before 1538     1538.0
#
#     number_of_voices remarks                                     genre.url  \
# 8                4.0          https://crimproject.org/data/genres/chanson/
# 11               4.0          https://crimproject.org/data/genres/chanson/
# 12               4.0          https://crimproject.org/data/genres/chanson/
# 14               4.0            https://crimproject.org/data/genres/motet/
# 32               4.0          https://crimproject.org/data/genres/chanson/
#
#    genre.name                                       composer.url  \
# 8     Chanson  https://crimproject.org/data/people/CRIM_Perso...
# 11    Chanson  https://crimproject.org/data/people/CRIM_Perso...
# 12    Chanson  https://crimproject.org/data/people/CRIM_Perso...
# 14      Motet  https://crimproject.org/data/people/CRIM_Perso...
# 32    Chanson  https://crimproject.org/data/people/CRIM_Perso...
#
#             composer.name  composer
# 8           Pierre Cadéac       NaN
# 11         Pierre Sandrin       NaN
# 12       Pierre Passereau       NaN
# 14  Pierre de Manchicourt       NaN
# 32         Pierre Sandrin       NaN

# %% [markdown]
# #### Logical Operators:  Not
#
# For **not** use "~"
#
# `pierres = piece_df['composer.name'].str.contains('Pierre', na=False)`
#
# `piece_df[~pierres].head()`

# %%
pierres = piece_df['composer.name'].str.contains('Pierre', na=False)

piece_df[~pierres].head()
# Out:
#                                                  url         piece_id  \
# 0  https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0001
# 1  https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0002
# 2  https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0003
# 3  https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0004
# 4  https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0005
#
#                             title                      full_title  \
# 0                  Vidi speciosam                  Vidi speciosam
# 1                O gente brunette                O gente brunette
# 2   Missa IX (Cum iubilo) - Kyrie   Missa IX (Cum iubilo) - Kyrie
# 3  Missa IX (Cum iubilo) - Gloria  Missa IX (Cum iubilo) - Gloria
# 4                         Credo I                         Credo I
#
#                                            pdf_links  \
# 0  [https://crimproject.org/pdf/CRIM_Model_0001.pdf]
# 1  [https://crimproject.org/pdf/CRIM_Model_0002.pdf]
# 2  [https://crimproject.org/pdf/CRIM_Model_0003.pdf]
# 3  [https://crimproject.org/pdf/CRIM_Model_0004.pdf]
# 4  [https://crimproject.org/pdf/CRIM_Model_0005.pdf]
#
#                                            mei_links  date  date_sort  \
# 0  [https://crimproject.org/mei/CRIM_Model_0001.mei]  1538     1538.0
# 1  [https://crimproject.org/mei/CRIM_Model_0002.mei]  1548     1548.0
# 2  [https://crimproject.org/mei/CRIM_Model_0003.mei]  11xx     1100.0
# 3  [https://crimproject.org/mei/CRIM_Model_0004.mei]  10xx     1000.0
# 4  [https://crimproject.org/mei/CRIM_Model_0005.mei]  10xx     1000.0
#
#    number_of_voices                             remarks  \
# 0               5.0
# 1               4.0
# 2               1.0  In solemnitatibus et festis B.M.V.
# 3               1.0  In solemnitatibus et festis B.M.V.
# 4               1.0
#
#                                            genre.url         genre.name  \
# 0         https://crimproject.org/data/genres/motet/              Motet
# 1       https://crimproject.org/data/genres/chanson/            Chanson
# 2  https://crimproject.org/data/genres/ordinarium...  Ordinarium missae
# 3  https://crimproject.org/data/genres/ordinarium...  Ordinarium missae
# 4  https://crimproject.org/data/genres/ordinarium...  Ordinarium missae
#
#                                         composer.url    composer.name  \
# 0  https://crimproject.org/data/people/CRIM_Perso...    Johannes Lupi
# 1  https://crimproject.org/data/people/CRIM_Perso...  Thomas Champion
# 2  https://crimproject.org/data/people/CRIM_Perso...        Anonymous
# 3  https://crimproject.org/data/people/CRIM_Perso...        Anonymous
# 4  https://crimproject.org/data/people/CRIM_Perso...        Anonymous
#
#    composer
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %% [markdown]
# #### Another Way To Find Exact Matches in a Column
#
# `kyries = piece_df['title'] == 'Kyrie'`
#
# `piece_df[kyries].head()`

# %%
kyries = piece_df['title'] == 'Kyrie'
piece_df[kyries].head()
# Out:
#                                                   url          piece_id  \
# 50  https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0001_1
# 55  https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0002_1
# 60  https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0003_1
# 65  https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0004_1
# 70  https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0005_1
#
#     title                     full_title  \
# 50  Kyrie       Missa Confitemini: Kyrie
# 55  Kyrie    Missa Vidi speciosam: Kyrie
# 60  Kyrie  Missa O gente brunette: Kyrie
# 65  Kyrie   Missa Virginis Mariae: Kyrie
# 70  Kyrie         Missa Ave Maria: Kyrie
#
#                                             pdf_links  \
# 50  [https://crimproject.org/pdf/CRIM_Mass_0001_1....
# 55  [https://crimproject.org/pdf/CRIM_Mass_0002_1....
# 60  [https://crimproject.org/pdf/CRIM_Mass_0003_1....
# 65  [https://crimproject.org/pdf/CRIM_Mass_0004_1....
# 70  [https://crimproject.org/pdf/CRIM_Mass_0005_1....
#
#                                             mei_links  date  date_sort  \
# 50  [https://crimproject.org/mei/CRIM_Mass_0001_1....  1556     1556.0
# 55  [https://crimproject.org/mei/CRIM_Mass_0002_1....  1556     1556.0
# 60  [https://crimproject.org/mei/CRIM_Mass_0003_1....  1568     1568.0
# 65  [https://crimproject.org/mei/CRIM_Mass_0004_1....  1557     1557.0
# 70  [https://crimproject.org/mei/CRIM_Mass_0005_1....  1515     1515.0
#
#     number_of_voices remarks                                  genre.url  \
# 50               4.0          https://crimproject.org/data/genres/mass/
# 55               5.0          https://crimproject.org/data/genres/mass/
# 60               4.0          https://crimproject.org/data/genres/mass/
# 65               4.0          https://crimproject.org/data/genres/mass/
# 70               4.0          https://crimproject.org/data/genres/mass/
#
#        genre.name                                       composer.url  \
# 50  Mass movement  https://crimproject.org/data/people/CRIM_Perso...
# 55  Mass movement  https://crimproject.org/data/people/CRIM_Perso...
# 60  Mass movement  https://crimproject.org/data/people/CRIM_Perso...
# 65  Mass movement  https://crimproject.org/data/people/CRIM_Perso...
# 70  Mass movement  https://crimproject.org/data/people/CRIM_Perso...
#
#        composer.name  composer
# 50      Pierre Colin       NaN
# 55    Mathieu Sohier       NaN
# 60  Nicolas De Marle       NaN
# 65    Pierre Clereau       NaN
# 70  Antoine de Févin       NaN

# %% [markdown]
# #### Logical Operators AND OR
#
# "&" = AND
#
# "|" = OR

# %%
kyrie = piece_df['title'].str.contains("Kyrie")
pierre = piece_df['composer.name'].str.contains('Pierre', na=False)
piece_df[kyrie & pierre]
# Out:
#                                                    url          piece_id  \
# 50   https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0001_1
# 65   https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0004_1
# 100  https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0011_1
# 110  https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0013_1
#
#      title                            full_title  \
# 50   Kyrie              Missa Confitemini: Kyrie
# 65   Kyrie          Missa Virginis Mariae: Kyrie
# 100  Kyrie  Missa Je n’en puis plus durer: Kyrie
# 110  Kyrie  Missa Quo abiit dilectus tuus: Kyrie
#
#                                              pdf_links  \
# 50   [https://crimproject.org/pdf/CRIM_Mass_0001_1....
# 65   [https://crimproject.org/pdf/CRIM_Mass_0004_1....
# 100  [https://crimproject.org/pdf/CRIM_Mass_0011_1....
# 110  [https://crimproject.org/pdf/CRIM_Mass_0013_1....
#
#                                              mei_links  date  date_sort  \
# 50   [https://crimproject.org/mei/CRIM_Mass_0001_1....  1556     1556.0
# 65   [https://crimproject.org/mei/CRIM_Mass_0004_1....  1557     1557.0
# 100  [https://crimproject.org/mei/CRIM_Mass_0011_1....  1557     1557.0
# 110  [https://crimproject.org/mei/CRIM_Mass_0013_1....  1556     1556.0
#
#      number_of_voices remarks                                  genre.url  \
# 50                4.0          https://crimproject.org/data/genres/mass/
# 65                4.0          https://crimproject.org/data/genres/mass/
# 100               4.0          https://crimproject.org/data/genres/mass/
# 110               4.0          https://crimproject.org/data/genres/mass/
#
#         genre.name                                       composer.url  \
# 50   Mass movement  https://crimproject.org/data/people/CRIM_Perso...
# 65   Mass movement  https://crimproject.org/data/people/CRIM_Perso...
# 100  Mass movement  https://crimproject.org/data/people/CRIM_Perso...
# 110  Mass movement  https://crimproject.org/data/people/CRIM_Perso...
#
#              composer.name  composer
# 50            Pierre Colin       NaN
# 65          Pierre Clereau       NaN
# 100        Pierre Daulphin       NaN
# 110  Pierre de Manchicourt       NaN

# %%
piece_df[(piece_df['title'].str.contains("Kyrie")) | (piece_df['composer.name'].str.contains('Pierre', na=False))]
# Out:
#                                                    url          piece_id  \
# 50   https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0001_1
# 65   https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0004_1
# 100  https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0011_1
# 110  https://crimproject.org/data/pieces/CRIM_Mass_...  CRIM_Mass_0013_1
#
#      title                            full_title  \
# 50   Kyrie              Missa Confitemini: Kyrie
# 65   Kyrie          Missa Virginis Mariae: Kyrie
# 100  Kyrie  Missa Je n’en puis plus durer: Kyrie
# 110  Kyrie  Missa Quo abiit dilectus tuus: Kyrie
#
#                                              pdf_links  \
# 50   [https://crimproject.org/pdf/CRIM_Mass_0001_1....
# 65   [https://crimproject.org/pdf/CRIM_Mass_0004_1....
# 100  [https://crimproject.org/pdf/CRIM_Mass_0011_1....
# 110  [https://crimproject.org/pdf/CRIM_Mass_0013_1....
#
#                                              mei_links  date  date_sort  \
# 50   [https://crimproject.org/mei/CRIM_Mass_0001_1....  1556     1556.0
# 65   [https://crimproject.org/mei/CRIM_Mass_0004_1....  1557     1557.0
# 100  [https://crimproject.org/mei/CRIM_Mass_0011_1....  1557     1557.0
# 110  [https://crimproject.org/mei/CRIM_Mass_0013_1....  1556     1556.0
#
#      number_of_voices remarks                                  genre.url  \
# 50                4.0          https://crimproject.org/data/genres/mass/
# 65                4.0          https://crimproject.org/data/genres/mass/
# 100               4.0          https://crimproject.org/data/genres/mass/
# 110               4.0          https://crimproject.org/data/genres/mass/
#
#         genre.name                                       composer.url  \
# 50   Mass movement  https://crimproject.org/data/people/CRIM_Perso...
# 65   Mass movement  https://crimproject.org/data/people/CRIM_Perso...
# 100  Mass movement  https://crimproject.org/data/people/CRIM_Perso...
# 110  Mass movement  https://crimproject.org/data/people/CRIM_Perso...
#
#              composer.name  composer Pierre
# 50            Pierre Colin       NaN   True
# 65          Pierre Clereau       NaN   True
# 100        Pierre Daulphin       NaN   True
# 110  Pierre de Manchicourt       NaN   True

# %% [markdown]
# #### More Examples of Masking
#
# `mask = piece_df['piece_id'].str.contains("Model_0013")`
#
# `piece_df[mask]`

# %%
mask = piece_df['piece_id'].str.contains("Model_0013")
piece_df[mask]
# Out:
#                                                   url         piece_id  \
# 12  https://crimproject.org/data/pieces/CRIM_Model...  CRIM_Model_0013
#
#                       title               full_title  \
# 12  Je n’en puis plus durer  Je n’en puis plus durer
#
#                                             pdf_links  \
# 12  [https://crimproject.org/pdf/CRIM_Model_0013.pdf]
#
#                                             mei_links  date  date_sort  \
# 12  [https://crimproject.org/mei/CRIM_Model_0013.mei]  1540     1540.0
#
#     number_of_voices remarks                                     genre.url  \
# 12               4.0          https://crimproject.org/data/genres/chanson/
#
#    genre.name                                       composer.url  \
# 12    Chanson  https://crimproject.org/data/people/CRIM_Perso...
#
#        composer.name  composer
# 12  Pierre Passereau       NaN

# %% [markdown]
# #### Extract Information with Regular Expression
#
# `df_obs["measures"] = df_obs['ema'].str.extract('(\d+-\d+)')`

# %%
df_obs = pd.json_normalize(obs_data)

# %%
df_obs["measures"] = df_obs['ema'].str.extract('(\d+-\d+)')

# %%
df_obs.head()
# Out:
#                                             url  id  \
# 0  https://crimproject.org/data/observations/1/   1
# 1  https://crimproject.org/data/observations/2/   2
# 2  https://crimproject.org/data/observations/3/   3
# 3  https://crimproject.org/data/observations/4/   4
# 4  https://crimproject.org/data/observations/5/   5
#
#                                                  ema musical_type  \
# 0  1-6/1,1,1-2,1-2,2,2/@1,@1-3,@1-3+@1,@1-3+@1-3,...         fuga
# 1  1-6/1,1,1+3,1+3,3,3/@1-4,@1-3,@1-3+@1-4,@1-3+@...         fuga
# 2          5-9/1,1,1-2,2,2/@3,@1-4,@1-2+@4,@1-4,@1-2         fuga
# 3              5-8/1,1+4,1+4,4/@3,@1-4+@4,@1+@1-3,@1         fuga
# 4  5-9,14-18/1,1,1-2,1-2,1-2,3,3,3-4,3-4,3-4/@3,@...         fuga
#
#                 remarks                    created  \
# 0  Makes up a longer ID  2017-06-19T19:22:54-04:00
# 1    Makes up longer ID  2017-06-19T19:22:54-04:00
# 2                        2017-06-19T19:31:29-04:00
# 3                        2017-06-19T19:31:29-04:00
# 4                        2017-06-19T20:36:44-04:00
#
#                             updated  curated  \
# 0  2022-02-03T18:01:55.831239-05:00     True
# 1  2022-02-03T18:01:55.833865-05:00     True
# 2  2022-02-03T18:01:55.844668-05:00     True
# 3  2022-02-03T18:01:55.846150-05:00     True
# 4  2022-02-03T18:01:55.854019-05:00     True
#
#                                         observer.url observer.name  ...  \
# 0  https://crimproject.org/data/people/CRIM_Perso...    Ian Lorenz  ...
# 1  https://crimproject.org/data/people/CRIM_Perso...    Ian Lorenz  ...
# 2  https://crimproject.org/data/people/CRIM_Perso...    Ian Lorenz  ...
# 3  https://crimproject.org/data/people/CRIM_Perso...    Ian Lorenz  ...
# 4  https://crimproject.org/data/people/CRIM_Perso...  Drew Ivarson  ...
#
#   details.irregular cadence details.cantizans name reg  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#   details.dovetail voice name details.tenorizans name reg  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   details.dovetail cadence voice details.dovetail voice name reg details  \
# 0                            NaN                             NaN     NaN
# 1                            NaN                             NaN     NaN
# 2                            NaN                             NaN     NaN
# 3                            NaN                             NaN     NaN
# 4                            NaN                             NaN     NaN
#
#   details.altizans details.bassizans measures
# 0              NaN               NaN      1-6
# 1              NaN               NaN      1-6
# 2              NaN               NaN      5-9
# 3              NaN               NaN      5-8
# 4              NaN               NaN      5-9
#
# [5 rows x 54 columns]
