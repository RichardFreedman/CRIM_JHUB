# %% [markdown]
# # Viewing CRIM Database Data

# %% [markdown]
# ### Load the data from CRIM

# %%
import requests
import pandas as pd
import json
from pandas.io.json import json_normalize
# rel_data = requests.get('http://crimproject.org/data/relationships/').json()
# obs_data = requests.get('https://crimproject.org/data/observations/').json()
people = requests.get('https://crimproject.org/data/people/').json()
pieces = requests.get('https://crimproject.org/data/pieces/').json()
voices = requests.get('https://crimproject.org/data/voices/').json()

# %%
obs_data[0]
# Out:
# {'url': 'https://crimproject.org/data/observations/1/',
#  'id': 1,
#  'observer': {'url': 'https://crimproject.org/data/people/CRIM_Person_1012/',
#   'name': 'Ian Lorenz'},
#  'piece': {'url': 'https://crimproject.org/data/pieces/CRIM_Model_0011/',
#   'piece_id': 'CRIM_Model_0011',
#   'full_title': 'Tota pulchra es',
#   'mass': None},
#  'ema': '1-6/1,1,1-2,1-2,2,2/@1,@1-3,@1-3+@1,@1-3+@1-3,@1-3,@1',
#  'musical_type': 'fuga',
#  'details': {'voices': [1, 2],
#   'inverted': False,
#   'periodic': False,
#   'regularity': None,
#   'retrograde': False,
#   'sequential': False,
#   'voice names': ['Superius', 'Contratenor'],
#   'time intervals': 'B2',
#   'entry intervals': '4-',
#   'voice names reg': ['Superius', 'Contratenor']},
#  'definition': {'url': 'https://crimproject.org/data/definition/15/',
#   'id': 15,
#   'observation_definition': [{'name': 'cantus firmus',
#     'subtypes': [{'form': 'text', 'name': 'voice', 'validation': '\\d'},
#      {'form': 'radio',
#       'name': 'features',
#       'default': 'both pitches and durations',
#       'options': ['both pitches and durations',
#        'pitches only',
#        'durations only']}]},
#    {'name': 'soggetto',
#     'subtypes': [{'form': 'text', 'name': 'voice', 'validation': '\\d'},
#      {'form': 'radio',
#       'name': 'features',
#       'default': 'both pitches and durations',
#       'options': ['both pitches and durations',
#        'pitches only',
#        'durations only']},
#      {'form': 'boolean', 'name': 'ostinato'},
#      {'form': 'boolean', 'name': 'periodic'}]},
#    {'name': 'counter soggetto',
#     'subtypes': [{'form': 'text', 'name': 'voice', 'validation': '\\d'},
#      {'form': 'radio',
#       'name': 'features',
#       'default': 'both pitches and durations',
#       'options': ['both pitches and durations',
#        'pitches only',
#        'durations only']},
#      {'form': 'boolean', 'name': 'ostinato'},
#      {'form': 'boolean', 'name': 'periodic'}]},
#    {'name': 'contrapuntal duo',
#     'subtypes': [{'form': 'text', 'name': 'voices', 'validation': '\\d,\\d'}]},
#    {'name': 'fuga',
#     'subtypes': [{'form': 'text',
#       'name': 'voices',
#       'validation': '\\d(,\\d)+'},
#      {'form': 'text',
#       'name': 'entry intervals',
#       'validation': '(\\d{1,2}[\\+-])+'},
#      {'form': 'text',
#       'name': 'time intervals',
#       'validation': '[LBSM]\\d{1,2}(\\/\\d{1,2})*'},
#      {'form': 'radio',
#       'name': 'regularity',
#       'options': ['strict', 'flexed', 'flexed tonal'],
#       'required': True},
#      {'form': 'boolean', 'name': 'inverted'},
#      {'form': 'boolean', 'name': 'periodic'},
#      {'form': 'boolean', 'name': 'retrograde'},
#      {'form': 'boolean', 'name': 'sequential'}]},
#    {'name': 'imitative duo',
#     'subtypes': [{'form': 'text',
#       'name': 'voices',
#       'validation': '\\d,\\d(,\\d,\\d)*'},
#      {'form': 'text',
#       'name': 'entry intervals',
#       'validation': '(\\d{1,2}[\\+-])+'},
#      {'form': 'text',
#       'name': 'time intervals',
#       'validation': '[LBSM]\\d{1,2}(\\/\\d{1,2})*'},
#      {'form': 'radio',
#       'name': 'regularity',
#       'options': ['strict', 'flexed', 'flexed tonal'],
#       'required': True},
#      {'form': 'boolean', 'name': 'invertible counterpoint'},
#      {'form': 'boolean', 'name': 'added entries'}]},
#    {'name': 'periodic entry',
#     'subtypes': [{'form': 'text',
#       'name': 'voices',
#       'validation': '\\d,\\d(,\\d)+'},
#      {'form': 'text',
#       'name': 'entry intervals',
#       'validation': '(\\d{1,2}[\\+-])+'},
#      {'form': 'text',
#       'name': 'time intervals',
#       'validation': '[LBSM]\\d{1,2}(\\/\\d{1,2})*'},
#      {'form': 'radio',
#       'name': 'regularity',
#       'options': ['strict', 'flexed', 'flexed tonal'],
#       'required': True},
#      {'form': 'boolean', 'name': 'sequential'},
#      {'form': 'boolean', 'name': 'invertible counterpoint'},
#      {'form': 'boolean', 'name': 'added entries'}]},
#    {'name': 'non-imitative duo',
#     'subtypes': [{'form': 'text',
#       'name': 'voices',
#       'validation': '\\d,\\d(,\\d,\\d)*'},
#      {'form': 'text',
#       'name': 'entry intervals',
#       'validation': '(\\d{1,2}[\\+-])+'},
#      {'form': 'text',
#       'name': 'time intervals',
#       'validation': '[LBSM]\\d{1,2}(\\/\\d{1,2})*'},
#      {'form': 'radio',
#       'name': 'regularity',
#       'options': ['strict', 'flexed', 'flexed tonal'],
#       'required': True},
#      {'form': 'boolean', 'name': 'sequential'},
#      {'form': 'boolean', 'name': 'invertible counterpoint'},
#      {'form': 'boolean', 'name': 'added entries'}]},
#    {'name': 'homorhythm',
#     'subtypes': [{'form': 'radio',
#       'name': 'type',
#       'options': ['simple', 'staggered', 'sequential', 'fauxbourdon'],
#       'required': True},
#      {'form': 'text', 'name': 'voices', 'validation': '\\d,\\d(,\\d)+'},
#      {'form': 'boolean', 'name': 'dialogue'}]},
#    {'name': 'cadence',
#     'subtypes': [{'form': 'radio',
#       'name': 'tone',
#       'options': ['C', 'D', 'E', 'E-flat', 'F', 'G', 'A', 'B', 'B-flat'],
#       'required': True},
#      {'form': 'radio',
#       'name': 'type',
#       'options': ['authentic', 'plagal', 'phrygian'],
#       'required': True},
#      {'form': 'text', 'name': 'cantizans', 'validation': '\\d?'},
#      {'form': 'text', 'name': 'tenorizans', 'validation': '\\d?'},
#      {'form': 'boolean', 'name': 'irregular cadence'},
#      {'form': 'checkbox',
#       'name': 'irregular roles',
#       'options': ['cantizans', 'altizans', 'tenorizans', 'bassizans']},
#      {'form': 'boolean', 'name': 'dovetail cadence'},
#      {'form': 'text', 'name': 'dovetail cadence voice', 'validation': '\\d?'},
#      {'form': 'radio',
#       'name': 'dovetail position',
#       'options': ['above', 'between', 'below'],
#       'required': False}]}]},
#  'remarks': 'Makes up a longer ID',
#  'created': '2017-06-19T19:22:54-04:00',
#  'updated': '2022-02-03T18:01:55.831239-05:00',
#  'curated': True}

# %%
df = pd.json_normalize(people)
df.head()
# Out:
#                                                  url         person_id  \
# 0  https://crimproject.org/data/people/CRIM_Perso...  CRIM_Person_0001
# 1  https://crimproject.org/data/people/CRIM_Perso...  CRIM_Person_0002
# 2  https://crimproject.org/data/people/CRIM_Perso...  CRIM_Person_0003
# 3  https://crimproject.org/data/people/CRIM_Perso...  CRIM_Person_0004
# 4  https://crimproject.org/data/people/CRIM_Perso...  CRIM_Person_0005
#
#                 name           name_sort name_alternate_list birth_date  \
# 0       Pierre Colin       Colin, Pierre                           15xx
# 1  Nicolas Du Chemin  Du Chemin, Nicolas                          1515?
# 2     Mathieu Sohier     Sohier, Mathieu                           15xx
# 3      Johannes Lupi      Lupi, Johannes                          1506?
# 4  Pierre Attaignant  Attaignant, Pierre                          1494?
#
#   death_date active_date                                         role_types
# 0       15xx   1538–1572  [{'url': 'https://crimproject.org/data/roletyp...
# 1       1576              [{'url': 'https://crimproject.org/data/roletyp...
# 2    c. 1560       1540s  [{'url': 'https://crimproject.org/data/roletyp...
# 3       1539       1530s  [{'url': 'https://crimproject.org/data/roletyp...
# 4      1552?              [{'url': 'https://crimproject.org/data/roletyp...

# %%
df.shape
# Out:
# (5398, 53)

# %%
df['name_sort'].value_counts()
# Out:
# Pierazzo, Elena            1
# Bazzacco, Anna             1
# Louboutin, Claire          1
# Russo-Batterham, Daniel    1
# Gombert, Nicolas           1
#                           ..
# Amadino, Riccardo          1
# Rodin, Jesse               1
# Freedman, Richard          1
# Manfredi, Manon            1
# Magro, Agostino            1
# Name: name_sort, Length: 185, dtype: int64

# %%
mask = df['role.type'].str.contains("composer")
comp = df[mask]
lorenz_list['piece.full_title'].value_counts()

# fiala_list = df[mask]
# fiala_list['piece.full_title'].value_counts()
# Out:
# Je suis déshéritée                          354
# Quo abiit dilectus tuus                     322
# Missa Je suis déshéritée: Credo             112
# Missa Je suis déshéritée: Gloria             92
# Missa Quo abiit dilectus tuus: Credo         86
# Missa Quo abiit dilectus tuus: Gloria        76
# Missa Je suis déshéritée: Sanctus            62
# Missa Quo abiit dilectus tuus: Sanctus       56
# Missa Quo abiit dilectus tuus: Kyrie         54
# Missa Je suis déshéritée: Agnus Dei          52
# Missa Quo abiit dilectus tuus: Agnus Dei     51
# Missa Je suis déshéritée: Kyrie              36
# Tota pulchra es                               2
# Missa Tota pulchra es: Credo                  2
# Name: piece.full_title, dtype: int64

# %%
df['piece.piece_id'].str.contains("Model_0013")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5413    False
# 5414    False
# 5415    False
# 5416    False
# 5417    False
# Name: piece.piece_id, Length: 5418, dtype: bool

# %%
df["measures"] = df['ema'].str.extract('(\d+-\d+)')

# %%
df.head()
# Out:
#                                             url  id  \
# 0  https://crimproject.org/data/observations/1/   1
# 1  https://crimproject.org/data/observations/2/   2
# 2  https://crimproject.org/data/observations/3/   3
# 3  https://crimproject.org/data/observations/4/   4
# 4  https://crimproject.org/data/observations/5/   5
#
#                                                  ema musical_type  \
# 0  1-6/1,1,1-2,1-2,2,2/@1,@1-3,@1-3+@1,@1-3+@1-3,...         fuga
# 1  1-6/1,1,1+3,1+3,3,3/@1-4,@1-3,@1-3+@1-4,@1-3+@...         fuga
# 2          5-9/1,1,1-2,2,2/@3,@1-4,@1-2+@4,@1-4,@1-2         fuga
# 3              5-8/1,1+4,1+4,4/@3,@1-4+@4,@1+@1-3,@1         fuga
# 4  5-9,14-18/1,1,1-2,1-2,1-2,3,3,3-4,3-4,3-4/@3,@...         fuga
#
#                 remarks                    created  \
# 0  Makes up a longer ID  2017-06-19T19:22:54-04:00
# 1    Makes up longer ID  2017-06-19T19:22:54-04:00
# 2                        2017-06-19T19:31:29-04:00
# 3                        2017-06-19T19:31:29-04:00
# 4                        2017-06-19T20:36:44-04:00
#
#                             updated  curated  \
# 0  2022-02-03T18:01:55.831239-05:00     True
# 1  2022-02-03T18:01:55.833865-05:00     True
# 2  2022-02-03T18:01:55.844668-05:00     True
# 3  2022-02-03T18:01:55.846150-05:00     True
# 4  2022-02-03T18:01:55.854019-05:00     True
#
#                                         observer.url observer.name  ...  \
# 0  https://crimproject.org/data/people/CRIM_Perso...    Ian Lorenz  ...
# 1  https://crimproject.org/data/people/CRIM_Perso...    Ian Lorenz  ...
# 2  https://crimproject.org/data/people/CRIM_Perso...    Ian Lorenz  ...
# 3  https://crimproject.org/data/people/CRIM_Perso...    Ian Lorenz  ...
# 4  https://crimproject.org/data/people/CRIM_Perso...  Drew Ivarson  ...
#
#   details.irregular cadence details.cantizans name reg  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#   details.dovetail voice name details.tenorizans name reg  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   details.dovetail cadence voice details.dovetail voice name reg details  \
# 0                            NaN                             NaN     NaN
# 1                            NaN                             NaN     NaN
# 2                            NaN                             NaN     NaN
# 3                            NaN                             NaN     NaN
# 4                            NaN                             NaN     NaN
#
#   details.altizans details.bassizans measures
# 0              NaN               NaN      1-6
# 1              NaN               NaN      1-6
# 2              NaN               NaN      5-9
# 3              NaN               NaN      5-8
# 4              NaN               NaN      5-9
#
# [5 rows x 54 columns]
