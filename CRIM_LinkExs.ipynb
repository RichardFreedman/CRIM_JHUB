# %%
import requests
from IPython.display import display, HTML
from IPython.display import IFrame
import urllib.parse

import crim_intervals
from crim_intervals import * 
from crim_intervals import main_objs
import crim_intervals.visualizations as viz
import pandas as pd
import re
import altair as alt
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interact
from pandas import json_normalize
from pyvis.network import Network
from IPython.display import display
import requests
import os
import glob as glob
import json
import urllib.parse


MYDIR = ("saved_csv")
CHECK_FOLDER = os.path.isdir(MYDIR)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MYDIR)
    print("created folder : ", MYDIR)
else:
    print(MYDIR, "folder already exists.")
    
MUSDIR = ("Music_Files")
CHECK_FOLDER = os.path.isdir(MUSDIR)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MUSDIR)
    print("created folder : ", MUSDIR)
else:
    print(MUSDIR, "folder already exists.")
# Out:
# saved_csv folder already exists.
# Music_Files folder already exists.

# %% [markdown]
# ## Import Piece

# %%
prefix = 'https://raw.githubusercontent.com/CRIM-Project/CRIM-online/master/crim/static/mei/MEI_4.0/'
piece_id = 'CRIM_Model_0008.mei'

url = prefix + piece_id


piece = importScore(url)
piece.metadata
# Out:
# {'title': 'Ave Maria', 'composer': 'Josquin Des Prés', 'date': 1502}

# %%
# %%capture --no-display
# piece.verovioPrintExample(10, 13)

# %%
prefix = 'https://raw.githubusercontent.com/CRIM-Project/CRIM-online/master/crim/static/mei/MEI_4.0/'
piece_id = 'CRIM_Model_0008.mei'
url = prefix + piece_id
piece = importScore(url)
cd=piece.cadences()
# piece.verovioCadences(df=cd)

# %%
p_types = piece.presentationTypes()
piece.verovioPtypes(p_types)
# Out:
# Results:
# File Name:  CRIM_Model_0008
# Josquin Des Prés
# Ave Maria
# Measures: 1-7
# Presentation Type:  PEN
# Voices:  ['[Superius]', 'Altus', 'Tenor', 'Bassus']
# Number of Entries:  4
# Soggetti:  [('4', '1', '2', '2')]
# Melodic Entry Intervals:  ['P-8', 'P1', 'P-8']
# Time Entry Intervals:  [16.0, 16.0, 16.0]
# Flexed:  False
# Parallel Entries: None
# Number of Non-Overlapping Voices: 0
# [Warning] Unsupported data.PERCENT '100'
# [Warning] Unsupported data.PERCENT '100'
# [Warning] Unsupported data.PERCENT '100'
# [Warning] Unsupported data.PERCENT '100'
# [Warning] Unsupported '<line>' within <measure>
# [Warning] Unsupported '<line>' within <measure>
# [Warning] Unsupported '<line>' within <measure>
# [Warning] Unsupported '<line>' within <measure>
# [Warning] Unsupported '<line>' within <measure>
# [Warning] Unsupported '<line>' within <measure>
# [Warning] Unsupported '<line>' within <measure>
# [Warning] Unsupported '<line>' within <measure>
# ...

# %%
prefix = 'https://raw.githubusercontent.com/CRIM-Project/CRIM-online/master/crim/static/mei/MEI_4.0/'
piece_id = 'CRIM_Model_0008.mei'
url = prefix + piece_id
piece = importScore(url)
hr = piece.homorhythm()
piece.linkExamples(df=hr, piece_url=url)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>active_voices</th>
#       <th>number_dur_ngrams</th>
#       <th>hr_voices</th>
#       <th>[Superius]</th>
#       <th>Altus</th>
#       <th>Tenor</th>
#       <th>Bassus</th>
#       <th>syllable_set</th>
#       <th>count_lyr_ngrams</th>
#       <th>active_syll_voices</th>
#       <th>voice_match</th>
#       <th>ngram_length</th>
#       <th>Progress</th>
#     </tr>
#     <tr>
#       <th>Measure</th>
#       <th>Beat</th>
#       <th>Offset</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>31.0</th>
#       <th>3.0</th>
#       <th>244.0</th>
#       <td>2.0</td>
# ...

# %%
prefix = 'https://raw.githubusercontent.com/CRIM-Project/CRIM-online/master/crim/static/mei/MEI_4.0/'
piece_id = 'CRIM_Model_0008.mei'
url = prefix + piece_id
piece = importScore(url)
mel = piece.melodic(kind='d')
ng = piece.ngrams(df=mel, n=6, offsets='both')
piece.linkExamples(df=ng, piece_url=url)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>[Superius]</th>
#       <th>Altus</th>
#       <th>Tenor</th>
#       <th>Bassus</th>
#     </tr>
#     <tr>
#       <th>First</th>
#       <th>Last</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>62.0</th>
#       <th>76.0</th>
#       <td><a href="https://eleon024.github.io/ema_react_app/?pieceURL=https%3A%2F%2Fraw.githubusercontent.com%2FCRIM-Project%2FCRIM-online%2Fmaster%2Fcrim%2Fstatic%2Fmei%2FMEI_4.0%2FCRIM_Model_0008.mei&ema_expression=%2F8-10%2F1%2C1%2C1%2F%401.0-end%2C%40all%2C%40start-3.0%2Fhighlight&measure_range=8-10&observation=+%28%27-2%27%2C+%27-2%27%2C+%27-2%27%2C+%272%27%2C+%27-2%27%2C+%274%27%29" rel="noopener noreferrer" target="_blank">('-2', '-2', '-2', '2', '-2', '4')</a></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
# ...

# %% [markdown]
# ## Ngrams and Link Example

# %%
prefix = 'https://raw.githubusercontent.com/CRIM-Project/CRIM-online/master/crim/static/mei/MEI_4.0/'
piece_id = 'CRIM_Model_0008.mei'
url = prefix + piece_id
piece = importScore(url)
mel = piece.melodic(kind='d')
ng = piece.ngrams(df=mel, n=6, offsets='both')
piece.linkExamples(df=ng, piece_url=url)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>[Superius]</th>
#       <th>Altus</th>
#       <th>Tenor</th>
#       <th>Bassus</th>
#     </tr>
#     <tr>
#       <th>First</th>
#       <th>Last</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>62.0</th>
#       <th>76.0</th>
#       <td><a href="https://eleon024.github.io/ema_react_app/?pieceURL=https%3A%2F%2Fraw.githubusercontent.com%2FCRIM-Project%2FCRIM-online%2Fmaster%2Fcrim%2Fstatic%2Fmei%2FMEI_4.0%2FCRIM_Model_0008.mei&ema_expression=%2F8-10%2F1%2C1%2C1%2F%401.0-end%2C%40all%2C%40start-3.0%2Fhighlight&measure_range=8-10&observation=+%28%27-2%27%2C+%27-2%27%2C+%27-2%27%2C+%272%27%2C+%27-2%27%2C+%274%27%29" rel="noopener noreferrer" target="_blank">('-2', '-2', '-2', '2', '-2', '4')</a></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
# ...

# %%
pieceurl = 'Music_Files/Daser_Missa_Ecce_nunc_Kyrie_E_corr.mei'
piece.linkExamples(df=ng, piece_url=pieceurl)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>[Superius]</th>
#       <th>Altus</th>
#       <th>Tenor</th>
#       <th>Bassus</th>
#     </tr>
#     <tr>
#       <th>First</th>
#       <th>Last</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>62.0</th>
#       <th>76.0</th>
#       <td><a href="https://eleon024.github.io/ema_react_app/?pieceURL=Music_Files%2FDaser_Missa_Ecce_nunc_Kyrie_E_corr.mei&ema_expression=%2F8-10%2F1%2C1%2C1%2F%401.0-end%2C%40all%2C%40start-3.0%2Fhighlight&measure_range=8-10&observation=+%28%27-2%27%2C+%27-2%27%2C+%27-2%27%2C+%272%27%2C+%27-2%27%2C+%274%27%29" rel="noopener noreferrer" target="_blank">('-2', '-2', '-2', '2', '-2', '4')</a></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>64.0</th>
#       <th>82.0</th>
# ...

# %% [markdown]
# ## Cadences and Linked Examples

# %%
cad = piece.cadences()
selected_cads = cad[cad['Tone'] == 'E']
piece.linkExamples(df=cad, piece_url=url)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CadType</th>
#       <th>LeadingTones</th>
#       <th>CVFs</th>
#       <th>Low</th>
#       <th>RelLow</th>
#       <th>Tone</th>
#       <th>RelTone</th>
#       <th>TSig</th>
#       <th>Measure</th>
#       <th>Beat</th>
#       <th>Sounding</th>
#       <th>Progress</th>
#       <th>SinceLast</th>
#       <th>ToNext</th>
#     </tr>
#     <tr>
#       <th>Last</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>188.0</th>
# ...

# %% [markdown]
# ## HR and Linked Examples

# %%
hr = piece.homorhythm(ngram_length = 4, full_hr = True).head(5)
piece.linkExamples(df=hr)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>active_voices</th>
#       <th>number_dur_ngrams</th>
#       <th>hr_voices</th>
#       <th>[Superius]</th>
#       <th>Altus</th>
#       <th>Tenor</th>
#       <th>Bassus</th>
#       <th>syllable_set</th>
#       <th>count_lyr_ngrams</th>
#       <th>active_syll_voices</th>
#       <th>voice_match</th>
#       <th>ngram_length</th>
#       <th>Progress</th>
#     </tr>
#     <tr>
#       <th>Measure</th>
#       <th>Beat</th>
#       <th>Offset</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>31.0</th>
#       <th>3.0</th>
#       <th>244.0</th>
#       <td>2.0</td>
# ...

# %% [markdown]
# ## Presentation Types and Linked Examples

# %%
pt = piece.presentationTypes(limit_to_entries = True,
                        head_flex=1,
                        body_flex = 0,
                        include_hidden_types = False,
                        combine_unisons = True,
                        melodic_ngram_length = 4)

# %%
ids = pt[pt['Presentation_Type'] == "FUGA"]

# %%
piece.linkExamples(df=ids)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Composer</th>
#       <th>Title</th>
#       <th>First_Offset</th>
#       <th>Measures_Beats</th>
#       <th>Melodic_Entry_Intervals</th>
#       <th>Offsets</th>
#       <th>Soggetti</th>
#       <th>Time_Entry_Intervals</th>
#       <th>Voices</th>
#       <th>Presentation_Type</th>
#       <th>Number_Entries</th>
#       <th>Flexed_Entries</th>
#       <th>Parallel_Entries</th>
#       <th>Parallel_Voice</th>
#       <th>Count_Non_Overlaps</th>
#       <th>Progress</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>Josquin Des Prés</td>
#       <td>Ave Maria</td>
#       <td>176.0</td>
#       <td>[23.0/1.0, 28.0/1.0]</td>
#       <td>[P-8]</td>
#       <td>[176.0, 216.0]</td>
#       <td>[(-3, -2, 2, 2), (-2, -2, 2, 2)]</td>
#       <td>[40.0]</td>
#       <td>[Altus, Bassus]</td>
# ...
