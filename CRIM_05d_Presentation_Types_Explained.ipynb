# %% [markdown]
# ## Presentation Type Tools Explained

# %%
import intervals
from intervals import * 
from intervals import main_objs
import pandas as pd
import re
import os
import numpy
import itertools
# import collections
MYDIR = ("saved_csv")
CHECK_FOLDER = os.path.isdir(MYDIR)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MYDIR)
    print("created folder : ", MYDIR)

else:
    print(MYDIR, "folder already exists.")
    
MUSDIR = ("Music_Files")
CHECK_FOLDER = os.path.isdir(MUSDIR)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MUSDIR)
    print("created folder : ", MUSDIR)

else:
    print(MUSDIR, "folder already exists.")
# Out:
# saved_csv folder already exists.
# Music_Files folder already exists.

# %%
# Select a prefix:

# prefix = 'Music_Files/'
# just add the CRIM Piece ID here
prefix = 'https://crimproject.org/mei/'
# just add the CRIM Piece ID here
mei_file = 'CRIM_Model_0008.mei'
url = prefix + mei_file
piece = importScore(url)

print(piece.metadata)
# Out:
# {'title': 'Ave Maria', 'composer': 'Josquin Des Prés', 'date': 1502}

# %% [markdown]
# # How does it Work?

# %% [markdown]
# ### Find the Melodic Entries
#
# With various options, then passed to the entries method:
#
# ```
# nr = piece.notes(combineUnisons=True)
# mel = piece.melodic(df=nr, kind='d', end=False)
# mel_ng = piece.ngrams(df=mel, n=4)
# entries = piece.entries(mel_ng)
# ng_durs = piece.durations(df=entries)
# det = piece.detailIndex(nr, offset=True, progress=True)
# entries.head(15)
# ```
#
#
# OR simply with defaults:
#
# ```
# piece.entries(df=None, n=None, thematic=False, anywhere=False, fermatas=True, exclude=[])
# ```

# %%
nr = piece.notes(combineUnisons=True)
mel = piece.melodic(df=nr, kind='d', end=False)
mel_ng = piece.ngrams(df=mel, n=4)
entries = piece.entries(mel_ng)
ng_durs = piece.durations(df=entries)
det = piece.detailIndex(nr, offset=True, progress=True)
entries.head(15)


# piece.entries()
# Out:
#             [Superius]            Altus            Tenor           Bassus
# 0.0      (4, 2, 2, -3)              NaN              NaN              NaN
# 16.0               NaN    (4, 2, 2, -3)              NaN              NaN
# 32.0               NaN              NaN    (4, 2, 2, -3)              NaN
# 48.0               NaN              NaN              NaN    (4, 2, 2, -3)
# 56.0   (-2, -2, -2, 2)              NaN              NaN              NaN
# 72.0               NaN  (-2, -2, -2, 2)              NaN              NaN
# 88.0               NaN              NaN  (-2, -2, -2, 2)              NaN
# 104.0              NaN              NaN              NaN  (-2, -2, -2, 2)
# 124.0   (2, 2, -3, -2)              NaN              NaN              NaN
# 156.0              NaN              NaN    (2, 2, -3, 3)              NaN
# 176.0              NaN   (-3, -2, 2, 2)              NaN              NaN
# 192.0   (-3, -2, 4, 2)              NaN              NaN              NaN
# 200.0              NaN              NaN  (-3, -2, 8, -2)              NaN
# 216.0              NaN              NaN              NaN   (-3, -2, 2, 2)
# 222.0  (-2, -2, -2, 2)              NaN              NaN              NaN

# %%
points = pd.DataFrame(columns=['Composer',
                    'Title',
                    'First_Offset',
                    'Measures_Beats',
                    'Melodic_Entry_Intervals',
                    'Offsets',
                    'Soggetti',
                    'Time_Entry_Intervals',
                    'Voices',
                    'Presentation_Type'])
points2 = pd.DataFrame()
# defines column order in final df
# others are at the end for the overlapping entries
col_order = list(points.columns) + ['Number_Entries',
                                    'Flexed_Entries',
                                    'Parallel_Entries',
                                    'Parallel_Voice',
                                    'Count_Offsets',
                                    'Offsets_Key']

det = piece.detailIndex(nr, offset=True, progress=True)
points
# Out:
# Empty DataFrame
# Columns: [Composer, Title, First_Offset, Measures_Beats, Melodic_Entry_Intervals, Offsets, Soggetti, Time_Entry_Intervals, Voices, Presentation_Type]
# Index: []

# %% [markdown]
# ### Stack the Entries
#
# - stack the entries as one column--in the order of their appearance
# - We also rename a column to clarify that this is our 'pattern'

# %%
mels_stacked = entries.stack().to_frame()
mels_stacked.rename(columns =  {0:"pattern"}, inplace = True)
mels_stacked
# Out:
#                            pattern
# 0.0    [Superius]    (4, 2, 2, -3)
# 16.0   Altus         (4, 2, 2, -3)
# 32.0   Tenor         (4, 2, 2, -3)
# 48.0   Bassus        (4, 2, 2, -3)
# 56.0   [Superius]  (-2, -2, -2, 2)
# ...                            ...
# 1200.0 Tenor        (-2, -2, 2, 2)
#        Bassus      (5, -2, -2, -2)
# 1236.0 [Superius]  (-2, -2, -2, 2)
#        Tenor        (-2, 2, 2, -2)
#        Bassus       (8, -4, 2, -2)
#
# [74 rows x 1 columns]

# %% [markdown]
# ### Edit Distances for Similar Entries
#
# - find the edit distance, based on side-by-side comparison of melodic ngrams
# - note that we can provide a 'head_flex' that allows small differences in the first interval to pass the test

# %%
# set the head flex:
head_flex = 1

# now use that flex in the "flexed_distance" function
dist = piece.flexed_distance(head_flex, entries)

# stack the result
dist_stack = dist.stack().to_frame()
dist_stack
# Out:
#                                  0
# (4, 2, 2, -3)  (4, 2, 2, -3)     0
#                (-2, -2, -2, 2)  19
#                (2, 2, -3, -2)    8
#                (2, 2, -3, 3)    13
#                (-3, -2, 2, 2)   16
# ...                             ..
# (8, -4, 2, -2) (-2, -2, 2, -2)  12
#                (-3, 4, -2, -2)  23
#                (-2, -2, 2, 2)   16
#                (-2, 2, 2, -2)   16
#                (8, -4, 2, -2)    0
#
# [1089 rows x 1 columns]

# %% [markdown]
# ### Body Flex
#
# - filter body flex distances to threshold.  <2 is good

# %%
# set body flex
body_distance = 1

# filter the previous dataframe (which already considers the head flex)
filtered_dist_stack = dist_stack[dist_stack[0] < body_distance]

# restack these
filtered_dist = filtered_dist_stack.reset_index()
filtered_dist.rename(columns =  {'level_0':"source", 'level_1':'match'}, inplace = True)
filtered_dist.head()
# Out:
#             source            match  0
# 0    (4, 2, 2, -3)    (4, 2, 2, -3)  0
# 1  (-2, -2, -2, 2)  (-2, -2, -2, 2)  0
# 2   (2, 2, -3, -2)   (2, 2, -3, -2)  0
# 3    (2, 2, -3, 3)    (2, 2, -3, 3)  0
# 4   (-3, -2, 2, 2)   (-3, -2, 2, 2)  0

# %% [markdown]
# ### Grouping Filtered Matches
#
# - Group the filtered distanced patterns

# %%
full_list_of_matches = filtered_dist.groupby('source')['match'].apply(list).reset_index()
full_list_of_matches.head()
# Out:
#              source               match
# 0  (-2, -2, -2, -2)  [(-2, -2, -2, -2)]
# 1   (-2, -2, -2, 2)   [(-2, -2, -2, 2)]
# 2   (-2, -2, -3, 5)   [(-2, -2, -3, 5)]
# 3   (-2, -2, 2, -2)   [(-2, -2, 2, -2)]
# 4   (-2, -2, 2, -3)   [(-2, -2, 2, -3)]

# %% [markdown]
# ### With the Matches Identified, Find the Locations and Distances Between Them
#
# - Using the "matches" from the previous step, return a series of arrays:  all of the instances of a given soggetto, with offset and voice

# %%
# just decide in advance that we are not looking for hidden types.
include_hidden_types = False

# Group the filtered distanced patterns
full_list_of_matches = filtered_dist.groupby('source')['match'].apply(list).reset_index()


# classification without hidden types
if include_hidden_types == False:
    for matches in full_list_of_matches["match"]:
        
        # build a list of the related entries--
        # those that qualify as matching according to initial settings for flex head and body
        related_entry_list = mels_stacked[mels_stacked['pattern'].isin(matches)]
        entry_array = related_entry_list.reset_index(level=1).rename(columns = {'level_1': "voice", 0: "pattern"})
        offset_list = entry_array.index.to_list()
        
        # split them when we encounter a long gap (> 70 offsets)
        split_list = list(ImportedPiece._split_by_threshold(offset_list))
        
        # classify each 'set'
        # note that the melodic entry distances are determined by the helper: _temp_dict_of_details
        # the data are temporarily stored in "temp", then appended to "points" in the next steps
        for item in split_list:
            temp = piece._temp_dict_of_details(item, entry_array, det, matches)
            points = points.append(temp, ignore_index=True)
            points['Presentation_Type'] = points['Time_Entry_Intervals'].apply(ImportedPiece._classify_by_offset)
            points.drop_duplicates(subset=["First_Offset"], keep='first', inplace = True)
            points = points[points['Offsets'].apply(len) > 1]

    
    # cleaning up and recording various other features:
    # offsets
    points["Offsets_Key"] = points["Offsets"].apply(ImportedPiece._offset_joiner)
    
    # flexed entries ?
    points['Flexed_Entries'] = points["Soggetti"].apply(len) > 1
    
    # how many entries ?
    points["Number_Entries"] = points["Offsets"].apply(len)
    
    # makes sure we have no p types with only one entry
    points["Count_Offsets"] = points["Offsets"].apply(set).apply(len)
    points = points[points["Count_Offsets"] > 1]

    # sorts results by first offset
    points = points.reindex(columns=col_order).sort_values("First_Offset").reset_index(drop=True)
    
    # applying various private functions for overlapping entry tests.
    # note that ng_durs must be passed to the first of these, via args
    
    points["Entry_Durs"] = points[["Offsets", "Voices"]].apply(ImportedPiece._dur_ngram_helper, args=(ng_durs,), axis=1)
    points["Overlaps"] = points[["Entry_Durs", "Offsets"]].apply(ImportedPiece._entry_overlap_helper, axis=1)
    points["Count_Non_Overlaps"] = points["Overlaps"].apply(ImportedPiece._non_overlap_count)
    
    # remove columns no longer needed
    points.drop(['Count_Offsets', 'Offsets_Key', 'Entry_Durs', 'Overlaps'], axis=1, inplace=True)

    
points
# Out:
#             Composer      Title  First_Offset  \
# 0   Josquin Des Prés  Ave Maria           0.0
# 1   Josquin Des Prés  Ave Maria          56.0
# 2   Josquin Des Prés  Ave Maria         176.0
# 3   Josquin Des Prés  Ave Maria         244.0
# 4   Josquin Des Prés  Ave Maria         428.0
# 5   Josquin Des Prés  Ave Maria         508.0
# 6   Josquin Des Prés  Ave Maria         616.0
# 7   Josquin Des Prés  Ave Maria         748.0
# 8   Josquin Des Prés  Ave Maria         796.0
# 9   Josquin Des Prés  Ave Maria         944.0
# 10  Josquin Des Prés  Ave Maria         948.0
# 11  Josquin Des Prés  Ave Maria         972.0
# 12  Josquin Des Prés  Ave Maria         980.0
# 13  Josquin Des Prés  Ave Maria        1124.0
#
#                           Measures_Beats Melodic_Entry_Intervals  \
# 0           [1/1.0, 3/1.0, 5/1.0, 7/1.0]          [P-8, P1, P-8]
# 1        [8/1.0, 10/1.0, 12/1.0, 14/1.0]          [P-8, P1, P-8]
# 2                       [23/1.0, 28/1.0]                   [P-8]
# 3                       [31/3.0, 35/3.0]                   [P-8]
# 4       [54/3.0, 55/1.0, 59/3.0, 60/1.0]         [P-5, P-4, P-5]
# 5       [64/3.0, 66/3.0, 67/3.0, 69/3.0]         [P-5, P-4, P-5]
# 6                       [78/1.0, 81/1.0]                   [P-8]
# 7                       [94/1.0, 98/1.0]                    [P1]
# 8                       [98/1.0, 98/2.0]                   [P-5]
# 9   [111/1.0, 114/1.0, 119/1.0, 122/1.0]          [P-8, P8, P-8]
# 10                    [111/3.0, 119/3.0]                    [P1]
# 11                    [114/3.0, 122/3.0]                    [P1]
# 12  [115/3.0, 123/3.0, 127/3.0, 129/3.0]           [P1, m7, P-8]
# 13                    [133/3.0, 136/3.0]                   [P-8]
#
#                             Offsets                          Soggetti  \
# 0           [0.0, 16.0, 32.0, 48.0]                   [(4, 2, 2, -3)]
# 1         [56.0, 72.0, 88.0, 104.0]                 [(-2, -2, -2, 2)]
# 2                    [176.0, 216.0]  [(-3, -2, 2, 2), (-2, -2, 2, 2)]
# 3                    [244.0, 276.0]                   [(2, 2, 2, -2)]
# 4      [428.0, 432.0, 468.0, 472.0]                   [(4, -2, 2, 2)]
# 5      [508.0, 524.0, 532.0, 548.0]                  [(2, -3, 2, -3)]
# 6                    [616.0, 640.0]                  [(2, -3, 2, -2)]
# 7                    [748.0, 796.0]                 [(2, -2, -2, -2)]
# 8                    [796.0, 800.0]                   [(2, 2, -3, 4)]
# 9    [944.0, 968.0, 1008.0, 1032.0]                 [(2, -2, -2, -2)]
# 10                  [948.0, 1012.0]                [(-2, -2, -2, -2)]
# 11                  [972.0, 1036.0]                 [(-2, -2, -3, 5)]
# 12  [980.0, 1044.0, 1076.0, 1092.0]                   [(2, 2, 2, -2)]
# 13                 [1124.0, 1148.0]                 [(-2, -2, 2, -2)]
#
#    Time_Entry_Intervals                                  Voices  \
# 0    [16.0, 16.0, 16.0]      [[Superius], Altus, Tenor, Bassus]
# 1    [16.0, 16.0, 16.0]      [[Superius], Altus, Tenor, Bassus]
# 2                [40.0]                         [Altus, Bassus]
# 3                [32.0]                     [[Superius], Tenor]
# 4      [4.0, 36.0, 4.0]      [[Superius], Altus, Tenor, Bassus]
# 5     [16.0, 8.0, 16.0]      [[Superius], Altus, Tenor, Bassus]
# 6                [24.0]                     [[Superius], Tenor]
# 7                [48.0]                          [Altus, Altus]
# 8                 [4.0]                     [[Superius], Tenor]
# 9    [24.0, 40.0, 24.0]  [[Superius], Tenor, [Superius], Tenor]
# 10               [64.0]                          [Altus, Altus]
# 11               [64.0]                        [Bassus, Bassus]
# 12   [64.0, 32.0, 16.0]       [Altus, Altus, [Superius], Tenor]
# 13               [24.0]                     [[Superius], Tenor]
#
#    Presentation_Type  Number_Entries  Flexed_Entries  Parallel_Entries  \
# 0                PEN               4           False               0.0
# 1                PEN               4           False               0.0
# 2               FUGA               2            True               0.0
# 3               FUGA               2           False               0.0
# 4                 ID               4           False               0.0
# 5                 ID               4           False               0.0
# 6               FUGA               2           False               0.0
# 7               FUGA               2           False               0.0
# 8               FUGA               2           False               0.0
# 9                 ID               4           False               0.0
# 10              FUGA               2           False               0.0
# 11              FUGA               2           False               0.0
# 12              FUGA               4           False               0.0
# 13              FUGA               2           False               0.0
#
#    Parallel_Voice  Count_Non_Overlaps
# 0            None                   0
# 1            None                   0
# 2            None                   0
# 3            None                   0
# 4            None                   0
# 5            None                   0
# 6            None                   0
# 7            None                   1
# 8            None                   0
# 9            None                   0
# 10           None                   1
# 11           None                   1
# 12           None                   2
# 13           None                   0

# %% [markdown]
# ### Split the Lists so We Avoid Long Gaps

# %%
# gets Progress!

temp = points.set_index("First_Offset")
temp2 = temp
piece.di(temp2, progress=True, beat=False, measure=False)
# Out:
#                   Composer      Title                        Measures_Beats  \
# Progress
# 0.000000  Josquin Des Prés  Ave Maria          [1/1.0, 3/1.0, 5/1.0, 7/1.0]
# 0.043478  Josquin Des Prés  Ave Maria       [8/1.0, 10/1.0, 12/1.0, 14/1.0]
# 0.136646  Josquin Des Prés  Ave Maria                      [23/1.0, 28/1.0]
# 0.189441  Josquin Des Prés  Ave Maria                      [31/3.0, 35/3.0]
# 0.332298  Josquin Des Prés  Ave Maria      [54/3.0, 55/1.0, 59/3.0, 60/1.0]
# 0.394410  Josquin Des Prés  Ave Maria      [64/3.0, 66/3.0, 67/3.0, 69/3.0]
# 0.478261  Josquin Des Prés  Ave Maria                      [78/1.0, 81/1.0]
# 0.580745  Josquin Des Prés  Ave Maria                      [94/1.0, 98/1.0]
# 0.618012  Josquin Des Prés  Ave Maria                      [98/1.0, 98/2.0]
# 0.732919  Josquin Des Prés  Ave Maria  [111/1.0, 114/1.0, 119/1.0, 122/1.0]
# 0.736025  Josquin Des Prés  Ave Maria                    [111/3.0, 119/3.0]
# 0.754658  Josquin Des Prés  Ave Maria                    [114/3.0, 122/3.0]
# 0.760870  Josquin Des Prés  Ave Maria  [115/3.0, 123/3.0, 127/3.0, 129/3.0]
# 0.872671  Josquin Des Prés  Ave Maria                    [133/3.0, 136/3.0]
#
#          Melodic_Entry_Intervals                          Offsets  \
# Progress
# 0.000000          [P-8, P1, P-8]          [0.0, 16.0, 32.0, 48.0]
# 0.043478          [P-8, P1, P-8]        [56.0, 72.0, 88.0, 104.0]
# 0.136646                   [P-8]                   [176.0, 216.0]
# 0.189441                   [P-8]                   [244.0, 276.0]
# 0.332298         [P-5, P-4, P-5]     [428.0, 432.0, 468.0, 472.0]
# 0.394410         [P-5, P-4, P-5]     [508.0, 524.0, 532.0, 548.0]
# 0.478261                   [P-8]                   [616.0, 640.0]
# 0.580745                    [P1]                   [748.0, 796.0]
# 0.618012                   [P-5]                   [796.0, 800.0]
# 0.732919          [P-8, P8, P-8]   [944.0, 968.0, 1008.0, 1032.0]
# 0.736025                    [P1]                  [948.0, 1012.0]
# 0.754658                    [P1]                  [972.0, 1036.0]
# 0.760870           [P1, m7, P-8]  [980.0, 1044.0, 1076.0, 1092.0]
# 0.872671                   [P-8]                 [1124.0, 1148.0]
#
#                                   Soggetti Time_Entry_Intervals  \
# Progress
# 0.000000                   [(4, 2, 2, -3)]   [16.0, 16.0, 16.0]
# 0.043478                 [(-2, -2, -2, 2)]   [16.0, 16.0, 16.0]
# 0.136646  [(-3, -2, 2, 2), (-2, -2, 2, 2)]               [40.0]
# 0.189441                   [(2, 2, 2, -2)]               [32.0]
# 0.332298                   [(4, -2, 2, 2)]     [4.0, 36.0, 4.0]
# 0.394410                  [(2, -3, 2, -3)]    [16.0, 8.0, 16.0]
# 0.478261                  [(2, -3, 2, -2)]               [24.0]
# 0.580745                 [(2, -2, -2, -2)]               [48.0]
# 0.618012                   [(2, 2, -3, 4)]                [4.0]
# 0.732919                 [(2, -2, -2, -2)]   [24.0, 40.0, 24.0]
# 0.736025                [(-2, -2, -2, -2)]               [64.0]
# 0.754658                 [(-2, -2, -3, 5)]               [64.0]
# 0.760870                   [(2, 2, 2, -2)]   [64.0, 32.0, 16.0]
# 0.872671                 [(-2, -2, 2, -2)]               [24.0]
#
#                                           Voices Presentation_Type  \
# Progress
# 0.000000      [[Superius], Altus, Tenor, Bassus]               PEN
# 0.043478      [[Superius], Altus, Tenor, Bassus]               PEN
# 0.136646                         [Altus, Bassus]              FUGA
# 0.189441                     [[Superius], Tenor]              FUGA
# 0.332298      [[Superius], Altus, Tenor, Bassus]                ID
# 0.394410      [[Superius], Altus, Tenor, Bassus]                ID
# 0.478261                     [[Superius], Tenor]              FUGA
# 0.580745                          [Altus, Altus]              FUGA
# 0.618012                     [[Superius], Tenor]              FUGA
# 0.732919  [[Superius], Tenor, [Superius], Tenor]                ID
# 0.736025                          [Altus, Altus]              FUGA
# 0.754658                        [Bassus, Bassus]              FUGA
# 0.760870       [Altus, Altus, [Superius], Tenor]              FUGA
# 0.872671                     [[Superius], Tenor]              FUGA
#
#           Number_Entries  Flexed_Entries  Parallel_Entries Parallel_Voice  \
# Progress
# 0.000000               4           False               0.0           None
# 0.043478               4           False               0.0           None
# 0.136646               2            True               0.0           None
# 0.189441               2           False               0.0           None
# 0.332298               4           False               0.0           None
# 0.394410               4           False               0.0           None
# 0.478261               2           False               0.0           None
# 0.580745               2           False               0.0           None
# 0.618012               2           False               0.0           None
# 0.732919               4           False               0.0           None
# 0.736025               2           False               0.0           None
# 0.754658               2           False               0.0           None
# 0.760870               4           False               0.0           None
# 0.872671               2           False               0.0           None
#
#           Count_Non_Overlaps
# Progress
# 0.000000                   0
# 0.043478                   0
# 0.136646                   0
# 0.189441                   0
# 0.332298                   0
# 0.394410                   0
# 0.478261                   0
# 0.580745                   1
# 0.618012                   0
# 0.732919                   0
# 0.736025                   1
# 0.754658                   1
# 0.760870                   2
# 0.872671                   0
