# %%
# python imports
from crim_intervals import * 
from crim_intervals import importScore 
from crim_intervals import main_objs
from IPython.display import SVG
from ipywidgets import interact
import altair as alt
import glob as glob
import crim_intervals
import crim_intervals.visualizations as viz
import numpy as np
import os
import pandas as pd
import re
import requests

MYDIR = ("saved_csv")
CHECK_FOLDER = os.path.isdir(MYDIR)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MYDIR)
    print("created folder : ", MYDIR)

else:
    print(MYDIR, "folder already exists.")
    
MUSDIR = ("Music_Files")
CHECK_FOLDER = os.path.isdir(MUSDIR)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MUSDIR)
    print("created folder : ", MUSDIR)

else:
    print(MUSDIR, "folder already exists.")
# Out:
# created folder :  saved_csv
# created folder :  Music_Files

# %%
path = 'https://crimproject.org/mei/CRIM_Model_0008.mei'

# %%
search_tuple = ('4', '1', '2')

# %%
piece = importScore(path)
pt=piece.presentationTypes(melodic_ngram_length=3,
                          limit_to_entries=True,
                          include_hidden_types=True)
# pt['Soggetti'] = pt['Soggetti'].apply(lambda x: str(x[0]) if x else '')
pt['first_tuple'] = pt['Soggetti'].apply(lambda x: x[0] if x else None)
# Example: Searching for the tuple ('A', 'B')


# Filter the DataFrame
filtered_df = pt[pt['Soggetti'].apply(lambda x: search_tuple in x)]
filtered_df
if 'PEN' in pt['Presentation_Type'].values:

# filter for a given type
    # pt = pt.loc[pt['Presentation_Type'] == 'PEN']
    piece.linkExamples(df=filtered_df, piece_url=path)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Composer</th>
#       <th>Title</th>
#       <th>First_Offset</th>
#       <th>Measures_Beats</th>
#       <th>Melodic_Entry_Intervals</th>
#       <th>Offsets</th>
#       <th>Soggetti</th>
#       <th>Time_Entry_Intervals</th>
#       <th>Voices</th>
#       <th>Presentation_Type</th>
#       <th>Number_Entries</th>
#       <th>Flexed_Entries</th>
#       <th>Parallel_Entries</th>
#       <th>Parallel_Voice</th>
#       <th>Progress</th>
#       <th>first_tuple</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Josquin Des Prés</td>
#       <td>Ave Maria</td>
#       <td>0.0</td>
#       <td>[1.0/1.0, 3.0/1.0, 5.0/1.0, 7.0/1.0]</td>
#       <td>[P-8, P1, P-8]</td>
#       <td>[0.0, 16.0, 32.0, 48.0]</td>
#       <td>[(4, 1, 2)]</td>
#       <td>[16.0, 16.0, 16.0]</td>
#       <td>[[Superius], Altus, Tenor, Bassus]</td>
#       <td><a href="https://eleon024.github.io/ema_react_app/?pieceURL=https%3A%2F%2Fcrimproject.org%2Fmei%2FCRIM_Model_0008.mei&ema_expression=%2F1%2C2%2C3%2C4%2C5%2C6%2C7%2C8%2F1%2C1%2C2%2C2%2C3%2C3%2C4%2C4%2F%40all%2C%401-3.0%2C%40all%2C%401-3.0%2C%40all%2C%401-3.0%2C%40all%2C%401-3.0%2Fhighlight&measure_range=1-8&observation=+PEN" rel="noopener noreferrer" target="_blank">PEN</a></td>
#       <td>4</td>
#       <td>False</td>
#       <td>False</td>
#       <td>None</td>
#       <td>0.000000</td>
#       <td>(4, 1, 2)</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Josquin Des Prés</td>
#       <td>Ave Maria</td>
#       <td>0.0</td>
#       <td>[1.0/1.0, 3.0/1.0, 5.0/1.0]</td>
#       <td>[P-8, P1]</td>
#       <td>[0.0, 16.0, 32.0]</td>
#       <td>[(4, 1, 2)]</td>
#       <td>[16.0, 16.0]</td>
#       <td>[[Superius], Altus, Tenor]</td>
#       <td><a href="https://eleon024.github.io/ema_react_app/?pieceURL=https%3A%2F%2Fcrimproject.org%2Fmei%2FCRIM_Model_0008.mei&ema_expression=%2F1%2C2%2C3%2C4%2C5%2C6%2F1%2C1%2C2%2C2%2C3%2C3%2F%40all%2C%401-3.0%2C%40all%2C%401-3.0%2C%40all%2C%401-3.0%2Fhighlight&measure_range=1-6&observation=+PEN" rel="noopener noreferrer" target="_blank">PEN</a></td>
#       <td>3</td>
#       <td>False</td>
#       <td>False</td>
#       <td>None</td>
#       <td>0.000000</td>
#       <td>(4, 1, 2)</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Josquin Des Prés</td>
#       <td>Ave Maria</td>
#       <td>0.0</td>
#       <td>[1.0/1.0, 3.0/1.0, 7.0/1.0]</td>
#       <td>[P-8, P-8]</td>
#       <td>[0.0, 16.0, 48.0]</td>
#       <td>[(4, 1, 2)]</td>
#       <td>[16.0, 32.0]</td>
#       <td>[[Superius], Altus, Bassus]</td>
#       <td><a href="https://eleon024.github.io/ema_react_app/?pieceURL=https%3A%2F%2Fcrimproject.org%2Fmei%2FCRIM_Model_0008.mei&ema_expression=%2F1%2C2%2C3%2C4%2C7%2C8%2F1%2C1%2C2%2C2%2C4%2C4%2F%40all%2C%401-3.0%2C%40all%2C%401-3.0%2C%40all%2C%401-3.0%2Fhighlight&measure_range=1-8&observation=+FUGA" rel="noopener noreferrer" target="_blank">FUGA</a></td>
#       <td>3</td>
#       <td>False</td>
#       <td>False</td>
#       <td>None</td>
#       <td>0.000000</td>
#       <td>(4, 1, 2)</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Josquin Des Prés</td>
#       <td>Ave Maria</td>
#       <td>0.0</td>
#       <td>[1.0/1.0, 5.0/1.0, 7.0/1.0]</td>
#       <td>[P-8, P-8]</td>
#       <td>[0.0, 32.0, 48.0]</td>
#       <td>[(4, 1, 2)]</td>
#       <td>[32.0, 16.0]</td>
#       <td>[[Superius], Tenor, Bassus]</td>
#       <td><a href="https://eleon024.github.io/ema_react_app/?pieceURL=https%3A%2F%2Fcrimproject.org%2Fmei%2FCRIM_Model_0008.mei&ema_expression=%2F1%2C2%2C5%2C6%2C7%2C8%2F1%2C1%2C3%2C3%2C4%2C4%2F%40all%2C%401-3.0%2C%40all%2C%401-3.0%2C%40all%2C%401-3.0%2Fhighlight&measure_range=1-8&observation=+FUGA" rel="noopener noreferrer" target="_blank">FUGA</a></td>
#       <td>3</td>
#       <td>False</td>
#       <td>False</td>
#       <td>None</td>
#       <td>0.000000</td>
#       <td>(4, 1, 2)</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Josquin Des Prés</td>
#       <td>Ave Maria</td>
#       <td>16.0</td>
#       <td>[3.0/1.0, 5.0/1.0, 7.0/1.0]</td>
#       <td>[P1, P-8]</td>
#       <td>[16.0, 32.0, 48.0]</td>
#       <td>[(4, 1, 2)]</td>
#       <td>[16.0, 16.0]</td>
#       <td>[Altus, Tenor, Bassus]</td>
#       <td><a href="https://eleon024.github.io/ema_react_app/?pieceURL=https%3A%2F%2Fcrimproject.org%2Fmei%2FCRIM_Model_0008.mei&ema_expression=%2F3%2C4%2C5%2C6%2C7%2C8%2F2%2C2%2C3%2C3%2C4%2C4%2F%40all%2C%401-3.0%2C%40all%2C%401-3.0%2C%40all%2C%401-3.0%2Fhighlight&measure_range=3-8&observation=+PEN" rel="noopener noreferrer" target="_blank">PEN</a></td>
#       <td>3</td>
#       <td>False</td>
#       <td>False</td>
#       <td>None</td>
#       <td>0.012422</td>
#       <td>(4, 1, 2)</td>
#     </tr>
#   </tbody>
# </table>

# %%
pt['first_tuple'] = pt['Soggetti'].apply(lambda x: x[0] if x else None)
# Example: Searching for the tuple ('A', 'B')
search_tuple = ('4', '1', '2')

# Filter the DataFrame
filtered_df = pt[pt['Soggetti'].apply(lambda x: search_tuple in x)]
filtered_df
# Out:
#            Composer      Title  First_Offset  \
# 0  Josquin Des Prés  Ave Maria           0.0
#
#                          Measures_Beats Melodic_Entry_Intervals  \
# 0  [1.0/1.0, 3.0/1.0, 5.0/1.0, 7.0/1.0]          [P-8, P1, P-8]
#
#                    Offsets     Soggetti Time_Entry_Intervals  \
# 0  [0.0, 16.0, 32.0, 48.0]  [(4, 1, 2)]   [16.0, 16.0, 16.0]
#
#                                Voices Presentation_Type  Number_Entries  \
# 0  [[Superius], Altus, Tenor, Bassus]               PEN               4
#
#    Flexed_Entries  Parallel_Entries Parallel_Voice  Count_Non_Overlaps  \
# 0           False             False           None                   0
#
#    Progress first_tuple
# 0       0.0   (4, 1, 2)
