# %%
import intervals
from intervals import * 
from intervals import main_objs
import intervals.visualizations as viz
import pandas as pd
import re
import altair as alt 
from ipywidgets import interact
from pandas.io.json import json_normalize
from pyvis.network import Network
from IPython.display import display
import requests
import os

MYDIR = ("saved_csv")
CHECK_FOLDER = os.path.isdir(MYDIR)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MYDIR)
    print("created folder : ", MYDIR)

else:
    print(MYDIR, "folder already exists.")
# Out:
# saved_csv folder already exists.

# %% [markdown]
# ### Here is Batch for Melodic NGrams

# %%
corpus = CorpusBase(['https://crimproject.org/mei/CRIM_Mass_0014_3.mei',
                             'https://crimproject.org/mei/CRIM_Model_0009.mei'])
func1 = ImportedPiece.getMelodic
# NB: you would probably want to set metadata to False for most preliminary results
list_of_dfs = corpus.batch(func=func1, kwargs={'compound': True, 'end': False}, metadata=False)
func2 = ImportedPiece.getNgrams
list_of_melodic_ngrams = corpus.batch(func=func2, kwargs={'n': 5}, list_args={'df': list_of_dfs})
# Out:
# Downloading remote score...
# Successfully imported https://crimproject.org/mei/CRIM_Mass_0014_3.mei
# Downloading remote score...
# Successfully imported https://crimproject.org/mei/CRIM_Model_0009.mei

# %%
list_of_melodic_ngrams

# %% [markdown]
# ### Here is Batch for Cadences

# %%
corpus = CorpusBase(['https://crimproject.org/mei/CRIM_Mass_0014_3.mei',
                             'https://crimproject.org/mei/CRIM_Model_0009.mei'])
func1 = ImportedPiece.getMelodic
# NB: you would probably want to set metadata to False for most preliminary results
list_of_dfs = corpus.batch(func=func1, kwargs={'compound': True, 'end': False}, metadata=False)
func2 = ImportedPiece.classifyCadences
list_of_cadences = corpus.batch(func=func2)
# Out:
# Memoized piece detected.
# Memoized piece detected.

# %%
list_of_cadences
# Out:
# [              CadType Evaded  LeadingTones  Low RelLow  Tone RelTone  Measure  \
#  168.0   Clausula Vera  False           0.0   G3     P1     G      P1       22
#  232.0   Clausula Vera  False           0.0   D3    -P4     D     -P4       30
#  304.0   Clausula Vera  False           0.0   G3     P1     G      P1       39
#  400.0        Phrygian  False           1.0   D3    -P4     A      M2       51
#  440.0        Phrygian  False           1.0   A3     M2     A      M2       56
#  472.0   Clausula Vera  False           0.0   D3    -P4     D     -P4       60
#  480.0        Phrygian  False           1.0   G3     P1     A      M2       61
#  484.0   Clausula Vera   True           1.0   G3     P1     G      P1       61
#  492.0   Clausula Vera  False           0.0   G3     P1     G      P1       62
#  500.0   Clausula Vera  False           0.0   C4     P4     D     -P4       63
#  504.0   Clausula Vera   True           1.0   C4     P4     C     -P5       64
#  520.0             NaN    NaN           NaN  B-3     m3     D     -P4       66
#  536.0   Clausula Vera  False           0.0   D3    -P4     D     -P4       68
#  560.0       Authentic  False           0.0   G3     P1     G      P1       71
#  636.0   Clausula Vera  False           0.0   D4     P5     D     -P4       80
#  700.0   Clausula Vera  False           1.0   D3    -P4     D     -P4       88
#  768.0   Clausula Vera  False           0.0   G3     P1     G      P1       97
#  792.0       Authentic  False           0.0   G3     P1     G      P1      100
#  900.0       Authentic  False           1.0   G3     P1     G      P1      112
#  988.0   Clausula Vera  False           0.0   D3    -P4     D     -P4      122
#  1028.0  Clausula Vera  False           1.0  B-2    -M6    B-      m3      127
#  1076.0  Clausula Vera  False           0.0   D3    -P4     D     -P4      133
#  1124.0  Clausula Vera  False           0.0   G4     P8     G      P1      138
#  1160.0      Authentic   True           0.0   E4     M6     C     -P5      142
#  1188.0  Clausula Vera   True          -1.0   D5    P12  None     NaN      146
#  1220.0  Clausula Vera  False           1.0  B-3     m3    B-      m3      150
#  1248.0  Clausula Vera  False           0.0   G4     P8     G      P1      153
#  1276.0       Phrygian  False           1.0   A3     M2     A      M2      157
#  1328.0  Clausula Vera  False           0.0   D3    -P4     D     -P4      163
#  1332.0      Authentic  False           0.0   G3     P1     G      P1      164
#  1404.0  Clausula Vera  False           1.0  B-3     m3    B-      m3      173
#  1456.0  Clausula Vera  False           0.0   D3    -P4     D     -P4      179
#  1492.0  Clausula Vera  False           1.0  B-2    -M6    B-      m3      184
#  1572.0  Clausula Vera  False           0.0   D3    -P4     D     -P4      194
#  1664.0  Clausula Vera   True           1.0   C4     P4     E     -m3      204
#  1700.0         Plagal  False           1.0   D3    -P4     A      M2      209
#  1748.0  Clausula Vera  False           0.0   D3    -P4     D     -P4      215
#  1764.0  Clausula Vera  False           0.0   D3    -P4     D     -P4      217
#  1772.0       Phrygian  False           1.0   G3     P1     A      M2      218
#  1776.0  Clausula Vera   True           1.0   G3     P1     G      P1      218
#  1784.0  Clausula Vera  False           0.0   G3     P1     G      P1      219
#  1804.0  Clausula Vera  False           0.0   D3    -P4     D     -P4      222
#  1820.0  Clausula Vera  False           0.0   D3    -P4     D     -P4      224
#  1844.0  Clausula Vera  False           0.0   E3    -m3     G      P1      227
#  1864.0  Clausula Vera  False           0.0   D3    -P4     D     -P4      229
#  1884.0  Clausula Vera  False           0.0   G3     P1     G      P1      232
#  1900.0       Phrygian  False           1.0   A3     M2     A      M2      234
#  1916.0            NaN    NaN           NaN  B-3     m3     D     -P4      236
#  1988.0  Clausula Vera  False           0.0   G3     P1     G      P1      245
#  2068.0       Phrygian  False           1.0   F3    -M2     A      M2      255
#  2092.0         Plagal  False           1.0   D3    -P4     A      M2      258
#  2144.0  Clausula Vera  False           0.0   D3    -P4     D     -P4      264
#  2164.0      Authentic  False           0.0   D3    -P4     D     -P4      267
#  2220.0      Authentic  False           1.0   F3    -M2     F     -M2      274
#  2364.0      Authentic  False           0.0   G3     P1     G      P1      286
#
#          Beat  Progress  SinceLast  ToNext          Composer  \
#  168.0    1.0  0.071066      168.0    64.0  Antoine de Févin
#  232.0    1.0  0.098139       64.0    72.0  Antoine de Févin
#  304.0    1.0  0.128596       72.0    96.0  Antoine de Févin
#  400.0    1.0  0.169205       96.0    40.0  Antoine de Févin
#  440.0    1.0  0.186125       40.0    32.0  Antoine de Févin
#  472.0    1.0  0.199662       32.0     8.0  Antoine de Févin
#  480.0    1.0  0.203046        8.0     4.0  Antoine de Févin
#  484.0    3.0  0.204738        4.0     8.0  Antoine de Févin
#  492.0    3.0  0.208122        8.0     8.0  Antoine de Févin
#  500.0    3.0  0.211506        8.0     4.0  Antoine de Févin
#  504.0    1.0  0.213198        4.0    16.0  Antoine de Févin
#  520.0    1.0  0.219966       16.0    16.0  Antoine de Févin
#  536.0    1.0  0.226734       16.0    24.0  Antoine de Févin
#  560.0    1.0  0.236887       24.0    76.0  Antoine de Févin
#  636.0    3.0  0.269036       76.0    64.0  Antoine de Févin
#  700.0    3.0  0.296108       64.0    68.0  Antoine de Févin
#  768.0    1.0  0.324873       68.0    24.0  Antoine de Févin
#  792.0    1.0  0.335025       24.0   108.0  Antoine de Févin
#  900.0    1.0  0.380711      108.0    88.0  Antoine de Févin
#  988.0    1.0  0.417936       88.0    40.0  Antoine de Févin
#  1028.0   1.0  0.434856       40.0    48.0  Antoine de Févin
#  1076.0   1.0  0.455161       48.0    48.0  Antoine de Févin
#  1124.0   1.0  0.475465       48.0    36.0  Antoine de Févin
#  1160.0   3.0  0.490694       36.0    28.0  Antoine de Févin
#  1188.0   1.0  0.502538       28.0    32.0  Antoine de Févin
#  1220.0   1.0  0.516074       32.0    28.0  Antoine de Févin
#  1248.0   3.0  0.527919       28.0    28.0  Antoine de Févin
#  1276.0   1.0  0.539763       28.0    52.0  Antoine de Févin
#  1328.0   3.0  0.561760       52.0     4.0  Antoine de Févin
#  1332.0   1.0  0.563452        4.0    72.0  Antoine de Févin
#  1404.0   1.0  0.593909       72.0    52.0  Antoine de Févin
#  1456.0   3.0  0.615905       52.0    36.0  Antoine de Févin
#  1492.0   1.0  0.631134       36.0    80.0  Antoine de Févin
#  1572.0   1.0  0.664975       80.0    92.0  Antoine de Févin
#  1664.0   3.0  0.703892       92.0    36.0  Antoine de Févin
#  1700.0   1.0  0.719120       36.0    48.0  Antoine de Févin
#  1748.0   1.0  0.739425       48.0    16.0  Antoine de Févin
#  1764.0   1.0  0.746193       16.0     8.0  Antoine de Févin
#  1772.0   1.0  0.749577        8.0     4.0  Antoine de Févin
#  1776.0   3.0  0.751269        4.0     8.0  Antoine de Févin
#  1784.0   3.0  0.754653        8.0    20.0  Antoine de Févin
#  1804.0   1.0  0.763113       20.0    16.0  Antoine de Févin
#  1820.0   1.0  0.769882       16.0    24.0  Antoine de Févin
#  1844.0   1.0  0.780034       24.0    20.0  Antoine de Févin
#  1864.0   3.0  0.788494       20.0    20.0  Antoine de Févin
#  1884.0   1.0  0.796954       20.0    16.0  Antoine de Févin
#  1900.0   1.0  0.803723       16.0    16.0  Antoine de Févin
#  1916.0   1.0  0.810491       16.0    72.0  Antoine de Févin
#  1988.0   1.0  0.840948       72.0    80.0  Antoine de Févin
#  2068.0   1.0  0.874788       80.0    24.0  Antoine de Févin
#  2092.0   1.0  0.884941       24.0    52.0  Antoine de Févin
#  2144.0   3.0  0.906937       52.0    20.0  Antoine de Févin
#  2164.0   1.0  0.915398       20.0    56.0  Antoine de Févin
#  2220.0   1.0  0.939086       56.0   144.0  Antoine de Févin
#  2364.0   1.0  1.000000      144.0    16.0  Antoine de Févin
#
#                             Title
#  168.0   Missa Mente tota:  Credo
#  232.0   Missa Mente tota:  Credo
#  304.0   Missa Mente tota:  Credo
#  400.0   Missa Mente tota:  Credo
#  440.0   Missa Mente tota:  Credo
#  472.0   Missa Mente tota:  Credo
#  480.0   Missa Mente tota:  Credo
#  484.0   Missa Mente tota:  Credo
#  492.0   Missa Mente tota:  Credo
#  500.0   Missa Mente tota:  Credo
#  504.0   Missa Mente tota:  Credo
#  520.0   Missa Mente tota:  Credo
#  536.0   Missa Mente tota:  Credo
#  560.0   Missa Mente tota:  Credo
#  636.0   Missa Mente tota:  Credo
#  700.0   Missa Mente tota:  Credo
#  768.0   Missa Mente tota:  Credo
#  792.0   Missa Mente tota:  Credo
#  900.0   Missa Mente tota:  Credo
#  988.0   Missa Mente tota:  Credo
#  1028.0  Missa Mente tota:  Credo
#  1076.0  Missa Mente tota:  Credo
#  1124.0  Missa Mente tota:  Credo
#  1160.0  Missa Mente tota:  Credo
#  1188.0  Missa Mente tota:  Credo
#  1220.0  Missa Mente tota:  Credo
#  1248.0  Missa Mente tota:  Credo
#  1276.0  Missa Mente tota:  Credo
#  1328.0  Missa Mente tota:  Credo
#  1332.0  Missa Mente tota:  Credo
#  1404.0  Missa Mente tota:  Credo
#  1456.0  Missa Mente tota:  Credo
#  1492.0  Missa Mente tota:  Credo
#  1572.0  Missa Mente tota:  Credo
#  1664.0  Missa Mente tota:  Credo
#  1700.0  Missa Mente tota:  Credo
#  1748.0  Missa Mente tota:  Credo
#  1764.0  Missa Mente tota:  Credo
#  1772.0  Missa Mente tota:  Credo
#  1776.0  Missa Mente tota:  Credo
#  1784.0  Missa Mente tota:  Credo
#  1804.0  Missa Mente tota:  Credo
#  1820.0  Missa Mente tota:  Credo
#  1844.0  Missa Mente tota:  Credo
#  1864.0  Missa Mente tota:  Credo
#  1884.0  Missa Mente tota:  Credo
#  1900.0  Missa Mente tota:  Credo
#  1916.0  Missa Mente tota:  Credo
#  1988.0  Missa Mente tota:  Credo
#  2068.0  Missa Mente tota:  Credo
#  2092.0  Missa Mente tota:  Credo
#  2144.0  Missa Mente tota:  Credo
#  2164.0  Missa Mente tota:  Credo
#  2220.0  Missa Mente tota:  Credo
#  2364.0  Missa Mente tota:  Credo  ,
#               CadType  Evaded  LeadingTones Low RelLow Tone RelTone  Measure  \
#  48.0   Clausula Vera   False             0  D3    -m3    D     -m3        7
#  64.0       Authentic   False             0  D3    -m3    D     -m3        9
#  112.0  Clausula Vera   False             0  D3    -m3    D     -m3       15
#  128.0  Clausula Vera   False             0  D3    -m3    D     -m3       17
#  160.0      Authentic   False             1  F3     P1    F      P1       21
#  184.0      Authentic   False             1  C3    -P4    C     -P4       24
#  212.0  Clausula Vera   False             1  F3     P1    F      P1       27
#
#         Beat  Progress  SinceLast  ToNext       Composer               Title
#  48.0    1.0  0.195122       48.0    16.0  Pierre Cadéac  Je suis déshéritée
#  64.0    1.0  0.260163       16.0    48.0  Pierre Cadéac  Je suis déshéritée
#  112.0   1.0  0.455285       48.0    16.0  Pierre Cadéac  Je suis déshéritée
#  128.0   1.0  0.520325       16.0    32.0  Pierre Cadéac  Je suis déshéritée
#  160.0   1.0  0.650407       32.0    24.0  Pierre Cadéac  Je suis déshéritée
#  184.0   1.0  0.747967       24.0    28.0  Pierre Cadéac  Je suis déshéritée
#  212.0   3.0  0.861789       28.0    36.0  Pierre Cadéac  Je suis déshéritée  ]
