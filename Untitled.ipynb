# %%
import verovio

# %%
tk = verovio.toolkit()
tk.loadFile("Music_Files/CRIM_Mass_0007_4.mei")
tk.getPageCount()
svg = tk.renderToSVG()
svg
# Out:
# [Warning] Unsupported '<line>' within <measure>
# [Warning] Unsupported '<line>' within <measure>
# ...

# %%
tk = verovio.toolkit()
tk.select("{ 'measureRange': '2-3' }")
tk.loadFile('Music_Files/CRIM_Mass_0007_4.mei')
tk.renderToSVG()
tk.renderToSVGFile( "page-scaled.svg", 2 )
a = tk.renderToSVGFile( "page.svg", 3 )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/k5/k4j_550s2yq5776vgmw6r_xr0000gp/T/ipykernel_34539/120327358.py in <module>
#       1 tk = verovio.toolkit()
# ----> 2 tk.select("{ 'measureRange': '2-3' }")
#       3 tk.loadFile('Music_Files/CRIM_Mass_0007_4.mei')
#       4 tk.renderToSVG()
#       5 tk.renderToSVGFile( "page-scaled.svg", 2 )
#
# AttributeError: 'toolkit' object has no attribute 'select'

# %%
from IPython.display import SVG
SVG(filename='page-scaled.svg')

# %%
# import EmaMei from '../src/EmaMei'
import EmaMeiProcessor from '../src/EmaMeiProcessor'

const fullExpr = `/https%3A%2F%2Fraw.githubusercontent.com%2Fmusic-encoding%2Fsample-encodings%2Fmaster%2FMEI_4.0%2FMusic%2FComplete_examples%2FBach_Musikalisches_Opfer_Trio.mei/all/all/@all`

const emaMei: EmaMeiProcessor = await EmaMei.withFullExpr(fullExpr)

// The result:
const addressedSelection = emaMei.getSelection()
# Out:
#   File "<ipython-input-2-aa6f2f0a923b>", line 1
#     import EmaMei from '../src/EmaMei'
#                   ^
# SyntaxError: invalid syntax

# %%
tk.setOption( "pageHeight", "2100" )
tk.setOption( "pageWidth", "2900" )
tk.setScale(25)
tk.redoLayout()
tk.renderToSVGFile( "page-scaled.svg", 2 )
# Out:
# True

# %%
a = tk.renderToSVGFile( "page.svg", 3 )

# %%
result = tk.renderToMIDI( "sample.midi" )
result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/k5/k4j_550s2yq5776vgmw6r_xr0000gp/T/ipykernel_74566/2802095166.py in <module>
# ----> 1 result = tk.renderToMIDI( "sample.midi" )
#       2 result
#
# TypeError: renderToMIDI() takes 1 positional argument but 2 were given

# %%
from IPython.display import SVG
SVG(filename='page-scaled.svg')
