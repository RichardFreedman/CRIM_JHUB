# %% [markdown]
# # CRIM Intervals:  Presentation Types
#
# ### Note:  Still Under Development!:
#
# #### Import Music Files
#
# * If you are exploring pieces from CRIM, importing simply involves providing the CRIM URL of the MEI file:
#     * **`piece = importScore('https://crimproject.org/mei/CRIM_Model_0008.mei')`**
#
# * But you can also use the Notebook with any MEI, MusicXML, or MIDI file of your own. You can easily do this when you run the Notebooks on Jupyter Hub, you will also find a folder called **`Music_Files`**.  Upload the file here, then provide the path to that file:
#     * **`piece = import_m21_score('Music_Files/My_File_Name.mei')`**.
#
# #### Save outputs as CSV or Excel
#
# * The Jupyter Hub version of these Notebooks also provides a folder called **`saved_csv`**.  You can save **csv** files of any data frame there with this command:
#     * **`notebook_data_frame_name.to_csv('saved_csv/your_file_title.csv')`**.
# * If you prefer **Excel** documents (which are better for anything with a complex set of columns or hierarhical index), use **ExcelWriter**.  In the following code, you will need to provide these commands:
#     * **`writer = pd.ExcelWriter('saved_csv/file_name.xlsx', engine='xlsxwriter')`**
# * Now convert your dataframe to Excel
#     * **`frame_name.to_excel(writer, sheet_name='Sheet1')`**
# * And finally save the new file to the folder here in the Notebook:
#     * **`writer.save()`**
#
# Put the following code to a new cell and update the frame_name and file_name:
#
# `writer = pd.ExcelWriter('saved_csv/file_name.xlsx', engine='xlsxwriter')` <br>
# `frame_name.to_excel(writer, sheet_name='Sheet1')` <br>
# `writer.save()` <br>

# %% [markdown]
# ## A. Import Intervals and Other Code
#
# * The first step is to import all the code required for the Notebook
# * **`arrow/run`** or **`Shift + Enter`** in the following cell:

# %%
import intervals
from intervals import * 
import intervals.visualizations as viz
import pandas as pd
import re
import altair as alt 
from ipywidgets import interact
from pandas.io.json import json_normalize
from pyvis.network import Network
from IPython.display import display
import requests
import os
import numpy

# You should change 'test' to your preferred folder.
MYDIR = ("saved_csv")
CHECK_FOLDER = os.path.isdir(MYDIR)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MYDIR)
    print("created folder : ", MYDIR)

else:
    print(MYDIR, "folder already exists.")
    
# New version to include in main_objs code
def find_entry_int_distance(coordinates, piece: intervals.main_objs.ImportedPiece):
    tone_list = []
    all_tones = piece.getNoteRest()
    
    for item in coordinates:
        filtered_tones = all_tones.loc[item] 
        tone_list.append(filtered_tones)
        
    noteObjects = [note.Note(tone) for tone in tone_list]
    _ints = [interval.Interval(noteObjects[i], noteObjects[i + 1]) for i in range(len(noteObjects) - 1)]
    entry_ints = []
    
    for _int in _ints:
        entry_ints.append(_int.directedName)
    
    return entry_ints
# Out:
# saved_csv folder already exists.

# %% [markdown]
# ## B. Importing a Piece and Run Imitation Classifier

# %%
piece = importScore('https://crimproject.org/mei/CRIM_Model_0008.mei')
points = piece.getPoints()
# Out:
# Downloading remote score...
# Successfully imported https://crimproject.org/mei/CRIM_Model_0008.mei
# Memoized piece detected.
# Finding close matches...
# 137 melodic intervals had more than 3 exact or close matches.
#    pattern_generating_match pattern_matched piece_title        part  \
# 0              (4, 1, 2, 2)    (4, 1, 2, 2)   Ave Maria  [Superius]
# 5             (1, 2, 2, -3)   (1, 2, 2, -3)   Ave Maria  [Superius]
# 2              (4, 1, 2, 2)    (4, 1, 2, 2)   Ave Maria       Altus
# 13            (1, 2, 2, -3)   (1, 2, 2, -3)   Ave Maria       Altus
# 3              (4, 1, 2, 2)    (4, 1, 2, 2)   Ave Maria       Tenor
#
#     end_measure  end_beat  start_offset  end_offset  \
# 0             3       3.0           0.0        20.0
# 5             4       1.0           4.0        24.0
# 2             5       3.0          16.0        36.0
# 13            6       1.0          20.0        40.0
# 3             7       3.0          32.0        52.0
#
#                note_durations  \
# 0   (4.0, 8.0, 4.0, 4.0, 4.0)
# 5   (8.0, 4.0, 4.0, 4.0, 8.0)
# 2   (4.0, 8.0, 4.0, 4.0, 4.0)
# 13  (8.0, 4.0, 4.0, 4.0, 8.0)
# 3   (4.0, 8.0, 4.0, 4.0, 4.0)
#
#                                                 ema  \
# 0              1-3/1/@1.0-end,@start-end,@start-3.0
# 5   1-4/1/@3.0-end,@start-end,@start-end,@start-1.0
# 2              3-5/2/@1.0-end,@start-end,@start-3.0
# 13  3-6/2/@3.0-end,@start-end,@start-end,@start-1.0
# 3              5-7/3/@1.0-end,@start-end,@start-3.0
#
#                                               ema_url  sum_durs  group_number  \
# 0   https://ema.crimproject.org/https%3A%2F%2Fcrim...      24.0           142
# 5   https://ema.crimproject.org/https%3A%2F%2Fcrim...      28.0            87
# 2   https://ema.crimproject.org/https%3A%2F%2Fcrim...      24.0           142
# 13  https://ema.crimproject.org/https%3A%2F%2Fcrim...      28.0            87
# 3   https://ema.crimproject.org/https%3A%2F%2Fcrim...      24.0           142
#
#     prev_entry_off  next_entry_off  is_first  is_last  last_off_diff  \
# 0            472.0            16.0      True    False          472.0
# 5            804.0             4.0      True    False          800.0
# 2              0.0            32.0     False    False           16.0
# 13             4.0            20.0     False    False           16.0
# 3             16.0            48.0     False    False           16.0
#
#     next_off_diff  parallel  forward_gapped  back_gapped  singleton  \
# 0            16.0     False           False        False      False
# 5             0.0     False           False        False      False
# 2            16.0     False           False        False      False
# 13            0.0     False           False        False      False
# 3            16.0     False           False        False      False
#
#     split_group  combined_group  sub_group_id predicted_type  entry_number  \
# 0         False            True         293.0            PEN             1
# 5         False            True         188.0            PEN             1
# 2         False           False         293.0            PEN             2
# 13        False           False         188.0            PEN             2
# 3         False           False         293.0            PEN             3
#
#     start
# 0   1/1.0
# 5   1/3.0
# 2   3/1.0
# 13  3/3.0
# 3   5/1.0

# %% [markdown]
# #### B.2 Finding Time and Entry Interval Details
#
# *  This is temporary code, but please run it.

# %%
df3 = points

# make lists of voices and offsets and put them in dfs to be merged

voice_groups = df3.groupby('sub_group_id')['part'].apply(list)
voice_groups_df = voice_groups.reset_index(name = 'voice_list')

offset_groups = df3.groupby('sub_group_id')['start_offset'].apply(list)
offset_groups_df = offset_groups.reset_index(name = 'offset_list')

meas_beat_groups = df3.groupby('sub_group_id')['start'].apply(list)
meas_beat_groups_df = meas_beat_groups.reset_index(name = 'measure_beat_list')


# keep just the first entry in each point
df3 = df3[df3["entry_number"] == 1]

# merge the dfs of offsets and voices into the main list of points
# zip the lists of offsets and voices together as tuples
# find the offset = time intervals

df5 = pd.merge(df3, voice_groups_df,
how='inner', on='sub_group_id')

df6 = pd.merge(df5, offset_groups_df,
how='inner', on='sub_group_id')

df7 =  pd.merge(df6, meas_beat_groups_df,
how='inner', on='sub_group_id')

df7["time_intervals"] = df7['offset_list'].apply(lambda x: numpy.diff(x))

df8 = df7[["piece_title", "pattern_matched", "predicted_type", "measure_beat_list", "offset_list", "time_intervals", "voice_list"]].copy()

df8['tone_coordinates'] = df8.apply(lambda row: list(zip(row.offset_list, row.voice_list)), axis='columns')

#  apply the function to find the entry intervals
# remove cols no long needed

df8['entry_intervals'] = df8['tone_coordinates'].apply(lambda x: find_entry_int_distance(x, piece))
df8.drop(columns=['offset_list', 'tone_coordinates'])
# Out:
#     piece_title   pattern_matched predicted_type  \
# 0     Ave Maria      (4, 1, 2, 2)            PEN
# 1     Ave Maria     (1, 2, 2, -3)            PEN
# 2     Ave Maria   (-2, -2, -2, 2)            PEN
# 3     Ave Maria   (-2, -2, 2, -2)            PEN
# 4     Ave Maria    (2, -2, 4, -2)            PEN
# 5     Ave Maria   (-2, 4, -2, -2)            PEN
# 6     Ave Maria    (4, -2, -2, 2)           Fuga
# 7     Ave Maria    (-2, -2, 2, 2)           Fuga
# 8     Ave Maria      (1, 1, 2, 2)            PEN
# 9     Ave Maria     (1, 2, 2, -3)            PEN
# 10    Ave Maria  (-2, -2, -2, -2)             ID
# 11    Ave Maria     (-2, 2, 2, 2)           Fuga
# 12    Ave Maria      (2, 2, 2, 2)           Fuga
# 13    Ave Maria     (2, 2, 2, -2)           Fuga
# 14    Ave Maria   (-2, -2, -2, 2)           Fuga
# 15    Ave Maria    (-2, -2, 2, 2)           Fuga
# 16    Ave Maria      (1, 2, 2, 1)           Fuga
# 17    Ave Maria      (2, 2, 1, 2)           Fuga
# 18    Ave Maria     (2, 1, 2, -2)           Fuga
# 19    Ave Maria     (1, 2, -2, 1)           Fuga
# 20    Ave Maria    (1, 2, -2, -2)            PEN
# 21    Ave Maria   (2, -2, -2, -2)            PEN
# 22    Ave Maria    (2, -2, 1, -2)           Fuga
# 23    Ave Maria    (-2, 1, -2, 2)           Fuga
# 24    Ave Maria     (2, 2, 2, -3)           Fuga
# 25    Ave Maria     (-3, 2, 2, 2)           Fuga
# 26    Ave Maria     (2, 2, -3, 2)             ID
# 27    Ave Maria     (2, -3, 2, 2)             ID
# 28    Ave Maria     (2, 2, 2, -5)           Fuga
# 29    Ave Maria     (2, 2, 2, -2)           Fuga
# 30    Ave Maria     (2, 2, -2, 2)           Fuga
# 31    Ave Maria    (2, -2, 2, -3)             ID
# 32    Ave Maria    (-2, 2, -3, 2)             ID
# 33    Ave Maria    (-3, 2, -2, 2)           Fuga
# 34    Ave Maria    (2, 2, -3, -2)           Fuga
# 35    Ave Maria   (-2, -2, -2, 2)           Fuga
# 36    Ave Maria     (4, -2, 2, 2)             ID
# 37    Ave Maria    (-2, 2, 2, -3)             ID
# 38    Ave Maria   (2, -3, -2, -2)             ID
# 39    Ave Maria   (-3, -2, -2, 1)             ID
# 40    Ave Maria    (2, -3, 2, -3)           Fuga
# 41    Ave Maria    (-3, 2, -3, 2)           Fuga
# 42    Ave Maria    (2, -3, 2, -2)             ID
# 43    Ave Maria   (-3, 2, -2, -2)             ID
# 44    Ave Maria   (2, -2, -2, -2)             ID
# 45    Ave Maria     (2, -3, 1, 2)           Fuga
# 46    Ave Maria    (-3, 1, 2, -3)           Fuga
# 47    Ave Maria     (1, 2, -3, 1)           Fuga
# 48    Ave Maria    (-2, 1, -2, 2)           Fuga
# 49    Ave Maria     (1, 1, 2, -3)           Fuga
# 50    Ave Maria      (1, 5, 1, 2)           Fuga
# 51    Ave Maria     (1, 2, -3, 2)           Fuga
# 52    Ave Maria    (2, -3, 2, -2)           Fuga
# 53    Ave Maria   (-3, 2, -2, -2)           Fuga
# 54    Ave Maria     (1, 2, -2, 1)           Fuga
# 55    Ave Maria   (2, -2, -2, -2)           Fuga
# 56    Ave Maria    (2, -2, 1, -2)           Fuga
# 57    Ave Maria  (-2, -2, -2, -2)           Fuga
# 58    Ave Maria   (5, -2, -2, -2)           Fuga
# 59    Ave Maria   (-2, 3, -2, -2)           Fuga
# 60    Ave Maria   (-2, -2, -2, 2)           Fuga
# 61    Ave Maria   (2, -2, -2, -2)           Fuga
# 62    Ave Maria      (1, 1, 2, 1)           Fuga
# 63    Ave Maria      (1, 2, 1, 2)           Fuga
# 64    Ave Maria      (2, 1, 2, 1)           Fuga
# 65    Ave Maria      (1, 1, 2, 1)           Fuga
# 66    Ave Maria      (1, 2, 1, 2)           Fuga
# 67    Ave Maria      (2, 1, 2, 1)           Fuga
# 68    Ave Maria     (2, 1, -3, 1)           Fuga
# 69    Ave Maria     (-3, 1, 4, 1)           Fuga
# 70    Ave Maria     (1, -3, 1, 4)           Fuga
# 71    Ave Maria    (1, 4, -2, -2)           Fuga
# 72    Ave Maria   (4, -2, -2, -2)           Fuga
# 73    Ave Maria  (-2, -2, -2, -2)           Fuga
# 74    Ave Maria   (-2, -2, -2, 1)           Fuga
# 75    Ave Maria    (-2, -2, 1, 4)           Fuga
# 76    Ave Maria     (-2, 1, 4, 1)           Fuga
# 77    Ave Maria      (1, 4, 1, 2)           Fuga
# 78    Ave Maria     (1, 2, -3, 2)           Fuga
# 79    Ave Maria    (2, -3, 2, -3)           Fuga
# 80    Ave Maria     (1, 1, 2, -2)           Fuga
# 81    Ave Maria  (-2, -2, -2, -2)           Fuga
# 82    Ave Maria    (1, 2, -2, -2)             ID
# 83    Ave Maria   (2, -2, -2, -2)             ID
# 84    Ave Maria   (-2, -2, -2, 1)           Fuga
# 85    Ave Maria    (-2, -2, 1, 3)           Fuga
# 86    Ave Maria    (-2, 1, 3, -2)           Fuga
# 87    Ave Maria    (1, 3, -2, -2)           Fuga
# 88    Ave Maria   (3, -2, -2, -2)           Fuga
# 89    Ave Maria     (1, 1, 2, -2)           Fuga
# 90    Ave Maria   (-2, -2, -2, 1)           Fuga
# 91    Ave Maria    (-2, -2, 1, 3)           Fuga
# 92    Ave Maria    (-2, 1, 3, -2)           Fuga
# 93    Ave Maria    (1, 3, -2, -2)           Fuga
# 94    Ave Maria   (3, -2, -2, -2)           Fuga
# 95    Ave Maria     (2, 2, -2, 2)           Fuga
# 96    Ave Maria     (2, 2, 2, -2)           Fuga
# 97    Ave Maria     (2, -2, 2, 2)           Fuga
# 98    Ave Maria     (-2, 2, 2, 2)           Fuga
# 99    Ave Maria   (-2, -2, -2, 2)           Fuga
# 100   Ave Maria    (1, -2, -2, 2)           Fuga
# 101   Ave Maria   (-2, -2, 2, -2)           Fuga
# 102   Ave Maria   (-2, 2, -2, -2)           Fuga
# 103   Ave Maria    (2, -3, 2, -2)           Fuga
# 104   Ave Maria    (-2, 1, -2, 2)           Fuga
#
#                                      measure_beat_list  \
# 0                         [1/1.0, 3/1.0, 5/1.0, 7/1.0]
# 1                         [1/3.0, 3/3.0, 5/3.0, 7/3.0]
# 2                      [8/1.0, 10/1.0, 12/1.0, 14/1.0]
# 3                              [8/4.0, 10/4.0, 12/4.0]
# 4                              [9/3.0, 11/3.0, 13/3.0]
# 5                             [10/1.0, 12/1.0, 14/1.0]
# 6                             [10/2.0, 12/2.5, 14/2.0]
# 7                     [10/3.0, 12/3.0, 14/3.0, 14/4.0]
# 8                     [16/3.0, 18/3.0, 20/3.0, 22/3.0]
# 9                     [17/2.0, 19/2.0, 21/2.0, 23/2.0]
# 10                    [19/1.0, 19/2.5, 20/4.0, 21/1.5]
# 11                            [24/1.0, 28/1.5, 29/1.0]
# 12                                    [24/3.0, 25/1.0]
# 13                                    [25/2.5, 28/2.0]
# 14                                    [27/4.5, 28/4.0]
# 15                                    [28/1.0, 28/3.5]
# 16                                    [31/3.0, 35/3.0]
# 17                                    [32/1.0, 36/1.0]
# 18                                    [32/3.0, 36/3.0]
# 19                                    [33/1.0, 37/1.0]
# 20                            [33/1.0, 37/1.0, 41/1.0]
# 21                            [33/3.0, 37/3.0, 41/3.0]
# 22                            [33/3.0, 37/1.0, 37/3.0]
# 23                                    [33/4.0, 37/4.0]
# 24   [42/1.0, 44/3.0, 44/4.0, 46/2.0, 46/3.0, 46/4....
# 25    [44/1.0, 45/4.0, 46/1.0, 47/4.0, 48/1.0, 50/1.0]
# 26                    [44/4.0, 45/1.0, 46/4.0, 47/1.0]
# 27                    [45/2.0, 45/3.0, 47/2.0, 47/3.0]
# 28                                    [48/1.0, 50/2.0]
# 29                                    [48/3.0, 48/4.0]
# 30                                    [49/1.0, 49/2.0]
# 31                    [49/3.0, 49/4.0, 50/4.0, 51/1.0]
# 32                    [50/1.0, 50/2.0, 51/1.0, 51/2.0]
# 33                                    [50/3.0, 50/4.0]
# 34            [51/3.5, 55/4.0, 56/2.0, 60/4.0, 61/2.0]
# 35                                    [51/4.0, 53/2.0]
# 36                    [54/3.0, 55/1.0, 59/3.0, 60/1.0]
# 37                    [55/1.0, 55/3.0, 60/1.0, 60/3.0]
# 38                    [56/1.0, 56/3.0, 61/1.0, 61/3.0]
# 39                    [56/3.0, 57/1.0, 61/3.0, 62/1.0]
# 40            [64/3.0, 66/3.0, 67/3.0, 69/3.0, 73/3.0]
# 41            [65/1.0, 67/1.0, 68/1.0, 70/1.0, 74/1.0]
# 42                    [65/3.0, 67/3.0, 68/3.0, 70/3.0]
# 43                    [66/1.0, 68/1.0, 69/1.0, 71/1.0]
# 44                    [66/3.0, 68/3.0, 69/3.0, 71/3.0]
# 45                                    [70/3.0, 73/3.0]
# 46                                    [70/4.0, 73/4.0]
# 47                                    [71/1.5, 74/1.5]
# 48                    [76/1.0, 79/4.0, 82/4.0, 85/4.0]
# 49                                    [78/1.0, 81/1.0]
# 50                                    [78/3.0, 81/3.0]
# 51                                    [78/3.0, 81/3.0]
# 52                                    [78/4.0, 81/4.0]
# 53                                    [79/1.0, 82/1.0]
# 54                                    [79/1.0, 82/1.0]
# 55                            [79/3.0, 82/3.0, 84/4.0]
# 56                                    [79/3.0, 82/3.0]
# 57            [84/1.0, 85/1.0, 85/3.0, 89/1.0, 90/4.0]
# 58                                    [88/3.0, 90/3.0]
# 59                                    [89/1.0, 91/4.5]
# 60                                    [90/1.0, 91/4.0]
# 61                                    [91/3.0, 94/1.0]
# 62                                    [94/2.0, 94/3.0]
# 63                                    [94/3.0, 94/1.0]
# 64                                    [94/1.0, 95/2.0]
# 65                                    [98/2.0, 98/3.0]
# 66                                    [98/3.0, 98/1.0]
# 67                                    [98/1.0, 99/2.0]
# 68                          [99/1.0, 100/2.0, 101/1.0]
# 69                         [100/1.0, 101/2.0, 101/1.0]
# 70                                  [102/2.0, 102/3.0]
# 71                                  [103/2.0, 103/3.0]
# 72                                  [103/1.0, 104/2.0]
# 73                         [104/2.0, 104/3.0, 106/2.0]
# 74                                  [104/3.5, 104/1.5]
# 75                                  [104/1.0, 105/2.0]
# 76                                  [104/1.5, 105/2.5]
# 77                                  [105/2.0, 105/3.0]
# 78                                  [106/2.0, 106/3.0]
# 79                                  [106/1.0, 107/2.0]
# 80                                  [111/1.0, 114/1.0]
# 81   [112/1.0, 114/4.0, 117/4.0, 120/1.0, 122/4.0, ...
# 82                [112/1.0, 115/1.0, 120/1.0, 123/1.0]
# 83                [112/3.0, 115/3.0, 120/3.0, 123/3.0]
# 84                                  [113/1.0, 116/1.0]
# 85                                  [113/4.0, 116/4.0]
# 86                                  [113/4.5, 116/4.5]
# 87                                  [114/1.0, 117/1.0]
# 88                                  [114/3.0, 117/3.0]
# 89                                  [119/1.0, 122/1.0]
# 90                                  [121/1.0, 124/1.0]
# 91                                  [121/4.0, 124/4.0]
# 92                                  [121/4.5, 124/4.5]
# 93                                  [122/1.0, 125/1.0]
# 94                                  [122/3.0, 125/3.0]
# 95                         [125/4.5, 128/1.0, 130/1.0]
# 96                                  [127/3.0, 129/3.0]
# 97                                  [128/3.0, 130/3.0]
# 98                         [129/1.0, 130/3.0, 131/1.0]
# 99                         [130/1.0, 135/3.5, 139/4.0]
# 100                                 [133/3.0, 136/3.0]
# 101                        [134/1.0, 137/1.0, 140/1.5]
# 102                                 [134/3.0, 137/3.0]
# 103                                 [138/4.0, 139/1.0]
# 104                                 [139/4.0, 143/1.0]
#
#                                        time_intervals  \
# 0                                  [16.0, 16.0, 16.0]
# 1                                  [16.0, 16.0, 16.0]
# 2                                  [16.0, 16.0, 16.0]
# 3                                        [16.0, 16.0]
# 4                                        [16.0, 16.0]
# 5                                        [16.0, 16.0]
# 6                                        [17.0, 15.0]
# 7                                   [16.0, 16.0, 2.0]
# 8                                  [16.0, 16.0, 16.0]
# 9                                  [16.0, 16.0, 16.0]
# 10                                   [3.0, 11.0, 3.0]
# 11                                        [33.0, 7.0]
# 12                                              [4.0]
# 13                                             [23.0]
# 14                                              [7.0]
# 15                                              [5.0]
# 16                                             [32.0]
# 17                                             [32.0]
# 18                                             [32.0]
# 19                                             [32.0]
# 20                                       [32.0, 32.0]
# 21                                       [32.0, 32.0]
# 22                                        [28.0, 4.0]
# 23                                             [32.0]
# 24                  [20.0, 2.0, 12.0, 2.0, 2.0, 36.0]
# 25                       [14.0, 2.0, 14.0, 2.0, 16.0]
# 26                                   [2.0, 14.0, 2.0]
# 27                                   [2.0, 14.0, 2.0]
# 28                                             [18.0]
# 29                                              [2.0]
# 30                                              [2.0]
# 31                                    [2.0, 8.0, 2.0]
# 32                                    [2.0, 6.0, 2.0]
# 33                                              [2.0]
# 34                             [33.0, 4.0, 36.0, 4.0]
# 35                                             [12.0]
# 36                                   [4.0, 36.0, 4.0]
# 37                                   [4.0, 36.0, 4.0]
# 38                                   [4.0, 36.0, 4.0]
# 39                                   [4.0, 36.0, 4.0]
# 40                            [16.0, 8.0, 16.0, 32.0]
# 41                            [16.0, 8.0, 16.0, 32.0]
# 42                                  [16.0, 8.0, 16.0]
# 43                                  [16.0, 8.0, 16.0]
# 44                                  [16.0, 8.0, 16.0]
# 45                                             [24.0]
# 46                                             [24.0]
# 47                                             [24.0]
# 48                                 [30.0, 24.0, 24.0]
# 49                                             [24.0]
# 50                                             [24.0]
# 51                                             [24.0]
# 52                                             [24.0]
# 53                                             [24.0]
# 54                                             [24.0]
# 55                                       [24.0, 18.0]
# 56                                             [24.0]
# 57                             [8.0, 4.0, 28.0, 14.0]
# 58                                             [16.0]
# 59                                             [23.0]
# 60                                             [14.0]
# 61                                             [32.0]
# 62                                              [4.0]
# 63                                              [4.0]
# 64                                              [4.0]
# 65                                              [4.0]
# 66                                              [4.0]
# 67                                              [4.0]
# 68                                        [4.0, 20.0]
# 69                                         [4.0, 8.0]
# 70                                              [4.0]
# 71                                              [4.0]
# 72                                              [4.0]
# 73                                        [4.0, 20.0]
# 74                                              [4.0]
# 75                                              [4.0]
# 76                                              [4.0]
# 77                                              [4.0]
# 78                                              [4.0]
# 79                                              [4.0]
# 80                                             [24.0]
# 81   [22.0, 24.0, 18.0, 22.0, 24.0, 30.0, 18.0, 28.0]
# 82                                 [24.0, 40.0, 24.0]
# 83                                 [24.0, 40.0, 24.0]
# 84                                             [24.0]
# 85                                             [24.0]
# 86                                             [24.0]
# 87                                             [24.0]
# 88                                             [24.0]
# 89                                             [24.0]
# 90                                             [24.0]
# 91                                             [24.0]
# 92                                             [24.0]
# 93                                             [24.0]
# 94                                             [24.0]
# 95                                       [17.0, 16.0]
# 96                                             [16.0]
# 97                                             [16.0]
# 98                                        [12.0, 4.0]
# 99                                       [45.0, 33.0]
# 100                                            [24.0]
# 101                                      [24.0, 25.0]
# 102                                            [24.0]
# 103                                             [2.0]
# 104                                            [26.0]
#
#                                             voice_list  \
# 0                   [[Superius], Altus, Tenor, Bassus]
# 1                   [[Superius], Altus, Tenor, Bassus]
# 2                   [[Superius], Altus, Tenor, Bassus]
# 3                           [[Superius], Altus, Tenor]
# 4                           [[Superius], Altus, Tenor]
# 5                           [[Superius], Altus, Tenor]
# 6                           [[Superius], Altus, Tenor]
# 7                   [[Superius], Altus, Tenor, Bassus]
# 8                   [[Superius], Altus, Tenor, Bassus]
# 9                   [[Superius], Altus, Tenor, Bassus]
# 10    [[Superius], [Superius], [Superius], [Superius]]
# 11                              [Altus, Altus, Bassus]
# 12                                      [Altus, Altus]
# 13                                      [Altus, Altus]
# 14                                 [Altus, [Superius]]
# 15                                      [Altus, Tenor]
# 16                                 [[Superius], Tenor]
# 17                                 [[Superius], Tenor]
# 18                                 [[Superius], Tenor]
# 19                                 [[Superius], Tenor]
# 20                         [Altus, Bassus, [Superius]]
# 21                         [Altus, Bassus, [Superius]]
# 22                          [[Superius], Altus, Tenor]
# 23                                 [[Superius], Altus]
# 24   [Altus, [Superius], Bassus, Tenor, [Superius],...
# 25   [[Superius], Tenor, [Superius], Tenor, [Superi...
# 26              [Tenor, [Superius], Tenor, [Superius]]
# 27              [Tenor, [Superius], Tenor, [Superius]]
# 28                                      [Altus, Altus]
# 29                                 [[Superius], Tenor]
# 30                                 [[Superius], Tenor]
# 31                      [Bassus, Tenor, Bassus, Tenor]
# 32                      [Bassus, Tenor, Bassus, Tenor]
# 33                                     [Bassus, Tenor]
# 34           [Altus, [Superius], Altus, Tenor, Bassus]
# 35                                 [[Superius], Altus]
# 36                  [[Superius], Altus, Tenor, Bassus]
# 37                  [[Superius], Altus, Tenor, Bassus]
# 38                  [[Superius], Altus, Tenor, Bassus]
# 39                  [[Superius], Altus, Tenor, Bassus]
# 40          [[Superius], Altus, Tenor, Bassus, Bassus]
# 41          [[Superius], Altus, Tenor, Bassus, Bassus]
# 42                  [[Superius], Altus, Tenor, Bassus]
# 43                  [[Superius], Altus, Tenor, Bassus]
# 44                  [[Superius], Altus, Tenor, Bassus]
# 45                                 [Altus, [Superius]]
# 46                                 [Altus, [Superius]]
# 47                                 [Altus, [Superius]]
# 48                  [[Superius], Altus, Bassus, Altus]
# 49                                 [[Superius], Tenor]
# 50                                     [Altus, Bassus]
# 51                                 [[Superius], Tenor]
# 52                                 [[Superius], Tenor]
# 53                                 [[Superius], Tenor]
# 54                                     [Altus, Bassus]
# 55                     [[Superius], Tenor, [Superius]]
# 56                                     [Altus, Bassus]
# 57     [Altus, [Superius], [Superius], Bassus, Bassus]
# 58                                    [Bassus, Bassus]
# 59                                     [Tenor, Bassus]
# 60                                      [Tenor, Tenor]
# 61                                      [Tenor, Altus]
# 62                                 [[Superius], Tenor]
# 63                                 [[Superius], Tenor]
# 64                                 [[Superius], Tenor]
# 65                                 [[Superius], Tenor]
# 66                                 [[Superius], Tenor]
# 67                                 [[Superius], Tenor]
# 68                          [[Superius], Tenor, Altus]
# 69                         [[Superius], Tenor, Bassus]
# 70                                 [[Superius], Tenor]
# 71                                 [[Superius], Tenor]
# 72                                 [[Superius], Tenor]
# 73                          [[Superius], Tenor, Altus]
# 74                                 [[Superius], Tenor]
# 75                                 [[Superius], Tenor]
# 76                                 [[Superius], Tenor]
# 77                                 [[Superius], Tenor]
# 78                                     [Bassus, Tenor]
# 79                                     [Bassus, Tenor]
# 80                                 [[Superius], Tenor]
# 81   [Altus, [Superius], Tenor, Altus, [Superius], ...
# 82              [[Superius], Tenor, [Superius], Tenor]
# 83              [[Superius], Tenor, [Superius], Tenor]
# 84                                 [[Superius], Tenor]
# 85                                 [[Superius], Tenor]
# 86                                 [[Superius], Tenor]
# 87                                 [[Superius], Tenor]
# 88                                 [[Superius], Tenor]
# 89                                 [[Superius], Tenor]
# 90                                 [[Superius], Tenor]
# 91                                 [[Superius], Tenor]
# 92                                 [[Superius], Tenor]
# 93                                 [[Superius], Tenor]
# 94                                 [[Superius], Tenor]
# 95                         [Bassus, [Superius], Tenor]
# 96                                 [[Superius], Tenor]
# 97                                 [[Superius], Tenor]
# 98                         [[Superius], Bassus, Tenor]
# 99                             [Bassus, Altus, Bassus]
# 100                                [[Superius], Tenor]
# 101                        [[Superius], Tenor, Bassus]
# 102                                [[Superius], Tenor]
# 103                                    [Altus, Bassus]
# 104                                     [Altus, Tenor]
#
#                          entry_intervals
# 0                         [P-8, P1, P-8]
# 1                         [P-8, P1, P-8]
# 2                         [P-8, P1, P-8]
# 3                              [P-8, P1]
# 4                              [P-8, P1]
# 5                              [P-8, P1]
# 6                              [P-8, P1]
# 7                         [P-8, P1, m-9]
# 8                         [P-8, P1, P-8]
# 9                         [P-8, P1, P-8]
# 10                        [m-2, m2, m-2]
# 11                            [P4, P-11]
# 12                                  [M2]
# 13                                  [m2]
# 14                                  [M7]
# 15                                 [M-2]
# 16                                 [P-8]
# 17                                 [P-8]
# 18                                 [P-8]
# 19                                 [P-8]
# 20                            [P-8, M13]
# 21                            [P-8, M13]
# 22                            [P-11, P4]
# 23                                [P-11]
# 24          [P5, m-10, m6, M6, M-10, M2]
# 25               [P-5, m6, P-5, M6, M-9]
# 26                         [M6, P-5, M6]
# 27                         [M6, P-5, m6]
# 28                                 [P-4]
# 29                                 [P-5]
# 30                                 [P-5]
# 31                         [m6, m-7, m6]
# 32                         [M6, M-7, M6]
# 33                                  [M6]
# 34                   [M9, P-5, P-4, P-5]
# 35                                 [M-6]
# 36                       [P-5, P-4, P-5]
# 37                       [P-5, P-4, P-5]
# 38                       [P-5, P-4, P-5]
# 39                       [P-5, P-4, P-5]
# 40                   [P-5, P-4, P-5, P1]
# 41                   [P-5, P-4, P-5, P1]
# 42                       [P-5, P-4, P-5]
# 43                       [P-5, P-4, P-5]
# 44                       [P-5, P-4, P-5]
# 45                                  [M9]
# 46                                  [M9]
# 47                                  [m9]
# 48                        [P-4, P-8, m6]
# 49                                 [P-8]
# 50                                 [P-8]
# 51                                 [P-8]
# 52                                 [P-8]
# 53                                 [P-8]
# 54                                 [P-8]
# 55                             [P-8, P8]
# 56                                 [P-8]
# 57                   [P4, m-2, M-10, P1]
# 58                                  [P1]
# 59                                 [M-9]
# 60                                 [m-2]
# 61                                  [M2]
# 62                                 [P-5]
# 63                                 [P-5]
# 64                                 [P-5]
# 65                                 [P-5]
# 66                                 [P-5]
# 67                                 [P-5]
# 68                             [P-5, P4]
# 69                            [P-5, M-3]
# 70                                 [P-5]
# 71                                 [P-5]
# 72                                 [P-5]
# 73                             [P-5, M2]
# 74                                 [P-5]
# 75                                 [P-5]
# 76                                 [P-5]
# 77                                 [P-5]
# 78                                  [m6]
# 79                                  [m6]
# 80                                 [P-8]
# 81   [P5, P-8, P4, P5, P-8, P-5, M6, m2]
# 82                        [P-8, P8, P-8]
# 83                        [P-8, P8, P-8]
# 84                                 [P-8]
# 85                                 [P-8]
# 86                                 [P-8]
# 87                                 [P-8]
# 88                                 [P-8]
# 89                                 [P-8]
# 90                                 [P-8]
# 91                                 [P-8]
# 92                                 [P-8]
# 93                                 [P-8]
# 94                                 [P-8]
# 95                            [P11, P-8]
# 96                                 [P-8]
# 97                                 [P-8]
# 98                            [m-14, m7]
# 99                             [M7, M-7]
# 100                                [P-8]
# 101                           [P-8, P-8]
# 102                                [P-8]
# 103                                [M-3]
# 104                                 [m3]

# %%
classified_with_intervals = df8
classified_with_intervals
# Out:
#     piece_title   pattern_matched predicted_type  \
# 0     Ave Maria      (4, 1, 2, 2)            PEN
# 1     Ave Maria     (1, 2, 2, -3)            PEN
# 2     Ave Maria   (-2, -2, -2, 2)            PEN
# 3     Ave Maria   (-2, -2, 2, -2)            PEN
# 4     Ave Maria    (2, -2, 4, -2)            PEN
# 5     Ave Maria   (-2, 4, -2, -2)            PEN
# 6     Ave Maria    (4, -2, -2, 2)           Fuga
# 7     Ave Maria    (-2, -2, 2, 2)           Fuga
# 8     Ave Maria      (1, 1, 2, 2)            PEN
# 9     Ave Maria     (1, 2, 2, -3)            PEN
# 10    Ave Maria  (-2, -2, -2, -2)             ID
# 11    Ave Maria     (-2, 2, 2, 2)           Fuga
# 12    Ave Maria      (2, 2, 2, 2)           Fuga
# 13    Ave Maria     (2, 2, 2, -2)           Fuga
# 14    Ave Maria   (-2, -2, -2, 2)           Fuga
# 15    Ave Maria    (-2, -2, 2, 2)           Fuga
# 16    Ave Maria      (1, 2, 2, 1)           Fuga
# 17    Ave Maria      (2, 2, 1, 2)           Fuga
# 18    Ave Maria     (2, 1, 2, -2)           Fuga
# 19    Ave Maria     (1, 2, -2, 1)           Fuga
# 20    Ave Maria    (1, 2, -2, -2)            PEN
# 21    Ave Maria   (2, -2, -2, -2)            PEN
# 22    Ave Maria    (2, -2, 1, -2)           Fuga
# 23    Ave Maria    (-2, 1, -2, 2)           Fuga
# 24    Ave Maria     (2, 2, 2, -3)           Fuga
# 25    Ave Maria     (-3, 2, 2, 2)           Fuga
# 26    Ave Maria     (2, 2, -3, 2)             ID
# 27    Ave Maria     (2, -3, 2, 2)             ID
# 28    Ave Maria     (2, 2, 2, -5)           Fuga
# 29    Ave Maria     (2, 2, 2, -2)           Fuga
# 30    Ave Maria     (2, 2, -2, 2)           Fuga
# 31    Ave Maria    (2, -2, 2, -3)             ID
# 32    Ave Maria    (-2, 2, -3, 2)             ID
# 33    Ave Maria    (-3, 2, -2, 2)           Fuga
# 34    Ave Maria    (2, 2, -3, -2)           Fuga
# 35    Ave Maria   (-2, -2, -2, 2)           Fuga
# 36    Ave Maria     (4, -2, 2, 2)             ID
# 37    Ave Maria    (-2, 2, 2, -3)             ID
# 38    Ave Maria   (2, -3, -2, -2)             ID
# 39    Ave Maria   (-3, -2, -2, 1)             ID
# 40    Ave Maria    (2, -3, 2, -3)           Fuga
# 41    Ave Maria    (-3, 2, -3, 2)           Fuga
# 42    Ave Maria    (2, -3, 2, -2)             ID
# 43    Ave Maria   (-3, 2, -2, -2)             ID
# 44    Ave Maria   (2, -2, -2, -2)             ID
# 45    Ave Maria     (2, -3, 1, 2)           Fuga
# 46    Ave Maria    (-3, 1, 2, -3)           Fuga
# 47    Ave Maria     (1, 2, -3, 1)           Fuga
# 48    Ave Maria    (-2, 1, -2, 2)           Fuga
# 49    Ave Maria     (1, 1, 2, -3)           Fuga
# 50    Ave Maria      (1, 5, 1, 2)           Fuga
# 51    Ave Maria     (1, 2, -3, 2)           Fuga
# 52    Ave Maria    (2, -3, 2, -2)           Fuga
# 53    Ave Maria   (-3, 2, -2, -2)           Fuga
# 54    Ave Maria     (1, 2, -2, 1)           Fuga
# 55    Ave Maria   (2, -2, -2, -2)           Fuga
# 56    Ave Maria    (2, -2, 1, -2)           Fuga
# 57    Ave Maria  (-2, -2, -2, -2)           Fuga
# 58    Ave Maria   (5, -2, -2, -2)           Fuga
# 59    Ave Maria   (-2, 3, -2, -2)           Fuga
# 60    Ave Maria   (-2, -2, -2, 2)           Fuga
# 61    Ave Maria   (2, -2, -2, -2)           Fuga
# 62    Ave Maria      (1, 1, 2, 1)           Fuga
# 63    Ave Maria      (1, 2, 1, 2)           Fuga
# 64    Ave Maria      (2, 1, 2, 1)           Fuga
# 65    Ave Maria      (1, 1, 2, 1)           Fuga
# 66    Ave Maria      (1, 2, 1, 2)           Fuga
# 67    Ave Maria      (2, 1, 2, 1)           Fuga
# 68    Ave Maria     (2, 1, -3, 1)           Fuga
# 69    Ave Maria     (-3, 1, 4, 1)           Fuga
# 70    Ave Maria     (1, -3, 1, 4)           Fuga
# 71    Ave Maria    (1, 4, -2, -2)           Fuga
# 72    Ave Maria   (4, -2, -2, -2)           Fuga
# 73    Ave Maria  (-2, -2, -2, -2)           Fuga
# 74    Ave Maria   (-2, -2, -2, 1)           Fuga
# 75    Ave Maria    (-2, -2, 1, 4)           Fuga
# 76    Ave Maria     (-2, 1, 4, 1)           Fuga
# 77    Ave Maria      (1, 4, 1, 2)           Fuga
# 78    Ave Maria     (1, 2, -3, 2)           Fuga
# 79    Ave Maria    (2, -3, 2, -3)           Fuga
# 80    Ave Maria     (1, 1, 2, -2)           Fuga
# 81    Ave Maria  (-2, -2, -2, -2)           Fuga
# 82    Ave Maria    (1, 2, -2, -2)             ID
# 83    Ave Maria   (2, -2, -2, -2)             ID
# 84    Ave Maria   (-2, -2, -2, 1)           Fuga
# 85    Ave Maria    (-2, -2, 1, 3)           Fuga
# 86    Ave Maria    (-2, 1, 3, -2)           Fuga
# 87    Ave Maria    (1, 3, -2, -2)           Fuga
# 88    Ave Maria   (3, -2, -2, -2)           Fuga
# 89    Ave Maria     (1, 1, 2, -2)           Fuga
# 90    Ave Maria   (-2, -2, -2, 1)           Fuga
# 91    Ave Maria    (-2, -2, 1, 3)           Fuga
# 92    Ave Maria    (-2, 1, 3, -2)           Fuga
# 93    Ave Maria    (1, 3, -2, -2)           Fuga
# 94    Ave Maria   (3, -2, -2, -2)           Fuga
# 95    Ave Maria     (2, 2, -2, 2)           Fuga
# 96    Ave Maria     (2, 2, 2, -2)           Fuga
# 97    Ave Maria     (2, -2, 2, 2)           Fuga
# 98    Ave Maria     (-2, 2, 2, 2)           Fuga
# 99    Ave Maria   (-2, -2, -2, 2)           Fuga
# 100   Ave Maria    (1, -2, -2, 2)           Fuga
# 101   Ave Maria   (-2, -2, 2, -2)           Fuga
# 102   Ave Maria   (-2, 2, -2, -2)           Fuga
# 103   Ave Maria    (2, -3, 2, -2)           Fuga
# 104   Ave Maria    (-2, 1, -2, 2)           Fuga
#
#                                      measure_beat_list  \
# 0                         [1/1.0, 3/1.0, 5/1.0, 7/1.0]
# 1                         [1/3.0, 3/3.0, 5/3.0, 7/3.0]
# 2                      [8/1.0, 10/1.0, 12/1.0, 14/1.0]
# 3                              [8/4.0, 10/4.0, 12/4.0]
# 4                              [9/3.0, 11/3.0, 13/3.0]
# 5                             [10/1.0, 12/1.0, 14/1.0]
# 6                             [10/2.0, 12/2.5, 14/2.0]
# 7                     [10/3.0, 12/3.0, 14/3.0, 14/4.0]
# 8                     [16/3.0, 18/3.0, 20/3.0, 22/3.0]
# 9                     [17/2.0, 19/2.0, 21/2.0, 23/2.0]
# 10                    [19/1.0, 19/2.5, 20/4.0, 21/1.5]
# 11                            [24/1.0, 28/1.5, 29/1.0]
# 12                                    [24/3.0, 25/1.0]
# 13                                    [25/2.5, 28/2.0]
# 14                                    [27/4.5, 28/4.0]
# 15                                    [28/1.0, 28/3.5]
# 16                                    [31/3.0, 35/3.0]
# 17                                    [32/1.0, 36/1.0]
# 18                                    [32/3.0, 36/3.0]
# 19                                    [33/1.0, 37/1.0]
# 20                            [33/1.0, 37/1.0, 41/1.0]
# 21                            [33/3.0, 37/3.0, 41/3.0]
# 22                            [33/3.0, 37/1.0, 37/3.0]
# 23                                    [33/4.0, 37/4.0]
# 24   [42/1.0, 44/3.0, 44/4.0, 46/2.0, 46/3.0, 46/4....
# 25    [44/1.0, 45/4.0, 46/1.0, 47/4.0, 48/1.0, 50/1.0]
# 26                    [44/4.0, 45/1.0, 46/4.0, 47/1.0]
# 27                    [45/2.0, 45/3.0, 47/2.0, 47/3.0]
# 28                                    [48/1.0, 50/2.0]
# 29                                    [48/3.0, 48/4.0]
# 30                                    [49/1.0, 49/2.0]
# 31                    [49/3.0, 49/4.0, 50/4.0, 51/1.0]
# 32                    [50/1.0, 50/2.0, 51/1.0, 51/2.0]
# 33                                    [50/3.0, 50/4.0]
# 34            [51/3.5, 55/4.0, 56/2.0, 60/4.0, 61/2.0]
# 35                                    [51/4.0, 53/2.0]
# 36                    [54/3.0, 55/1.0, 59/3.0, 60/1.0]
# 37                    [55/1.0, 55/3.0, 60/1.0, 60/3.0]
# 38                    [56/1.0, 56/3.0, 61/1.0, 61/3.0]
# 39                    [56/3.0, 57/1.0, 61/3.0, 62/1.0]
# 40            [64/3.0, 66/3.0, 67/3.0, 69/3.0, 73/3.0]
# 41            [65/1.0, 67/1.0, 68/1.0, 70/1.0, 74/1.0]
# 42                    [65/3.0, 67/3.0, 68/3.0, 70/3.0]
# 43                    [66/1.0, 68/1.0, 69/1.0, 71/1.0]
# 44                    [66/3.0, 68/3.0, 69/3.0, 71/3.0]
# 45                                    [70/3.0, 73/3.0]
# 46                                    [70/4.0, 73/4.0]
# 47                                    [71/1.5, 74/1.5]
# 48                    [76/1.0, 79/4.0, 82/4.0, 85/4.0]
# 49                                    [78/1.0, 81/1.0]
# 50                                    [78/3.0, 81/3.0]
# 51                                    [78/3.0, 81/3.0]
# 52                                    [78/4.0, 81/4.0]
# 53                                    [79/1.0, 82/1.0]
# 54                                    [79/1.0, 82/1.0]
# 55                            [79/3.0, 82/3.0, 84/4.0]
# 56                                    [79/3.0, 82/3.0]
# 57            [84/1.0, 85/1.0, 85/3.0, 89/1.0, 90/4.0]
# 58                                    [88/3.0, 90/3.0]
# 59                                    [89/1.0, 91/4.5]
# 60                                    [90/1.0, 91/4.0]
# 61                                    [91/3.0, 94/1.0]
# 62                                    [94/2.0, 94/3.0]
# 63                                    [94/3.0, 94/1.0]
# 64                                    [94/1.0, 95/2.0]
# 65                                    [98/2.0, 98/3.0]
# 66                                    [98/3.0, 98/1.0]
# 67                                    [98/1.0, 99/2.0]
# 68                          [99/1.0, 100/2.0, 101/1.0]
# 69                         [100/1.0, 101/2.0, 101/1.0]
# 70                                  [102/2.0, 102/3.0]
# 71                                  [103/2.0, 103/3.0]
# 72                                  [103/1.0, 104/2.0]
# 73                         [104/2.0, 104/3.0, 106/2.0]
# 74                                  [104/3.5, 104/1.5]
# 75                                  [104/1.0, 105/2.0]
# 76                                  [104/1.5, 105/2.5]
# 77                                  [105/2.0, 105/3.0]
# 78                                  [106/2.0, 106/3.0]
# 79                                  [106/1.0, 107/2.0]
# 80                                  [111/1.0, 114/1.0]
# 81   [112/1.0, 114/4.0, 117/4.0, 120/1.0, 122/4.0, ...
# 82                [112/1.0, 115/1.0, 120/1.0, 123/1.0]
# 83                [112/3.0, 115/3.0, 120/3.0, 123/3.0]
# 84                                  [113/1.0, 116/1.0]
# 85                                  [113/4.0, 116/4.0]
# 86                                  [113/4.5, 116/4.5]
# 87                                  [114/1.0, 117/1.0]
# 88                                  [114/3.0, 117/3.0]
# 89                                  [119/1.0, 122/1.0]
# 90                                  [121/1.0, 124/1.0]
# 91                                  [121/4.0, 124/4.0]
# 92                                  [121/4.5, 124/4.5]
# 93                                  [122/1.0, 125/1.0]
# 94                                  [122/3.0, 125/3.0]
# 95                         [125/4.5, 128/1.0, 130/1.0]
# 96                                  [127/3.0, 129/3.0]
# 97                                  [128/3.0, 130/3.0]
# 98                         [129/1.0, 130/3.0, 131/1.0]
# 99                         [130/1.0, 135/3.5, 139/4.0]
# 100                                 [133/3.0, 136/3.0]
# 101                        [134/1.0, 137/1.0, 140/1.5]
# 102                                 [134/3.0, 137/3.0]
# 103                                 [138/4.0, 139/1.0]
# 104                                 [139/4.0, 143/1.0]
#
#                                            offset_list  \
# 0                              [0.0, 16.0, 32.0, 48.0]
# 1                              [4.0, 20.0, 36.0, 52.0]
# 2                            [56.0, 72.0, 88.0, 104.0]
# 3                                   [62.0, 78.0, 94.0]
# 4                                  [68.0, 84.0, 100.0]
# 5                                  [72.0, 88.0, 104.0]
# 6                                  [74.0, 91.0, 106.0]
# 7                           [76.0, 92.0, 108.0, 110.0]
# 8                         [124.0, 140.0, 156.0, 172.0]
# 9                         [130.0, 146.0, 162.0, 178.0]
# 10                        [144.0, 147.0, 158.0, 161.0]
# 11                               [184.0, 217.0, 224.0]
# 12                                      [188.0, 192.0]
# 13                                      [195.0, 218.0]
# 14                                      [215.0, 222.0]
# 15                                      [216.0, 221.0]
# 16                                      [244.0, 276.0]
# 17                                      [248.0, 280.0]
# 18                                      [252.0, 284.0]
# 19                                      [256.0, 288.0]
# 20                               [256.0, 288.0, 320.0]
# 21                               [260.0, 292.0, 324.0]
# 22                               [260.0, 288.0, 292.0]
# 23                                      [262.0, 294.0]
# 24   [328.0, 348.0, 350.0, 362.0, 364.0, 366.0, 402.0]
# 25          [344.0, 358.0, 360.0, 374.0, 376.0, 392.0]
# 26                        [350.0, 352.0, 366.0, 368.0]
# 27                        [354.0, 356.0, 370.0, 372.0]
# 28                                      [376.0, 394.0]
# 29                                      [380.0, 382.0]
# 30                                      [384.0, 386.0]
# 31                        [388.0, 390.0, 398.0, 400.0]
# 32                        [392.0, 394.0, 400.0, 402.0]
# 33                                      [396.0, 398.0]
# 34                 [405.0, 438.0, 442.0, 478.0, 482.0]
# 35                                      [406.0, 418.0]
# 36                        [428.0, 432.0, 468.0, 472.0]
# 37                        [432.0, 436.0, 472.0, 476.0]
# 38                        [440.0, 444.0, 480.0, 484.0]
# 39                        [444.0, 448.0, 484.0, 488.0]
# 40                 [508.0, 524.0, 532.0, 548.0, 580.0]
# 41                 [512.0, 528.0, 536.0, 552.0, 584.0]
# 42                        [516.0, 532.0, 540.0, 556.0]
# 43                        [520.0, 536.0, 544.0, 560.0]
# 44                        [524.0, 540.0, 548.0, 564.0]
# 45                                      [556.0, 580.0]
# 46                                      [558.0, 582.0]
# 47                                      [561.0, 585.0]
# 48                        [600.0, 630.0, 654.0, 678.0]
# 49                                      [616.0, 640.0]
# 50                                      [620.0, 644.0]
# 51                                      [620.0, 644.0]
# 52                                      [622.0, 646.0]
# 53                                      [624.0, 648.0]
# 54                                      [624.0, 648.0]
# 55                               [628.0, 652.0, 670.0]
# 56                                      [628.0, 652.0]
# 57                 [664.0, 672.0, 676.0, 704.0, 718.0]
# 58                                      [700.0, 716.0]
# 59                                      [704.0, 727.0]
# 60                                      [712.0, 726.0]
# 61                                      [724.0, 756.0]
# 62                                      [748.0, 752.0]
# 63                                      [752.0, 756.0]
# 64                                      [756.0, 760.0]
# 65                                      [796.0, 800.0]
# 66                                      [800.0, 804.0]
# 67                                      [804.0, 808.0]
# 68                               [816.0, 820.0, 840.0]
# 69                               [828.0, 832.0, 840.0]
# 70                                      [844.0, 848.0]
# 71                                      [856.0, 860.0]
# 72                                      [864.0, 868.0]
# 73                               [868.0, 872.0, 892.0]
# 74                                      [874.0, 878.0]
# 75                                      [876.0, 880.0]
# 76                                      [878.0, 882.0]
# 77                                      [880.0, 884.0]
# 78                                      [892.0, 896.0]
# 79                                      [900.0, 904.0]
# 80                                      [944.0, 968.0]
# 81   [952.0, 974.0, 998.0, 1016.0, 1038.0, 1062.0, ...
# 82                      [952.0, 976.0, 1016.0, 1040.0]
# 83                      [956.0, 980.0, 1020.0, 1044.0]
# 84                                      [960.0, 984.0]
# 85                                      [966.0, 990.0]
# 86                                      [967.0, 991.0]
# 87                                      [968.0, 992.0]
# 88                                      [972.0, 996.0]
# 89                                    [1008.0, 1032.0]
# 90                                    [1024.0, 1048.0]
# 91                                    [1030.0, 1054.0]
# 92                                    [1031.0, 1055.0]
# 93                                    [1032.0, 1056.0]
# 94                                    [1036.0, 1060.0]
# 95                            [1063.0, 1080.0, 1096.0]
# 96                                    [1076.0, 1092.0]
# 97                                    [1084.0, 1100.0]
# 98                            [1088.0, 1100.0, 1104.0]
# 99                            [1096.0, 1141.0, 1174.0]
# 100                                   [1124.0, 1148.0]
# 101                           [1128.0, 1152.0, 1177.0]
# 102                                   [1132.0, 1156.0]
# 103                                   [1166.0, 1168.0]
# 104                                   [1174.0, 1200.0]
#
#                                        time_intervals  \
# 0                                  [16.0, 16.0, 16.0]
# 1                                  [16.0, 16.0, 16.0]
# 2                                  [16.0, 16.0, 16.0]
# 3                                        [16.0, 16.0]
# 4                                        [16.0, 16.0]
# 5                                        [16.0, 16.0]
# 6                                        [17.0, 15.0]
# 7                                   [16.0, 16.0, 2.0]
# 8                                  [16.0, 16.0, 16.0]
# 9                                  [16.0, 16.0, 16.0]
# 10                                   [3.0, 11.0, 3.0]
# 11                                        [33.0, 7.0]
# 12                                              [4.0]
# 13                                             [23.0]
# 14                                              [7.0]
# 15                                              [5.0]
# 16                                             [32.0]
# 17                                             [32.0]
# 18                                             [32.0]
# 19                                             [32.0]
# 20                                       [32.0, 32.0]
# 21                                       [32.0, 32.0]
# 22                                        [28.0, 4.0]
# 23                                             [32.0]
# 24                  [20.0, 2.0, 12.0, 2.0, 2.0, 36.0]
# 25                       [14.0, 2.0, 14.0, 2.0, 16.0]
# 26                                   [2.0, 14.0, 2.0]
# 27                                   [2.0, 14.0, 2.0]
# 28                                             [18.0]
# 29                                              [2.0]
# 30                                              [2.0]
# 31                                    [2.0, 8.0, 2.0]
# 32                                    [2.0, 6.0, 2.0]
# 33                                              [2.0]
# 34                             [33.0, 4.0, 36.0, 4.0]
# 35                                             [12.0]
# 36                                   [4.0, 36.0, 4.0]
# 37                                   [4.0, 36.0, 4.0]
# 38                                   [4.0, 36.0, 4.0]
# 39                                   [4.0, 36.0, 4.0]
# 40                            [16.0, 8.0, 16.0, 32.0]
# 41                            [16.0, 8.0, 16.0, 32.0]
# 42                                  [16.0, 8.0, 16.0]
# 43                                  [16.0, 8.0, 16.0]
# 44                                  [16.0, 8.0, 16.0]
# 45                                             [24.0]
# 46                                             [24.0]
# 47                                             [24.0]
# 48                                 [30.0, 24.0, 24.0]
# 49                                             [24.0]
# 50                                             [24.0]
# 51                                             [24.0]
# 52                                             [24.0]
# 53                                             [24.0]
# 54                                             [24.0]
# 55                                       [24.0, 18.0]
# 56                                             [24.0]
# 57                             [8.0, 4.0, 28.0, 14.0]
# 58                                             [16.0]
# 59                                             [23.0]
# 60                                             [14.0]
# 61                                             [32.0]
# 62                                              [4.0]
# 63                                              [4.0]
# 64                                              [4.0]
# 65                                              [4.0]
# 66                                              [4.0]
# 67                                              [4.0]
# 68                                        [4.0, 20.0]
# 69                                         [4.0, 8.0]
# 70                                              [4.0]
# 71                                              [4.0]
# 72                                              [4.0]
# 73                                        [4.0, 20.0]
# 74                                              [4.0]
# 75                                              [4.0]
# 76                                              [4.0]
# 77                                              [4.0]
# 78                                              [4.0]
# 79                                              [4.0]
# 80                                             [24.0]
# 81   [22.0, 24.0, 18.0, 22.0, 24.0, 30.0, 18.0, 28.0]
# 82                                 [24.0, 40.0, 24.0]
# 83                                 [24.0, 40.0, 24.0]
# 84                                             [24.0]
# 85                                             [24.0]
# 86                                             [24.0]
# 87                                             [24.0]
# 88                                             [24.0]
# 89                                             [24.0]
# 90                                             [24.0]
# 91                                             [24.0]
# 92                                             [24.0]
# 93                                             [24.0]
# 94                                             [24.0]
# 95                                       [17.0, 16.0]
# 96                                             [16.0]
# 97                                             [16.0]
# 98                                        [12.0, 4.0]
# 99                                       [45.0, 33.0]
# 100                                            [24.0]
# 101                                      [24.0, 25.0]
# 102                                            [24.0]
# 103                                             [2.0]
# 104                                            [26.0]
#
#                                             voice_list  \
# 0                   [[Superius], Altus, Tenor, Bassus]
# 1                   [[Superius], Altus, Tenor, Bassus]
# 2                   [[Superius], Altus, Tenor, Bassus]
# 3                           [[Superius], Altus, Tenor]
# 4                           [[Superius], Altus, Tenor]
# 5                           [[Superius], Altus, Tenor]
# 6                           [[Superius], Altus, Tenor]
# 7                   [[Superius], Altus, Tenor, Bassus]
# 8                   [[Superius], Altus, Tenor, Bassus]
# 9                   [[Superius], Altus, Tenor, Bassus]
# 10    [[Superius], [Superius], [Superius], [Superius]]
# 11                              [Altus, Altus, Bassus]
# 12                                      [Altus, Altus]
# 13                                      [Altus, Altus]
# 14                                 [Altus, [Superius]]
# 15                                      [Altus, Tenor]
# 16                                 [[Superius], Tenor]
# 17                                 [[Superius], Tenor]
# 18                                 [[Superius], Tenor]
# 19                                 [[Superius], Tenor]
# 20                         [Altus, Bassus, [Superius]]
# 21                         [Altus, Bassus, [Superius]]
# 22                          [[Superius], Altus, Tenor]
# 23                                 [[Superius], Altus]
# 24   [Altus, [Superius], Bassus, Tenor, [Superius],...
# 25   [[Superius], Tenor, [Superius], Tenor, [Superi...
# 26              [Tenor, [Superius], Tenor, [Superius]]
# 27              [Tenor, [Superius], Tenor, [Superius]]
# 28                                      [Altus, Altus]
# 29                                 [[Superius], Tenor]
# 30                                 [[Superius], Tenor]
# 31                      [Bassus, Tenor, Bassus, Tenor]
# 32                      [Bassus, Tenor, Bassus, Tenor]
# 33                                     [Bassus, Tenor]
# 34           [Altus, [Superius], Altus, Tenor, Bassus]
# 35                                 [[Superius], Altus]
# 36                  [[Superius], Altus, Tenor, Bassus]
# 37                  [[Superius], Altus, Tenor, Bassus]
# 38                  [[Superius], Altus, Tenor, Bassus]
# 39                  [[Superius], Altus, Tenor, Bassus]
# 40          [[Superius], Altus, Tenor, Bassus, Bassus]
# 41          [[Superius], Altus, Tenor, Bassus, Bassus]
# 42                  [[Superius], Altus, Tenor, Bassus]
# 43                  [[Superius], Altus, Tenor, Bassus]
# 44                  [[Superius], Altus, Tenor, Bassus]
# 45                                 [Altus, [Superius]]
# 46                                 [Altus, [Superius]]
# 47                                 [Altus, [Superius]]
# 48                  [[Superius], Altus, Bassus, Altus]
# 49                                 [[Superius], Tenor]
# 50                                     [Altus, Bassus]
# 51                                 [[Superius], Tenor]
# 52                                 [[Superius], Tenor]
# 53                                 [[Superius], Tenor]
# 54                                     [Altus, Bassus]
# 55                     [[Superius], Tenor, [Superius]]
# 56                                     [Altus, Bassus]
# 57     [Altus, [Superius], [Superius], Bassus, Bassus]
# 58                                    [Bassus, Bassus]
# 59                                     [Tenor, Bassus]
# 60                                      [Tenor, Tenor]
# 61                                      [Tenor, Altus]
# 62                                 [[Superius], Tenor]
# 63                                 [[Superius], Tenor]
# 64                                 [[Superius], Tenor]
# 65                                 [[Superius], Tenor]
# 66                                 [[Superius], Tenor]
# 67                                 [[Superius], Tenor]
# 68                          [[Superius], Tenor, Altus]
# 69                         [[Superius], Tenor, Bassus]
# 70                                 [[Superius], Tenor]
# 71                                 [[Superius], Tenor]
# 72                                 [[Superius], Tenor]
# 73                          [[Superius], Tenor, Altus]
# 74                                 [[Superius], Tenor]
# 75                                 [[Superius], Tenor]
# 76                                 [[Superius], Tenor]
# 77                                 [[Superius], Tenor]
# 78                                     [Bassus, Tenor]
# 79                                     [Bassus, Tenor]
# 80                                 [[Superius], Tenor]
# 81   [Altus, [Superius], Tenor, Altus, [Superius], ...
# 82              [[Superius], Tenor, [Superius], Tenor]
# 83              [[Superius], Tenor, [Superius], Tenor]
# 84                                 [[Superius], Tenor]
# 85                                 [[Superius], Tenor]
# 86                                 [[Superius], Tenor]
# 87                                 [[Superius], Tenor]
# 88                                 [[Superius], Tenor]
# 89                                 [[Superius], Tenor]
# 90                                 [[Superius], Tenor]
# 91                                 [[Superius], Tenor]
# 92                                 [[Superius], Tenor]
# 93                                 [[Superius], Tenor]
# 94                                 [[Superius], Tenor]
# 95                         [Bassus, [Superius], Tenor]
# 96                                 [[Superius], Tenor]
# 97                                 [[Superius], Tenor]
# 98                         [[Superius], Bassus, Tenor]
# 99                             [Bassus, Altus, Bassus]
# 100                                [[Superius], Tenor]
# 101                        [[Superius], Tenor, Bassus]
# 102                                [[Superius], Tenor]
# 103                                    [Altus, Bassus]
# 104                                     [Altus, Tenor]
#
#                                       tone_coordinates  \
# 0    [(0.0, [Superius]), (16.0, Altus), (32.0, Teno...
# 1    [(4.0, [Superius]), (20.0, Altus), (36.0, Teno...
# 2    [(56.0, [Superius]), (72.0, Altus), (88.0, Ten...
# 3    [(62.0, [Superius]), (78.0, Altus), (94.0, Ten...
# 4    [(68.0, [Superius]), (84.0, Altus), (100.0, Te...
# 5    [(72.0, [Superius]), (88.0, Altus), (104.0, Te...
# 6    [(74.0, [Superius]), (91.0, Altus), (106.0, Te...
# 7    [(76.0, [Superius]), (92.0, Altus), (108.0, Te...
# 8    [(124.0, [Superius]), (140.0, Altus), (156.0, ...
# 9    [(130.0, [Superius]), (146.0, Altus), (162.0, ...
# 10   [(144.0, [Superius]), (147.0, [Superius]), (15...
# 11   [(184.0, Altus), (217.0, Altus), (224.0, Bassus)]
# 12                    [(188.0, Altus), (192.0, Altus)]
# 13                    [(195.0, Altus), (218.0, Altus)]
# 14               [(215.0, Altus), (222.0, [Superius])]
# 15                    [(216.0, Altus), (221.0, Tenor)]
# 16               [(244.0, [Superius]), (276.0, Tenor)]
# 17               [(248.0, [Superius]), (280.0, Tenor)]
# 18               [(252.0, [Superius]), (284.0, Tenor)]
# 19               [(256.0, [Superius]), (288.0, Tenor)]
# 20   [(256.0, Altus), (288.0, Bassus), (320.0, [Sup...
# 21   [(260.0, Altus), (292.0, Bassus), (324.0, [Sup...
# 22   [(260.0, [Superius]), (288.0, Altus), (292.0, ...
# 23               [(262.0, [Superius]), (294.0, Altus)]
# 24   [(328.0, Altus), (348.0, [Superius]), (350.0, ...
# 25   [(344.0, [Superius]), (358.0, Tenor), (360.0, ...
# 26   [(350.0, Tenor), (352.0, [Superius]), (366.0, ...
# 27   [(354.0, Tenor), (356.0, [Superius]), (370.0, ...
# 28                    [(376.0, Altus), (394.0, Altus)]
# 29               [(380.0, [Superius]), (382.0, Tenor)]
# 30               [(384.0, [Superius]), (386.0, Tenor)]
# 31   [(388.0, Bassus), (390.0, Tenor), (398.0, Bass...
# 32   [(392.0, Bassus), (394.0, Tenor), (400.0, Bass...
# 33                   [(396.0, Bassus), (398.0, Tenor)]
# 34   [(405.0, Altus), (438.0, [Superius]), (442.0, ...
# 35               [(406.0, [Superius]), (418.0, Altus)]
# 36   [(428.0, [Superius]), (432.0, Altus), (468.0, ...
# 37   [(432.0, [Superius]), (436.0, Altus), (472.0, ...
# 38   [(440.0, [Superius]), (444.0, Altus), (480.0, ...
# 39   [(444.0, [Superius]), (448.0, Altus), (484.0, ...
# 40   [(508.0, [Superius]), (524.0, Altus), (532.0, ...
# 41   [(512.0, [Superius]), (528.0, Altus), (536.0, ...
# 42   [(516.0, [Superius]), (532.0, Altus), (540.0, ...
# 43   [(520.0, [Superius]), (536.0, Altus), (544.0, ...
# 44   [(524.0, [Superius]), (540.0, Altus), (548.0, ...
# 45               [(556.0, Altus), (580.0, [Superius])]
# 46               [(558.0, Altus), (582.0, [Superius])]
# 47               [(561.0, Altus), (585.0, [Superius])]
# 48   [(600.0, [Superius]), (630.0, Altus), (654.0, ...
# 49               [(616.0, [Superius]), (640.0, Tenor)]
# 50                   [(620.0, Altus), (644.0, Bassus)]
# 51               [(620.0, [Superius]), (644.0, Tenor)]
# 52               [(622.0, [Superius]), (646.0, Tenor)]
# 53               [(624.0, [Superius]), (648.0, Tenor)]
# 54                   [(624.0, Altus), (648.0, Bassus)]
# 55   [(628.0, [Superius]), (652.0, Tenor), (670.0, ...
# 56                   [(628.0, Altus), (652.0, Bassus)]
# 57   [(664.0, Altus), (672.0, [Superius]), (676.0, ...
# 58                  [(700.0, Bassus), (716.0, Bassus)]
# 59                   [(704.0, Tenor), (727.0, Bassus)]
# 60                    [(712.0, Tenor), (726.0, Tenor)]
# 61                    [(724.0, Tenor), (756.0, Altus)]
# 62               [(748.0, [Superius]), (752.0, Tenor)]
# 63               [(752.0, [Superius]), (756.0, Tenor)]
# 64               [(756.0, [Superius]), (760.0, Tenor)]
# 65               [(796.0, [Superius]), (800.0, Tenor)]
# 66               [(800.0, [Superius]), (804.0, Tenor)]
# 67               [(804.0, [Superius]), (808.0, Tenor)]
# 68   [(816.0, [Superius]), (820.0, Tenor), (840.0, ...
# 69   [(828.0, [Superius]), (832.0, Tenor), (840.0, ...
# 70               [(844.0, [Superius]), (848.0, Tenor)]
# 71               [(856.0, [Superius]), (860.0, Tenor)]
# 72               [(864.0, [Superius]), (868.0, Tenor)]
# 73   [(868.0, [Superius]), (872.0, Tenor), (892.0, ...
# 74               [(874.0, [Superius]), (878.0, Tenor)]
# 75               [(876.0, [Superius]), (880.0, Tenor)]
# 76               [(878.0, [Superius]), (882.0, Tenor)]
# 77               [(880.0, [Superius]), (884.0, Tenor)]
# 78                   [(892.0, Bassus), (896.0, Tenor)]
# 79                   [(900.0, Bassus), (904.0, Tenor)]
# 80               [(944.0, [Superius]), (968.0, Tenor)]
# 81   [(952.0, Altus), (974.0, [Superius]), (998.0, ...
# 82   [(952.0, [Superius]), (976.0, Tenor), (1016.0,...
# 83   [(956.0, [Superius]), (980.0, Tenor), (1020.0,...
# 84               [(960.0, [Superius]), (984.0, Tenor)]
# 85               [(966.0, [Superius]), (990.0, Tenor)]
# 86               [(967.0, [Superius]), (991.0, Tenor)]
# 87               [(968.0, [Superius]), (992.0, Tenor)]
# 88               [(972.0, [Superius]), (996.0, Tenor)]
# 89             [(1008.0, [Superius]), (1032.0, Tenor)]
# 90             [(1024.0, [Superius]), (1048.0, Tenor)]
# 91             [(1030.0, [Superius]), (1054.0, Tenor)]
# 92             [(1031.0, [Superius]), (1055.0, Tenor)]
# 93             [(1032.0, [Superius]), (1056.0, Tenor)]
# 94             [(1036.0, [Superius]), (1060.0, Tenor)]
# 95   [(1063.0, Bassus), (1080.0, [Superius]), (1096...
# 96             [(1076.0, [Superius]), (1092.0, Tenor)]
# 97             [(1084.0, [Superius]), (1100.0, Tenor)]
# 98   [(1088.0, [Superius]), (1100.0, Bassus), (1104...
# 99   [(1096.0, Bassus), (1141.0, Altus), (1174.0, B...
# 100            [(1124.0, [Superius]), (1148.0, Tenor)]
# 101  [(1128.0, [Superius]), (1152.0, Tenor), (1177....
# 102            [(1132.0, [Superius]), (1156.0, Tenor)]
# 103                [(1166.0, Altus), (1168.0, Bassus)]
# 104                 [(1174.0, Altus), (1200.0, Tenor)]
#
#                          entry_intervals
# 0                         [P-8, P1, P-8]
# 1                         [P-8, P1, P-8]
# 2                         [P-8, P1, P-8]
# 3                              [P-8, P1]
# 4                              [P-8, P1]
# 5                              [P-8, P1]
# 6                              [P-8, P1]
# 7                         [P-8, P1, m-9]
# 8                         [P-8, P1, P-8]
# 9                         [P-8, P1, P-8]
# 10                        [m-2, m2, m-2]
# 11                            [P4, P-11]
# 12                                  [M2]
# 13                                  [m2]
# 14                                  [M7]
# 15                                 [M-2]
# 16                                 [P-8]
# 17                                 [P-8]
# 18                                 [P-8]
# 19                                 [P-8]
# 20                            [P-8, M13]
# 21                            [P-8, M13]
# 22                            [P-11, P4]
# 23                                [P-11]
# 24          [P5, m-10, m6, M6, M-10, M2]
# 25               [P-5, m6, P-5, M6, M-9]
# 26                         [M6, P-5, M6]
# 27                         [M6, P-5, m6]
# 28                                 [P-4]
# 29                                 [P-5]
# 30                                 [P-5]
# 31                         [m6, m-7, m6]
# 32                         [M6, M-7, M6]
# 33                                  [M6]
# 34                   [M9, P-5, P-4, P-5]
# 35                                 [M-6]
# 36                       [P-5, P-4, P-5]
# 37                       [P-5, P-4, P-5]
# 38                       [P-5, P-4, P-5]
# 39                       [P-5, P-4, P-5]
# 40                   [P-5, P-4, P-5, P1]
# 41                   [P-5, P-4, P-5, P1]
# 42                       [P-5, P-4, P-5]
# 43                       [P-5, P-4, P-5]
# 44                       [P-5, P-4, P-5]
# 45                                  [M9]
# 46                                  [M9]
# 47                                  [m9]
# 48                        [P-4, P-8, m6]
# 49                                 [P-8]
# 50                                 [P-8]
# 51                                 [P-8]
# 52                                 [P-8]
# 53                                 [P-8]
# 54                                 [P-8]
# 55                             [P-8, P8]
# 56                                 [P-8]
# 57                   [P4, m-2, M-10, P1]
# 58                                  [P1]
# 59                                 [M-9]
# 60                                 [m-2]
# 61                                  [M2]
# 62                                 [P-5]
# 63                                 [P-5]
# 64                                 [P-5]
# 65                                 [P-5]
# 66                                 [P-5]
# 67                                 [P-5]
# 68                             [P-5, P4]
# 69                            [P-5, M-3]
# 70                                 [P-5]
# 71                                 [P-5]
# 72                                 [P-5]
# 73                             [P-5, M2]
# 74                                 [P-5]
# 75                                 [P-5]
# 76                                 [P-5]
# 77                                 [P-5]
# 78                                  [m6]
# 79                                  [m6]
# 80                                 [P-8]
# 81   [P5, P-8, P4, P5, P-8, P-5, M6, m2]
# 82                        [P-8, P8, P-8]
# 83                        [P-8, P8, P-8]
# 84                                 [P-8]
# 85                                 [P-8]
# 86                                 [P-8]
# 87                                 [P-8]
# 88                                 [P-8]
# 89                                 [P-8]
# 90                                 [P-8]
# 91                                 [P-8]
# 92                                 [P-8]
# 93                                 [P-8]
# 94                                 [P-8]
# 95                            [P11, P-8]
# 96                                 [P-8]
# 97                                 [P-8]
# 98                            [m-14, m7]
# 99                             [M7, M-7]
# 100                                [P-8]
# 101                           [P-8, P-8]
# 102                                [P-8]
# 103                                [M-3]
# 104                                 [m3]

# %% [markdown]
# ### Get Presentation Types with Interact

# %%
@interact
def get_points(duration_type=['real', 'incremental'], interval_type=["generic", "semitone"], match_type=["close", "exact"], min_exact_matches=[2, 3, 4, 5, 6], min_close_matches=[2, 3, 4, 5, 6], close_distance=[1, 2, 3, 4, 5, 6], vector_size=[3, 2, 4, 5, 6, 7], increment_size=[4, 2, 1], forward_gap_limit=[40, 20, 10], backward_gap_limit=[40, 20, 10], min_sum_durations=[10, 5, 20], max_sum_durations=[30, 50, 15], offset_difference_limit=[500, 100, 50]):
    points = piece.getPoints(duration_type=duration_type, interval_type=interval_type, match_type=match_type, min_exact_matches=min_exact_matches, min_close_matches=min_close_matches, close_distance=close_distance, vector_size=vector_size, increment_size=increment_size, forward_gap_limit=forward_gap_limit, backward_gap_limit=backward_gap_limit, min_sum_durations=min_sum_durations, max_sum_durations=max_sum_durations, offset_difference_limit=offset_difference_limit)
    return points
    points
# Out:
# interactive(children=(Dropdown(description='duration_type', options=('real', 'incremental'), value='real'), Dr…

# %%
corpus = CorpusBase(['https://crimproject.org/mei/CRIM_Mass_0014_3.mei',
                             'https://crimproject.org/mei/CRIM_Model_0009.mei'])
func = ImportedPiece.getPoints  # <- NB there are no parentheses here
list_of_dfs = corpus.batch(func)
