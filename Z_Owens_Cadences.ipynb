# %% [markdown]
# # CRIM Intervals:  Cadences
#
# ### What Can You Do With this Notebook?
#
# * Find **cadences**, reporting type, tone, cadential voice functions (roles) and other information about the piece
# * Count and analyze distribution of cadences
#
# #### View Score Excerpts with Verovio in the NB
#
#
# * It is also possible to display the results of the Cadence
#     classifier in the Notebook with Verovio. Each excerpt is
#     two measures long:  the measure of the final tone of the cadence
#     and the previous measure.
#
# * The function also displays metadata about each excerpt, drawn from the
#     cadence results dataframe:  piece ID, composer, title, measures, type of
#     cadence, beat of the bar in which the final tone is heard, and evaded
#     status.
#
# * View the cadence table:
#
# > `piece.cadences()`
#
# * To show the cadences with Verovio, then just:
#
# >`piece.verovioCadences()`
#
# * Note that pink warning messages in the output can be ignored!
#
# * If you prefer to create the cadence table, then filter it in some way before passing to Verovio:
#
# >`cadences = piece.cadences()`
#
# (After filtering):
#
# > `piece.verovioCadences(cadences)`

# %%
import intervals
from intervals import * 
from intervals import main_objs
import intervals.visualizations as viz
import pandas as pd
import re
import altair as alt 
from ipywidgets import interact
from pandas.io.json import json_normalize
from pyvis.network import Network
import glob as glob
import os
from IPython.display import SVG
from pathlib import Path
import verovio
MYDIR = ("saved_csv")
CHECK_FOLDER = os.path.isdir(MYDIR)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MYDIR)
    print("created folder : ", MYDIR)

else:
    print(MYDIR, "folder already exists.")
    
MUSDIR = ("Music_Files")
CHECK_FOLDER = os.path.isdir(MUSDIR)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MUSDIR)
    print("created folder : ", MUSDIR)

else:
    print(MUSDIR, "folder already exists.")
# Out:
# saved_csv folder already exists.
# Music_Files folder already exists.

# %%
def verovio_print_piece(piece):
    # check path and import MEI or XML

    if piece.path.startswith('Music_Files/'):
        text_file = open(piece.path, "r")
        fetched_mei_string = text_file.read()
    else:
        response = requests.get(piece.path)
        fetched_mei_string = response.text
    # start the verovio toolkit and load the file there
    tk = verovio.toolkit()
    tk.loadData(fetched_mei_string)
    tk.setScale(30)
    tk.setOption( "pageHeight", "1500" )
    tk.setOption( "pageWidth", "3000" )


    tk.redoLayout()
    # get the number of pages and display the music
    count = tk.getPageCount()
    for c in range(1, count + 1):
        music = tk.renderToSVG(c)
        print("File Name: ", piece.file_name)
        print(piece.metadata['composer'])
        print(piece.metadata['title'])
        display(HTML(music))

# %% [markdown]
# ## B. Importing a Piece

# %%
def verovio_MorleyCadences(piece):
        """
    

        """
        if piece.path.startswith('Music_Files/'):
            text_file = open(piece.path, "r")
            fetched_mei_string = text_file.read()
        else:
            response = requests.get(piece.path)
            fetched_mei_string = response.text
        tk = verovio.toolkit()
        tk.loadData(fetched_mei_string)
        tk.setScale(30)
        tk.setOption( "pageHeight", "1500" )
        tk.setOption( "pageWidth", "3000" )
        morleyCadences = piece.morleyCadences()
        morleyCadences = piece.detailIndex(morleyCadences).reset_index()
        for cad in morleyCadences.index:
            c_meas = morleyCadences.loc[cad]["Measure"]
            c_beat = morleyCadences.loc[cad]["Beat"]
            low = c_meas-1
            high = c_meas
            mr = str(low) + "-" + str(high)
            mdict = {'measureRange': mr}

            # select verovio measures and redo layout
            tk.select(str(mdict))
            tk.redoLayout()

            # get the number of pages and display the music
            print("Results:")
            count = tk.getPageCount()
            for c in range(1, count + 1):
                music = tk.renderToSVG(c)
                print("File Name: ", piece.file_name)
                print(piece.metadata['composer'])
                print(piece.metadata['title'])
                print("Cadence End Measure:", c_meas)
                print("Beat: ", c_beat)
                display(HTML(music))

# %% [markdown]
# ### B.1 Import a Piece and Check Title

# %%
# Select a prefix:
# prefix = 'https://crimproject.org/mei/'
prefix = 'Music_Files/'
# just add the CRIM Piece ID here
mei_file = 'Morley_1597_074_03.musicxml'
# combine strings and import
url = prefix + mei_file
piece = importScore(url)
print(piece.metadata)
# Out:
# Previously imported piece detected.
# {'title': 'Morley_1597_074_03', 'composer': 'Morley'}

# %%
# GET EVERYTHING AND PRINT VEROVIO
# for name in glob.glob('Music_Files/*'):
#     piece = importScore(name)
#     verovio_print_piece(piece)

# %% [markdown]
# ### Cadential Voice Functions--What they Mean

# %%
# print(ImportedPiece.cvfs.__doc__)

# %% [markdown]
# ## Select Number of Voices and Import

# %%
number_voices = 3
corpus_list = []
for name in glob.glob('Music_Files/*'):
    piece = importScore(name)
    notes = piece.notes()
    if len(notes.columns) == number_voices:
        corpus_list.append(name)
        print(name  + 'has been added to your list')
#     else:
#         print('sorry, ' + name  + 'is not a three-voice piece')

corpus = CorpusBase(corpus_list)
# Out:
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_127_2.musicxmlhas been added to your list
# Previously imported piece detected.
# Music_Files/Morley_1597_127_3.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_127_8.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_128_01.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_129_6.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_128_06.musicxmlhas been added to your list
# Previously imported piece detected.
# Music_Files/Morley_1597_128_07.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_129_1.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_128_11.musicxmlhas been added to your list
# Previously imported piece detected.
# Music_Files/Morley_1597_128_10.musicxmlhas been added to your list
# Previously imported piece detected.
# Music_Files/Morley_1597_127_5.musicxmlhas been added to your list
# Previously imported piece detected.
# Music_Files/Morley_1597_127_4.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_128_08.musicxmlhas been added to your list
# Previously imported piece detected.
# Music_Files/Morley_1597_128_09.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_068.musicxmlhas been added to your list
# Previously imported piece detected.
# Music_Files/Morley_1597_128_02.musicxmlhas been added to your list
# Previously imported piece detected.
# Music_Files/Morley_1597_128_03.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_129_5.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_129_4.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_127_1.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_127_6.musicxmlhas been added to your list
# Previously imported piece detected.
# Music_Files/Morley_1597_127_7.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_194.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_128_05.musicxmlhas been added to your list
# Previously imported piece detected.
# Music_Files/Morley_1597_128_04.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Music_Files/Morley_1597_129_2.musicxmlhas been added to your list
# Previously imported piece detected.
# Music_Files/Morley_1597_129_3.musicxmlhas been added to your list
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.

# %% [markdown]
# ### Classify the Cadences as Corpus
#
# Here is what the code should look like:
#
# > func = ImportedPiece.cadences
# list_of_dfs = corpus.batch(func=func, kwargs={'keep_keys': True}, metadata=True)
# cadence_results = pd.concat(list_of_dfs, ignore_index=False)
# cadence_results['Validation'] = ""
# cadence_results['Comments'] = ""
# col_list = ['Composer', 'Title', 'Measure', 'Beat', 'Pattern', 'Key', 'CadType', 'Tone','CVFs',
#                 'LeadingTones', 'Sounding', 'Low','RelLow','RelTone',
#                 'Progress','SinceLast','ToNext', 'Validation', 'Comments']
# cadence_results = combined_df[col_list]
# cadence_results

# %% [markdown]
# ### The usual Cadence Tool

# %%
func = ImportedPiece.cadences
list_of_dfs = corpus.batch(func=func)
# func2 = ImportedPiece.detailIndex
# list_dfs_det = corpus.batch(func=func2, kwargs={'df': list_of_dfs, 'offset' : True}, metadata=True)
cadence_results = pd.concat(list_of_dfs, ignore_index=False)

cadence_results = cadence_results.sort_values(['Title', 'Progress'])
cadence_results = cadence_results.drop(['Low', 'RelLow', 'TSig', 'SinceLast', 'ToNext'], axis=1)
cadence_results.reset_index(inplace=True)
cadence_results.rename(columns = {'index':'Offset'}, inplace=True)
col_list = ['Composer', 'Title', 'Measure', 'Beat', 'Offset', 'Progress', 'CadType', 'Tone','CVFs', 'LeadingTones', 'Sounding']
cadence_results = cadence_results[col_list]
cadence_results.head()
# Out:
#   Composer            Title  Measure  Beat  Offset  Progress        CadType  \
# 0   Morley  Morley_1597_068        7   3.0    52.0  0.388060      Authentic
# 1   Morley  Morley_1597_068       10   3.0    76.0  0.567164      Authentic
# 2   Morley  Morley_1597_068       13   1.0    96.0  0.716418      Authentic
# 3   Morley  Morley_1597_068       14   1.0   104.0  0.776119  Clausula Vera
# 4   Morley  Morley_1597_068       15   1.0   112.0  0.835821  Clausula Vera
#
#   Tone CVFs  LeadingTones  Sounding
# 0    G  TCB           1.0       3.0
# 1    G  tCB           1.0       3.0
# 2    A  TCB           1.0       3.0
# 3    G   CT           1.0       3.0
# 4    D   CT           0.0       3.0

# %% [markdown]
# ### Summarize by Tone, Type, and Functions
#
# * You can easily summarize the data in various ways:
#
#     >`cadences.groupby(['Tone', 'CadType', 'CVFs']).size().reset_index(name='counts')`

# %%
cadence_summary = cadence_results.groupby(['Title', 'Tone', 'CadType', 'CVFs']).size().reset_index(name='counts')
cadence_summary.to_csv('Morley_a3_Cad_Summary_Table.csv')
cadence_summary
# Out:
#                  Title Tone                  CadType CVFs  counts
# 0      Morley_1597_068    A                Authentic  TCB       1
# 1      Morley_1597_068    D            Clausula Vera   CT       1
# 2      Morley_1597_068    G                Authentic  TCB       2
# 3      Morley_1597_068    G                Authentic  tCB       1
# 4      Morley_1597_068    G            Clausula Vera   CT       2
# 5    Morley_1597_127_3    C                Authentic  CtB       1
# 6    Morley_1597_127_3    C            Clausula Vera   CT       1
# 7    Morley_1597_127_3    G                Authentic  tCB       1
# 8    Morley_1597_127_4    G     Evaded Clausula Vera   tC       1
# 9    Morley_1597_127_7    G     Evaded Clausula Vera   tC       1
# 10  Morley_1597_128_02    G            Clausula Vera   CT       1
# 11  Morley_1597_128_03    G                Authentic   CB       1
# 12  Morley_1597_128_06    G                Authentic  tCB       1
# 13  Morley_1597_128_07    G                Authentic  tCB       1
# 14  Morley_1597_128_08    G     Evaded Clausula Vera   tC       1
# 15  Morley_1597_128_10    G     Evaded Clausula Vera   tC       1
# 16  Morley_1597_128_11    G  Abandoned Clausula Vera   zC       1
# 17  Morley_1597_128_11    G     Evaded Clausula Vera   tC       1
# 18   Morley_1597_129_1    C            Clausula Vera   CT       1
# 19   Morley_1597_129_2    C            Clausula Vera   CT       1
# 20   Morley_1597_129_3    C     Evaded Clausula Vera   tC       1
# 21   Morley_1597_129_4    C                Authentic  CtB       1
# 22   Morley_1597_129_5    C            Clausula Vera   CT       1
# 23   Morley_1597_129_6    G                Authentic  CtB       1
# 24     Morley_1597_194    F                Authentic  CtB       2
# 25     Morley_1597_194    F                Authentic  tCB       2
# 26     Morley_1597_194    F     Evaded Clausula Vera   Ct       1

# %% [markdown]
# ### C.4.  Display Results with Verovio
#
# #### For the Corpus
# >number_voices = 3
# corpus_list = []
# for name in glob.glob('Music_Files/*'):
#     piece = importScore(name)
#     notes = piece.notes()
#     if len(notes.columns) == number_voices:
#         piece.verovioCadences()
#
# #### For Just One Piece
#
# >prefix = 'Music_Files/'
# music_file = 'Morley_1597_074_03.musicxml'
# url = prefix + music_file
# piece = importScore(url)
# print(piece.metadata)

# %%
# FOR ONE PIECE
prefix = 'Music_Files/'
music_file = 'Morley_1597_074_03.musicxml'
url = prefix + music_file
piece = importScore(url)
# piece.verovioCadences()
# Out:
# Previously imported piece detected.

# %%
## Print the Whole Corpus according to Voice Filter
## Note you must repeat the import here
number_voices = 5
corpus_list = []
for name in glob.glob('Music_Files/*'):
    piece = importScore(name)
    notes = piece.notes()
    if len(notes.columns) == number_voices:
        piece.verovioCadences()

# %% [markdown]
# ### The Morley Cadences as Table

# %%
func = ImportedPiece.morleyCadences
list_of_dfs = corpus.batch(func=func, metadata=True)
func2 = ImportedPiece.detailIndex
list_dfs_det = corpus.batch(func=func2, kwargs={'progress': True, 'offset': True,'df': list_of_dfs}, metadata=True)
morleyCadence_results = pd.concat(list_dfs_det, ignore_index=False)
morleyCadence_results = morleyCadence_results.fillna(' ')
morleyCadence_results = morleyCadence_results.reset_index()
col_list = ['Composer', 'Title', 'Measure', 'Beat', 'Offset', 'Progress', '1', '2', '3']
morleyCadence_results = morleyCadence_results[col_list]

morleyCadence_results= morleyCadence_results.sort_values(["Title", 'Progress'])
morleyCadence_results
# Out:
#    Composer               Title  Measure      Beat  Offset  Progress  \
# 17   Morley     Morley_1597_068        3  1.000000    16.0  0.119403
# 18   Morley     Morley_1597_068        4  1.000000    24.0  0.179104
# 19   Morley     Morley_1597_068        7  1.000000    48.0  0.358209
# 20   Morley     Morley_1597_068        7  2.000000    50.0  0.373134
# 21   Morley     Morley_1597_068        8  1.000000    56.0  0.417910
# 22   Morley     Morley_1597_068        9  3.000000    68.0  0.507463
# 23   Morley     Morley_1597_068       10  3.000000    76.0  0.567164
# 24   Morley     Morley_1597_068       12  4.000000    94.0  0.701493
# 25   Morley     Morley_1597_068       13  1.000000    96.0  0.716418
# 26   Morley     Morley_1597_068       14  1.000000   104.0  0.776119
# 27   Morley     Morley_1597_068       15  1.000000   112.0  0.835821
# 28   Morley     Morley_1597_068       15  3.000000   116.0  0.865672
# 29   Morley     Morley_1597_068       17  3.000000   132.0  0.985075
# 0    Morley   Morley_1597_127_3        4  1.000000    24.0  0.428571
# 1    Morley   Morley_1597_127_3        6  1.000000    40.0  0.714286
# 2    Morley   Morley_1597_127_3        8  1.000000    56.0  1.000000
# 16   Morley   Morley_1597_127_4        2  1.000000     8.0  1.000000
# 15   Morley   Morley_1597_127_5        2  1.000000     8.0  1.000000
# 34   Morley   Morley_1597_127_6        2  1.000000     8.0  1.000000
# 35   Morley   Morley_1597_127_7        3  1.000000    16.0  1.000000
# 3    Morley  Morley_1597_128_01        3  1.000000    16.0  0.800000
# 4    Morley  Morley_1597_128_01        3  2.000000    18.0  0.900000
# 30   Morley  Morley_1597_128_02        4  3.000000    28.0  1.000000
# 31   Morley  Morley_1597_128_03        2  1.000000     8.0  1.000000
# 47   Morley  Morley_1597_128_05        2  1.000000     8.0  0.666667
# 6    Morley  Morley_1597_128_06        2  3.000000    12.0  0.500000
# 7    Morley  Morley_1597_128_06        3  3.000000    20.0  0.833333
# 8    Morley  Morley_1597_128_06        4  1.000000    24.0  1.000000
# 9    Morley  Morley_1597_128_07        2  1.000000     8.0  1.000000
# 11   Morley  Morley_1597_128_11        1  2.666667    10.0  0.416667
# 12   Morley  Morley_1597_128_11        2  3.000000    16.0  0.666667
# 13   Morley  Morley_1597_128_11        2  4.000000    18.0  0.750000
# 14   Morley  Morley_1597_128_11        3  3.000000    24.0  1.000000
# 10   Morley   Morley_1597_129_1        2  3.000000    12.0  1.000000
# 48   Morley   Morley_1597_129_2        1  4.000000     6.0  0.750000
# 49   Morley   Morley_1597_129_3        2  3.000000    12.0  1.000000
# 33   Morley   Morley_1597_129_4        2  3.000000    12.0  1.000000
# 32   Morley   Morley_1597_129_5        2  1.000000     8.0  1.000000
# 5    Morley   Morley_1597_129_6        3  1.000000    16.0  1.000000
# 36   Morley     Morley_1597_194        2  3.000000    12.0  0.078947
# 37   Morley     Morley_1597_194        3  1.000000    16.0  0.105263
# 38   Morley     Morley_1597_194        4  4.000000    30.0  0.197368
# 39   Morley     Morley_1597_194        5  3.000000    36.0  0.236842
# 40   Morley     Morley_1597_194        8  3.000000    60.0  0.394737
# 41   Morley     Morley_1597_194        8  4.000000    62.0  0.407895
# 42   Morley     Morley_1597_194       11  1.000000    80.0  0.526316
# 43   Morley     Morley_1597_194       11  3.000000    84.0  0.552632
# 44   Morley     Morley_1597_194       15  1.000000   112.0  0.736842
# 45   Morley     Morley_1597_194       18  1.000000   136.0  0.894737
# 46   Morley     Morley_1597_194       20  1.000000   152.0  1.000000
#
#                  1               2               3
# 17  Morley Cadence  Morley Cadence
# 18  Morley Cadence
# 19  Morley Cadence
# 20                  Morley Cadence
# 21                  Morley Cadence
# 22  Morley Cadence
# 23  Morley Cadence  Morley Cadence
# 24  Morley Cadence
# 25                  Morley Cadence
# 26                  Morley Cadence
# 27                  Morley Cadence
# 28  Morley Cadence
# 29                  Morley Cadence
# 0   Morley Cadence  Morley Cadence
# 1                                   Morley Cadence
# 2   Morley Cadence
# 16  Morley Cadence  Morley Cadence
# 15                  Morley Cadence
# 34                  Morley Cadence
# 35  Morley Cadence  Morley Cadence
# 3   Morley Cadence
# 4                   Morley Cadence
# 30                  Morley Cadence
# 31                  Morley Cadence
# 47                  Morley Cadence
# 6                   Morley Cadence
# 7   Morley Cadence
# 8                   Morley Cadence
# 9                   Morley Cadence
# 11  Morley Cadence
# 12                                  Morley Cadence
# 13                  Morley Cadence
# 14                                  Morley Cadence
# 10  Morley Cadence
# 48                  Morley Cadence
# 49                  Morley Cadence
# 33  Morley Cadence
# 32  Morley Cadence
# 5   Morley Cadence  Morley Cadence
# 36  Morley Cadence                  Morley Cadence
# 37  Morley Cadence
# 38  Morley Cadence  Morley Cadence
# 39  Morley Cadence
# 40                  Morley Cadence
# 41  Morley Cadence
# 42                  Morley Cadence  Morley Cadence
# 43                  Morley Cadence
# 44                  Morley Cadence
# 45  Morley Cadence  Morley Cadence
# 46  Morley Cadence  Morley Cadence

# %% [markdown]
# ### Print Morley Cadences

# %%
## Print the Whole Corpus according to Voice Filter
## Note you must repeat the import here
number_voices = 3
corpus_list = []
for name in glob.glob('Music_Files/*'):
    piece = importScore(name)
    notes = piece.notes()
    if len(notes.columns) == number_voices:
        verovio_MorleyCadences(piece)
# Out:
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Results:
# File Name:  Morley_1597_127_3
# Morley
# Morley_1597_127_3
# Cadence End Measure: 4
# Beat:  1.0
# <svg width="900px" height="450px" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:mei="http://www.music-encoding.org/ns/mei" overflow="visible">
#    <desc>Engraved by Verovio 3.10.0-845ab54</desc>
#    <defs>
#       <symbol id="E004-cxe8ky" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 0h53c30 0 59 -1 83 -5c206 -95 258 -264 263 -271c0 -1 -14 -7 -15 -6c-88 154 -251 170 -321 170c-1 0 -63 1 -63 1v111z" />
#       </symbol>
#       <symbol id="E003-cxe8ky" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 -0v111c0 0 62 1 63 1c70 0 233 16 321 170c1 1 15 -5 15 -6c-5 -7 -57 -176 -263 -271c-24 -4 -53 -5 -83 -5h-53z" />
#       </symbol>
#       <symbol id="E052-cxe8ky" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M382 117c-72 -2 -128 -47 -128 -120v-7c2 -46 43 -99 75 -115c-3 -2 -7 -5 -10 -10c-70 33 -116 88 -123 172v11c0 68 44 126 88 159c23 17 49 29 78 36l-29 170c-21 -13 -52 -37 -92 -73c-50 -44 -86 -84 -109 -119c-45 -69 -67 -130 -67 -182v-13 c5 -68 35 -127 93 -176s125 -73 203 -73c25 0 50 3 75 9c-19 111 -36 221 -54 331zM406 119l54 -326c73 25 110 78 110 161c0 7 0 15 -1 23c-7 95 -57 142 -151 142h-12zM461 939c-95 0 -135 -175 -135 -286c0 -24 2 -48 5 -71c50 39 92 82 127 128c40 53 60 100 60 140v8 c-4 53 -22 81 -55 81h-2zM441 -245c-23 -4 -48 -6 -76 -6c-59 0 -102 7 -130 20c-88 42 -150 93 -187 154c-26 44 -43 103 -48 176c0 6 -1 13 -1 19c0 54 15 111 45 170c29 57 65 106 110 148s96 85 153 127c-3 16 -8 46 -13 92c-4 43 -5 73 -5 89c0 117 16 172 69 257 c34 54 64 82 89 82c21 0 43 -30 69 -92s39 -115 41 -159v-15c0 -109 -21 -162 -67 -241c-13 -20 -63 -90 -98 -118c-13 -9 -25 -19 -37 -29l31 -181c8 1 18 2 28 2c58 0 102 -12 133 -35c59 -43 92 -104 98 -184c1 -7 1 -15 1 -22c0 -123 -87 -209 -181 -248 c8 -57 17 -110 25 -162c5 -31 6 -58 6 -80c0 -30 -5 -53 -14 -70c-25 -46 -59 -77 -102 -92c21 -1 85 -13 85 -60c0 -35 -22 -43 -31 -50c-6 -5 -8 -10 -8 -16s0 -11 4 -16c6 -11 9 -22 9 -34c0 -27 -18 -53 -46 -65c-11 -4 -27 -6 -41 -6c-34 0 -82 21 -90 58 c-1 5 -2 8 -2 12c0 28 25 57 51 66c4 1 6 2 6 5c0 2 -1 3 -2 3c-11 13 -16 27 -16 41c0 21 11 40 30 51h-5c-5 0 -11 -1 -16 -1c-37 0 -72 10 -108 27c-50 24 -77 59 -80 105v11c0 29 7 55 20 76c18 28 45 42 79 44h6c49 0 93 -42 97 -87v-9c0 -51 -34 -86 -105 -106 c17 -24 51 -36 102 -36c62 0 116 43 140 85c9 16 13 41 13 74c0 20 -1 42 -5 67c-8 53 -18 106 -26 159zM315 -781c-3 -2 -6 -5 -7 -8c-6 -8 -10 -19 -10 -30c0 -2 0 -4 1 -7c7 -32 34 -52 53 -52c20 0 37 20 37 36c0 5 -2 9 -4 14c-5 13 -14 24 -25 34c-6 5 -11 10 -17 14 c-4 2 -9 6 -14 6c-6 0 -11 -3 -14 -7zM349 -685c0 -14 10 -25 18 -34c8 -8 16 -18 26 -25c5 -2 10 -4 13 -4c17 0 22 30 23 48c0 9 -3 20 -9 26c-8 9 -23 14 -40 14c-15 -1 -29 -8 -31 -25z" />
#       </symbol>
#       <symbol id="E062-cxe8ky" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M582 -120c0 32 26 58 58 58s58 -26 58 -58s-26 -58 -58 -58s-58 26 -58 58zM582 120c0 32 26 58 58 58s58 -26 58 -58s-26 -58 -58 -58s-58 26 -58 58zM158 96c51 0 73 -14 88 -49l16 -39c0 -17 -2 -30 -7 -40c-3 -11 -10 -21 -19 -31c-17 -18 -49 -43 -84 -43 c-55 0 -77 13 -112 44c-24 21 -35 55 -35 100c0 46 14 81 32 112c30 52 71 79 137 93l36 6l26 2c154 0 235 -68 274 -182c11 -32 18 -68 18 -107c0 -103 -26 -182 -68 -250c-89 -145 -234 -230 -412 -288l-30 -5c-9 0 -14 3 -14 8c3 10 5 11 10 16c35 15 70 30 96 44l78 43 c96 57 162 136 197 258c9 33 17 60 22 100c3 22 5 35 6 39c-7 69 -16 115 -23 140s-4 22 -16 40c-8 12 -19 23 -31 34c-24 21 -62 44 -118 44c-48 0 -84 -8 -113 -28c-28 -19 -42 -44 -42 -73v-16c2 -5 3 -9 4 -11c24 22 52 39 84 39z" />
#       </symbol>
#       <symbol id="E082-cxe8ky" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M124 -185c-18 0 -55 -14 -65 -65h-36l-3 30c0 25 6 45 18 63c11 19 22 30 39 43l121 82l37 29c15 11 27 29 38 54c12 24 18 47 18 70c0 40 -19 88 -94 88c-25 0 -32 0 -50 -8c-14 -5 -23 -12 -26 -22c3 -9 7 -15 10 -18l24 -17c12 -7 17 -11 27 -21c5 -7 7 -16 7 -27 c0 -12 0 -57 -79 -74c-30 0 -76 26 -76 94c0 66 81 135 197 135c72 0 181 -32 181 -150c0 -53 -32 -95 -113 -133l-91 -41c-26 -11 -45 -23 -57 -37l49 7c84 0 115 -41 148 -41c20 0 33 20 39 61h35c0 -152 -68 -168 -114 -168c-17 0 -65 0 -79 7h10l-28 17 c-49 37 -69 40 -87 42z" />
#       </symbol>
#       <symbol id="E084-cxe8ky" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M20 -78c84 97 114 180 134 329h170c-13 -32 -82 -132 -99 -151l-84 -97c-33 -36 -59 -63 -80 -81h162v102l127 123v-225h57v-39h-57v-34c0 -43 19 -65 57 -65v-34h-244v36c48 0 60 26 60 70v27h-203v39z" />
#       </symbol>
#       <symbol id="E0A2-cxe8ky" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M198 133c102 0 207 -45 207 -133c0 -92 -98 -133 -207 -133c-101 0 -198 46 -198 133c0 88 93 133 198 133zM293 -21c0 14 -3 29 -8 44c-7 20 -18 38 -33 54c-20 21 -43 31 -68 31l-20 -2c-15 -5 -27 -14 -36 -28c-4 -9 -6 -17 -8 -24s-3 -16 -3 -27c0 -15 3 -34 9 -57 s18 -41 34 -55c15 -15 36 -23 62 -23c4 0 10 1 18 2c19 5 32 15 40 30s13 34 13 55z" />
#       </symbol>
#       <symbol id="E0A3-cxe8ky" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M278 64c0 22 -17 39 -43 39c-12 0 -26 -3 -41 -10c-85 -43 -165 -94 -165 -156c5 -25 15 -32 49 -32c67 11 200 95 200 159zM0 -36c0 68 73 174 200 174c66 0 114 -39 114 -97c0 -84 -106 -173 -218 -173c-64 0 -96 32 -96 96z" />
#       </symbol>
#       <symbol id="E262-cxe8ky" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M136 186v169h17v-164l44 14v-91l-44 -14v-165l44 12v-91l-44 -13v-155h-17v150l-76 -22v-155h-17v149l-43 -13v90l43 14v167l-43 -14v92l43 13v169h17v-163zM60 73v-167l76 22v168z" />
#       </symbol>
#    </defs>
#    <style type="text/css">g.page-margin{font-family:Times;} g.ending, g.fing, g.reh, g.tempo{font-weight:bold;} g.dir, g.dynam, g.mNum{font-style:italic;} g.label{font-weight:normal;}</style>
#    <svg class="definition-scale" color="black" viewBox="0 0 30000 15000">
#       <g class="page-margin" transform="translate(500, 500)">
#          <g id="srjpoje" class="score pageMilestone">
#             <title class="labelAttr">[selectionScore]</title>
#          </g>
#          <g id="ss4ytih" class="system">
#             <path d="M824 540 L824 4860" stroke="currentColor" stroke-width="27" />
#             <g id="gux44ye" class="grpSym">
#                <use xlink:href="#E003-cxe8ky" x="631" y="489" height="720px" width="720px" />
#                <use xlink:href="#E004-cxe8ky" x="631" y="4911" height="720px" width="720px" />
#                <rect x="631" y="483" height="4434" width="90" />
#             </g>
#             <g id="lf63dza" class="label">
#                <text x="451" y="990" text-anchor="end" font-size="0px">
#                   <tspan id="tk6mwz8" class="text">
#                      <tspan font-size="405px" class="text">T1</tspan>
#                   </tspan>
#                </text>
#             </g>
#             <g id="l5dhdap" class="label">
#                <text x="451" y="2790" text-anchor="end" font-size="0px">
#                   <tspan id="tdnd66e" class="text">
#                      <tspan font-size="405px" class="text">T2</tspan>
#                   </tspan>
#                </text>
#             </g>
#             <g id="l63ldxd" class="label">
#                <text x="451" y="4590" text-anchor="end" font-size="0px">
#                   <tspan id="tmc5pv1" class="text">
#                      <tspan font-size="405px" class="text">B</tspan>
#                   </tspan>
#                </text>
#             </g>
#             <g id="mryqdy9" class="measure">
#                <g id="myqw4n7" class="mNum autogenerated">
#                   <text x="811" y="232" text-anchor="middle" font-size="0px">
#                      <tspan id="tcg9h9s" class="text">
#                         <tspan font-size="324px" class="text">3</tspan>
#                      </tspan>
#                   </text>
#                </g>
#                <g id="sl70bbw" class="staff">
# Results:
# File Name:  Morley_1597_127_3
# Morley
# Morley_1597_127_3
# Cadence End Measure: 6
# Beat:  1.0
# <svg width="900px" height="450px" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:mei="http://www.music-encoding.org/ns/mei" overflow="visible">
#    <desc>Engraved by Verovio 3.10.0-845ab54</desc>
#    <defs>
#       <symbol id="E004-jblct5" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 0h53c30 0 59 -1 83 -5c206 -95 258 -264 263 -271c0 -1 -14 -7 -15 -6c-88 154 -251 170 -321 170c-1 0 -63 1 -63 1v111z" />
#       </symbol>
#       <symbol id="E003-jblct5" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 -0v111c0 0 62 1 63 1c70 0 233 16 321 170c1 1 15 -5 15 -6c-5 -7 -57 -176 -263 -271c-24 -4 -53 -5 -83 -5h-53z" />
#       </symbol>
#       <symbol id="E052-jblct5" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M382 117c-72 -2 -128 -47 -128 -120v-7c2 -46 43 -99 75 -115c-3 -2 -7 -5 -10 -10c-70 33 -116 88 -123 172v11c0 68 44 126 88 159c23 17 49 29 78 36l-29 170c-21 -13 -52 -37 -92 -73c-50 -44 -86 -84 -109 -119c-45 -69 -67 -130 -67 -182v-13 c5 -68 35 -127 93 -176s125 -73 203 -73c25 0 50 3 75 9c-19 111 -36 221 -54 331zM406 119l54 -326c73 25 110 78 110 161c0 7 0 15 -1 23c-7 95 -57 142 -151 142h-12zM461 939c-95 0 -135 -175 -135 -286c0 -24 2 -48 5 -71c50 39 92 82 127 128c40 53 60 100 60 140v8 c-4 53 -22 81 -55 81h-2zM441 -245c-23 -4 -48 -6 -76 -6c-59 0 -102 7 -130 20c-88 42 -150 93 -187 154c-26 44 -43 103 -48 176c0 6 -1 13 -1 19c0 54 15 111 45 170c29 57 65 106 110 148s96 85 153 127c-3 16 -8 46 -13 92c-4 43 -5 73 -5 89c0 117 16 172 69 257 c34 54 64 82 89 82c21 0 43 -30 69 -92s39 -115 41 -159v-15c0 -109 -21 -162 -67 -241c-13 -20 -63 -90 -98 -118c-13 -9 -25 -19 -37 -29l31 -181c8 1 18 2 28 2c58 0 102 -12 133 -35c59 -43 92 -104 98 -184c1 -7 1 -15 1 -22c0 -123 -87 -209 -181 -248 c8 -57 17 -110 25 -162c5 -31 6 -58 6 -80c0 -30 -5 -53 -14 -70c-25 -46 -59 -77 -102 -92c21 -1 85 -13 85 -60c0 -35 -22 -43 -31 -50c-6 -5 -8 -10 -8 -16s0 -11 4 -16c6 -11 9 -22 9 -34c0 -27 -18 -53 -46 -65c-11 -4 -27 -6 -41 -6c-34 0 -82 21 -90 58 c-1 5 -2 8 -2 12c0 28 25 57 51 66c4 1 6 2 6 5c0 2 -1 3 -2 3c-11 13 -16 27 -16 41c0 21 11 40 30 51h-5c-5 0 -11 -1 -16 -1c-37 0 -72 10 -108 27c-50 24 -77 59 -80 105v11c0 29 7 55 20 76c18 28 45 42 79 44h6c49 0 93 -42 97 -87v-9c0 -51 -34 -86 -105 -106 c17 -24 51 -36 102 -36c62 0 116 43 140 85c9 16 13 41 13 74c0 20 -1 42 -5 67c-8 53 -18 106 -26 159zM315 -781c-3 -2 -6 -5 -7 -8c-6 -8 -10 -19 -10 -30c0 -2 0 -4 1 -7c7 -32 34 -52 53 -52c20 0 37 20 37 36c0 5 -2 9 -4 14c-5 13 -14 24 -25 34c-6 5 -11 10 -17 14 c-4 2 -9 6 -14 6c-6 0 -11 -3 -14 -7zM349 -685c0 -14 10 -25 18 -34c8 -8 16 -18 26 -25c5 -2 10 -4 13 -4c17 0 22 30 23 48c0 9 -3 20 -9 26c-8 9 -23 14 -40 14c-15 -1 -29 -8 -31 -25z" />
#       </symbol>
#       <symbol id="E062-jblct5" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M582 -120c0 32 26 58 58 58s58 -26 58 -58s-26 -58 -58 -58s-58 26 -58 58zM582 120c0 32 26 58 58 58s58 -26 58 -58s-26 -58 -58 -58s-58 26 -58 58zM158 96c51 0 73 -14 88 -49l16 -39c0 -17 -2 -30 -7 -40c-3 -11 -10 -21 -19 -31c-17 -18 -49 -43 -84 -43 c-55 0 -77 13 -112 44c-24 21 -35 55 -35 100c0 46 14 81 32 112c30 52 71 79 137 93l36 6l26 2c154 0 235 -68 274 -182c11 -32 18 -68 18 -107c0 -103 -26 -182 -68 -250c-89 -145 -234 -230 -412 -288l-30 -5c-9 0 -14 3 -14 8c3 10 5 11 10 16c35 15 70 30 96 44l78 43 c96 57 162 136 197 258c9 33 17 60 22 100c3 22 5 35 6 39c-7 69 -16 115 -23 140s-4 22 -16 40c-8 12 -19 23 -31 34c-24 21 -62 44 -118 44c-48 0 -84 -8 -113 -28c-28 -19 -42 -44 -42 -73v-16c2 -5 3 -9 4 -11c24 22 52 39 84 39z" />
#       </symbol>
#       <symbol id="E082-jblct5" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M124 -185c-18 0 -55 -14 -65 -65h-36l-3 30c0 25 6 45 18 63c11 19 22 30 39 43l121 82l37 29c15 11 27 29 38 54c12 24 18 47 18 70c0 40 -19 88 -94 88c-25 0 -32 0 -50 -8c-14 -5 -23 -12 -26 -22c3 -9 7 -15 10 -18l24 -17c12 -7 17 -11 27 -21c5 -7 7 -16 7 -27 c0 -12 0 -57 -79 -74c-30 0 -76 26 -76 94c0 66 81 135 197 135c72 0 181 -32 181 -150c0 -53 -32 -95 -113 -133l-91 -41c-26 -11 -45 -23 -57 -37l49 7c84 0 115 -41 148 -41c20 0 33 20 39 61h35c0 -152 -68 -168 -114 -168c-17 0 -65 0 -79 7h10l-28 17 c-49 37 -69 40 -87 42z" />
#       </symbol>
#       <symbol id="E084-jblct5" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M20 -78c84 97 114 180 134 329h170c-13 -32 -82 -132 -99 -151l-84 -97c-33 -36 -59 -63 -80 -81h162v102l127 123v-225h57v-39h-57v-34c0 -43 19 -65 57 -65v-34h-244v36c48 0 60 26 60 70v27h-203v39z" />
#       </symbol>
#       <symbol id="E0A2-jblct5" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M198 133c102 0 207 -45 207 -133c0 -92 -98 -133 -207 -133c-101 0 -198 46 -198 133c0 88 93 133 198 133zM293 -21c0 14 -3 29 -8 44c-7 20 -18 38 -33 54c-20 21 -43 31 -68 31l-20 -2c-15 -5 -27 -14 -36 -28c-4 -9 -6 -17 -8 -24s-3 -16 -3 -27c0 -15 3 -34 9 -57 s18 -41 34 -55c15 -15 36 -23 62 -23c4 0 10 1 18 2c19 5 32 15 40 30s13 34 13 55z" />
#       </symbol>
#       <symbol id="E0A3-jblct5" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M278 64c0 22 -17 39 -43 39c-12 0 -26 -3 -41 -10c-85 -43 -165 -94 -165 -156c5 -25 15 -32 49 -32c67 11 200 95 200 159zM0 -36c0 68 73 174 200 174c66 0 114 -39 114 -97c0 -84 -106 -173 -218 -173c-64 0 -96 32 -96 96z" />
#       </symbol>
#       <symbol id="E0A4-jblct5" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 -39c0 68 73 172 200 172c66 0 114 -37 114 -95c0 -84 -106 -171 -218 -171c-64 0 -96 30 -96 94z" />
#       </symbol>
#       <symbol id="E241-jblct5" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M179 646c-4 8 -17 30 -18 33l-4 10c0 3 2 5 5 5s7 -2 13 -7c23 -33 46 -81 66 -132c22 -57 35 -125 35 -163c0 -104 -60 -183 -122 -241c-63 -59 -57 -53 -61 -56c-38 -34 -63 -95 -71 -95h-22v190c40 7 69 11 87 16c88 27 168 95 168 200c0 30 -12 89 -30 138 c-17 47 -31 73 -46 102z" />
#       </symbol>
#    </defs>
#    <style type="text/css">g.page-margin{font-family:Times;} g.ending, g.fing, g.reh, g.tempo{font-weight:bold;} g.dir, g.dynam, g.mNum{font-style:italic;} g.label{font-weight:normal;}</style>
#    <svg class="definition-scale" color="black" viewBox="0 0 30000 15000">
#       <g class="page-margin" transform="translate(500, 500)">
#          <g id="sm5et8c" class="score pageMilestone">
#             <title class="labelAttr">[selectionScore]</title>
#          </g>
#          <g id="sj4g6fe" class="system">
#             <path d="M824 540 L824 4860" stroke="currentColor" stroke-width="27" />
#             <g id="g864bow" class="grpSym">
#                <use xlink:href="#E003-jblct5" x="631" y="489" height="720px" width="720px" />
#                <use xlink:href="#E004-jblct5" x="631" y="4911" height="720px" width="720px" />
#                <rect x="631" y="483" height="4434" width="90" />
#             </g>
#             <g id="le5868j" class="label">
#                <text x="451" y="990" text-anchor="end" font-size="0px">
#                   <tspan id="txdca2y" class="text">
#                      <tspan font-size="405px" class="text">T1</tspan>
#                   </tspan>
#                </text>
#             </g>
#             <g id="lg114fe" class="label">
#                <text x="451" y="2790" text-anchor="end" font-size="0px">
#                   <tspan id="t8pm2yv" class="text">
#                      <tspan font-size="405px" class="text">T2</tspan>
#                   </tspan>
#                </text>
#             </g>
#             <g id="l691tse" class="label">
#                <text x="451" y="4590" text-anchor="end" font-size="0px">
#                   <tspan id="tcql1gw" class="text">
#                      <tspan font-size="405px" class="text">B</tspan>
#                   </tspan>
#                </text>
#             </g>
#             <g id="meik9v" class="measure">
#                <g id="mk79w1w" class="mNum autogenerated">
# Results:
# File Name:  Morley_1597_127_3
# Morley
# Morley_1597_127_3
# Cadence End Measure: 8
# Beat:  1.0
# <svg width="900px" height="450px" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:mei="http://www.music-encoding.org/ns/mei" overflow="visible">
#    <desc>Engraved by Verovio 3.10.0-845ab54</desc>
#    <defs>
#       <symbol id="E004-gmam40" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 0h53c30 0 59 -1 83 -5c206 -95 258 -264 263 -271c0 -1 -14 -7 -15 -6c-88 154 -251 170 -321 170c-1 0 -63 1 -63 1v111z" />
#       </symbol>
#       <symbol id="E003-gmam40" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 -0v111c0 0 62 1 63 1c70 0 233 16 321 170c1 1 15 -5 15 -6c-5 -7 -57 -176 -263 -271c-24 -4 -53 -5 -83 -5h-53z" />
#       </symbol>
#       <symbol id="E052-gmam40" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M382 117c-72 -2 -128 -47 -128 -120v-7c2 -46 43 -99 75 -115c-3 -2 -7 -5 -10 -10c-70 33 -116 88 -123 172v11c0 68 44 126 88 159c23 17 49 29 78 36l-29 170c-21 -13 -52 -37 -92 -73c-50 -44 -86 -84 -109 -119c-45 -69 -67 -130 -67 -182v-13 c5 -68 35 -127 93 -176s125 -73 203 -73c25 0 50 3 75 9c-19 111 -36 221 -54 331zM406 119l54 -326c73 25 110 78 110 161c0 7 0 15 -1 23c-7 95 -57 142 -151 142h-12zM461 939c-95 0 -135 -175 -135 -286c0 -24 2 -48 5 -71c50 39 92 82 127 128c40 53 60 100 60 140v8 c-4 53 -22 81 -55 81h-2zM441 -245c-23 -4 -48 -6 -76 -6c-59 0 -102 7 -130 20c-88 42 -150 93 -187 154c-26 44 -43 103 -48 176c0 6 -1 13 -1 19c0 54 15 111 45 170c29 57 65 106 110 148s96 85 153 127c-3 16 -8 46 -13 92c-4 43 -5 73 -5 89c0 117 16 172 69 257 c34 54 64 82 89 82c21 0 43 -30 69 -92s39 -115 41 -159v-15c0 -109 -21 -162 -67 -241c-13 -20 -63 -90 -98 -118c-13 -9 -25 -19 -37 -29l31 -181c8 1 18 2 28 2c58 0 102 -12 133 -35c59 -43 92 -104 98 -184c1 -7 1 -15 1 -22c0 -123 -87 -209 -181 -248 c8 -57 17 -110 25 -162c5 -31 6 -58 6 -80c0 -30 -5 -53 -14 -70c-25 -46 -59 -77 -102 -92c21 -1 85 -13 85 -60c0 -35 -22 -43 -31 -50c-6 -5 -8 -10 -8 -16s0 -11 4 -16c6 -11 9 -22 9 -34c0 -27 -18 -53 -46 -65c-11 -4 -27 -6 -41 -6c-34 0 -82 21 -90 58 c-1 5 -2 8 -2 12c0 28 25 57 51 66c4 1 6 2 6 5c0 2 -1 3 -2 3c-11 13 -16 27 -16 41c0 21 11 40 30 51h-5c-5 0 -11 -1 -16 -1c-37 0 -72 10 -108 27c-50 24 -77 59 -80 105v11c0 29 7 55 20 76c18 28 45 42 79 44h6c49 0 93 -42 97 -87v-9c0 -51 -34 -86 -105 -106 c17 -24 51 -36 102 -36c62 0 116 43 140 85c9 16 13 41 13 74c0 20 -1 42 -5 67c-8 53 -18 106 -26 159zM315 -781c-3 -2 -6 -5 -7 -8c-6 -8 -10 -19 -10 -30c0 -2 0 -4 1 -7c7 -32 34 -52 53 -52c20 0 37 20 37 36c0 5 -2 9 -4 14c-5 13 -14 24 -25 34c-6 5 -11 10 -17 14 c-4 2 -9 6 -14 6c-6 0 -11 -3 -14 -7zM349 -685c0 -14 10 -25 18 -34c8 -8 16 -18 26 -25c5 -2 10 -4 13 -4c17 0 22 30 23 48c0 9 -3 20 -9 26c-8 9 -23 14 -40 14c-15 -1 -29 -8 -31 -25z" />
#       </symbol>
#       <symbol id="E062-gmam40" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M582 -120c0 32 26 58 58 58s58 -26 58 -58s-26 -58 -58 -58s-58 26 -58 58zM582 120c0 32 26 58 58 58s58 -26 58 -58s-26 -58 -58 -58s-58 26 -58 58zM158 96c51 0 73 -14 88 -49l16 -39c0 -17 -2 -30 -7 -40c-3 -11 -10 -21 -19 -31c-17 -18 -49 -43 -84 -43 c-55 0 -77 13 -112 44c-24 21 -35 55 -35 100c0 46 14 81 32 112c30 52 71 79 137 93l36 6l26 2c154 0 235 -68 274 -182c11 -32 18 -68 18 -107c0 -103 -26 -182 -68 -250c-89 -145 -234 -230 -412 -288l-30 -5c-9 0 -14 3 -14 8c3 10 5 11 10 16c35 15 70 30 96 44l78 43 c96 57 162 136 197 258c9 33 17 60 22 100c3 22 5 35 6 39c-7 69 -16 115 -23 140s-4 22 -16 40c-8 12 -19 23 -31 34c-24 21 -62 44 -118 44c-48 0 -84 -8 -113 -28c-28 -19 -42 -44 -42 -73v-16c2 -5 3 -9 4 -11c24 22 52 39 84 39z" />
#       </symbol>
#       <symbol id="E082-gmam40" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M124 -185c-18 0 -55 -14 -65 -65h-36l-3 30c0 25 6 45 18 63c11 19 22 30 39 43l121 82l37 29c15 11 27 29 38 54c12 24 18 47 18 70c0 40 -19 88 -94 88c-25 0 -32 0 -50 -8c-14 -5 -23 -12 -26 -22c3 -9 7 -15 10 -18l24 -17c12 -7 17 -11 27 -21c5 -7 7 -16 7 -27 c0 -12 0 -57 -79 -74c-30 0 -76 26 -76 94c0 66 81 135 197 135c72 0 181 -32 181 -150c0 -53 -32 -95 -113 -133l-91 -41c-26 -11 -45 -23 -57 -37l49 7c84 0 115 -41 148 -41c20 0 33 20 39 61h35c0 -152 -68 -168 -114 -168c-17 0 -65 0 -79 7h10l-28 17 c-49 37 -69 40 -87 42z" />
#       </symbol>
#       <symbol id="E084-gmam40" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M20 -78c84 97 114 180 134 329h170c-13 -32 -82 -132 -99 -151l-84 -97c-33 -36 -59 -63 -80 -81h162v102l127 123v-225h57v-39h-57v-34c0 -43 19 -65 57 -65v-34h-244v36c48 0 60 26 60 70v27h-203v39z" />
#       </symbol>
#       <symbol id="E0A1-gmam40" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 165c0 5 6 5 12 5s13 0 13 -5v-40h298v40c0 5 7 5 13 5s12 0 12 -5v-330c0 -5 -6 -5 -12 -5s-13 0 -13 5v40h-298v-40c0 -5 -7 -5 -13 -5s-12 0 -12 5v330zM25 0c0 -29 1 -55 25 -55h248c24 0 25 26 25 55s-1 55 -25 55h-248c-24 0 -25 -26 -25 -55z" />
#       </symbol>
#       <symbol id="E0A2-gmam40" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M198 133c102 0 207 -45 207 -133c0 -92 -98 -133 -207 -133c-101 0 -198 46 -198 133c0 88 93 133 198 133zM293 -21c0 14 -3 29 -8 44c-7 20 -18 38 -33 54c-20 21 -43 31 -68 31l-20 -2c-15 -5 -27 -14 -36 -28c-4 -9 -6 -17 -8 -24s-3 -16 -3 -27c0 -15 3 -34 9 -57 s18 -41 34 -55c15 -15 36 -23 62 -23c4 0 10 1 18 2c19 5 32 15 40 30s13 34 13 55z" />
#       </symbol>
#       <symbol id="E0A3-gmam40" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M278 64c0 22 -17 39 -43 39c-12 0 -26 -3 -41 -10c-85 -43 -165 -94 -165 -156c5 -25 15 -32 49 -32c67 11 200 95 200 159zM0 -36c0 68 73 174 200 174c66 0 114 -39 114 -97c0 -84 -106 -173 -218 -173c-64 0 -96 32 -96 96z" />
#       </symbol>
#    </defs>
#    <style type="text/css">g.page-margin{font-family:Times;} g.ending, g.fing, g.reh, g.tempo{font-weight:bold;} g.dir, g.dynam, g.mNum{font-style:italic;} g.label{font-weight:normal;}</style>
#    <svg class="definition-scale" color="black" viewBox="0 0 30000 15000">
#       <g class="page-margin" transform="translate(500, 500)">
#          <g id="skmx1lw" class="score pageMilestone">
#             <title class="labelAttr">[selectionScore]</title>
#          </g>
#          <g id="sy2yl5d" class="system">
#             <path d="M824 540 L824 4860" stroke="currentColor" stroke-width="27" />
#             <g id="gqd3oi7" class="grpSym">
#                <use xlink:href="#E003-gmam40" x="631" y="489" height="720px" width="720px" />
#                <use xlink:href="#E004-gmam40" x="631" y="4911" height="720px" width="720px" />
#                <rect x="631" y="483" height="4434" width="90" />
#             </g>
#             <g id="li0xocr" class="label">
#                <text x="451" y="990" text-anchor="end" font-size="0px">
#                   <tspan id="tfwv6db" class="text">
#                      <tspan font-size="405px" class="text">T1</tspan>
#                   </tspan>
#                </text>
#             </g>
#             <g id="liapabt" class="label">
#                <text x="451" y="2790" text-anchor="end" font-size="0px">
#                   <tspan id="ttqvd4h" class="text">
#                      <tspan font-size="405px" class="text">T2</tspan>
#                   </tspan>
#                </text>
#             </g>
#             <g id="lyur5hi" class="label">
#                <text x="451" y="4590" text-anchor="end" font-size="0px">
#                   <tspan id="t42i3fc" class="text">
#                      <tspan font-size="405px" class="text">B</tspan>
#                   </tspan>
#                </text>
#             </g>
#             <g id="mm2oty8" class="measure">
#                <g id="m1bwoye" class="mNum autogenerated">
#                   <text x="811" y="232" text-anchor="middle" font-size="0px">
#                      <tspan id="tr89e33" class="text">
#                         <tspan font-size="324px" class="text">7</tspan>
#                      </tspan>
#                   </text>
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Results:
# File Name:  Morley_1597_128_01
# Morley
# Morley_1597_128_01
# Cadence End Measure: 3
# Beat:  1.0
# <svg width="900px" height="450px" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:mei="http://www.music-encoding.org/ns/mei" overflow="visible">
#    <desc>Engraved by Verovio 3.10.0-845ab54</desc>
#    <defs>
#       <symbol id="E004-ulvg93" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 0h53c30 0 59 -1 83 -5c206 -95 258 -264 263 -271c0 -1 -14 -7 -15 -6c-88 154 -251 170 -321 170c-1 0 -63 1 -63 1v111z" />
#       </symbol>
#       <symbol id="E003-ulvg93" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 -0v111c0 0 62 1 63 1c70 0 233 16 321 170c1 1 15 -5 15 -6c-5 -7 -57 -176 -263 -271c-24 -4 -53 -5 -83 -5h-53z" />
#       </symbol>
#       <symbol id="E052-ulvg93" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M382 117c-72 -2 -128 -47 -128 -120v-7c2 -46 43 -99 75 -115c-3 -2 -7 -5 -10 -10c-70 33 -116 88 -123 172v11c0 68 44 126 88 159c23 17 49 29 78 36l-29 170c-21 -13 -52 -37 -92 -73c-50 -44 -86 -84 -109 -119c-45 -69 -67 -130 -67 -182v-13 c5 -68 35 -127 93 -176s125 -73 203 -73c25 0 50 3 75 9c-19 111 -36 221 -54 331zM406 119l54 -326c73 25 110 78 110 161c0 7 0 15 -1 23c-7 95 -57 142 -151 142h-12zM461 939c-95 0 -135 -175 -135 -286c0 -24 2 -48 5 -71c50 39 92 82 127 128c40 53 60 100 60 140v8 c-4 53 -22 81 -55 81h-2zM441 -245c-23 -4 -48 -6 -76 -6c-59 0 -102 7 -130 20c-88 42 -150 93 -187 154c-26 44 -43 103 -48 176c0 6 -1 13 -1 19c0 54 15 111 45 170c29 57 65 106 110 148s96 85 153 127c-3 16 -8 46 -13 92c-4 43 -5 73 -5 89c0 117 16 172 69 257 c34 54 64 82 89 82c21 0 43 -30 69 -92s39 -115 41 -159v-15c0 -109 -21 -162 -67 -241c-13 -20 -63 -90 -98 -118c-13 -9 -25 -19 -37 -29l31 -181c8 1 18 2 28 2c58 0 102 -12 133 -35c59 -43 92 -104 98 -184c1 -7 1 -15 1 -22c0 -123 -87 -209 -181 -248 c8 -57 17 -110 25 -162c5 -31 6 -58 6 -80c0 -30 -5 -53 -14 -70c-25 -46 -59 -77 -102 -92c21 -1 85 -13 85 -60c0 -35 -22 -43 -31 -50c-6 -5 -8 -10 -8 -16s0 -11 4 -16c6 -11 9 -22 9 -34c0 -27 -18 -53 -46 -65c-11 -4 -27 -6 -41 -6c-34 0 -82 21 -90 58 c-1 5 -2 8 -2 12c0 28 25 57 51 66c4 1 6 2 6 5c0 2 -1 3 -2 3c-11 13 -16 27 -16 41c0 21 11 40 30 51h-5c-5 0 -11 -1 -16 -1c-37 0 -72 10 -108 27c-50 24 -77 59 -80 105v11c0 29 7 55 20 76c18 28 45 42 79 44h6c49 0 93 -42 97 -87v-9c0 -51 -34 -86 -105 -106 c17 -24 51 -36 102 -36c62 0 116 43 140 85c9 16 13 41 13 74c0 20 -1 42 -5 67c-8 53 -18 106 -26 159zM315 -781c-3 -2 -6 -5 -7 -8c-6 -8 -10 -19 -10 -30c0 -2 0 -4 1 -7c7 -32 34 -52 53 -52c20 0 37 20 37 36c0 5 -2 9 -4 14c-5 13 -14 24 -25 34c-6 5 -11 10 -17 14 c-4 2 -9 6 -14 6c-6 0 -11 -3 -14 -7zM349 -685c0 -14 10 -25 18 -34c8 -8 16 -18 26 -25c5 -2 10 -4 13 -4c17 0 22 30 23 48c0 9 -3 20 -9 26c-8 9 -23 14 -40 14c-15 -1 -29 -8 -31 -25z" />
#       </symbol>
#       <symbol id="E062-ulvg93" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M582 -120c0 32 26 58 58 58s58 -26 58 -58s-26 -58 -58 -58s-58 26 -58 58zM582 120c0 32 26 58 58 58s58 -26 58 -58s-26 -58 -58 -58s-58 26 -58 58zM158 96c51 0 73 -14 88 -49l16 -39c0 -17 -2 -30 -7 -40c-3 -11 -10 -21 -19 -31c-17 -18 -49 -43 -84 -43 c-55 0 -77 13 -112 44c-24 21 -35 55 -35 100c0 46 14 81 32 112c30 52 71 79 137 93l36 6l26 2c154 0 235 -68 274 -182c11 -32 18 -68 18 -107c0 -103 -26 -182 -68 -250c-89 -145 -234 -230 -412 -288l-30 -5c-9 0 -14 3 -14 8c3 10 5 11 10 16c35 15 70 30 96 44l78 43 c96 57 162 136 197 258c9 33 17 60 22 100c3 22 5 35 6 39c-7 69 -16 115 -23 140s-4 22 -16 40c-8 12 -19 23 -31 34c-24 21 -62 44 -118 44c-48 0 -84 -8 -113 -28c-28 -19 -42 -44 -42 -73v-16c2 -5 3 -9 4 -11c24 22 52 39 84 39z" />
#       </symbol>
#       <symbol id="E0A4-ulvg93" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 -39c0 68 73 172 200 172c66 0 114 -37 114 -95c0 -84 -106 -171 -218 -171c-64 0 -96 30 -96 94z" />
#       </symbol>
#       <symbol id="E082-ulvg93" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M124 -185c-18 0 -55 -14 -65 -65h-36l-3 30c0 25 6 45 18 63c11 19 22 30 39 43l121 82l37 29c15 11 27 29 38 54c12 24 18 47 18 70c0 40 -19 88 -94 88c-25 0 -32 0 -50 -8c-14 -5 -23 -12 -26 -22c3 -9 7 -15 10 -18l24 -17c12 -7 17 -11 27 -21c5 -7 7 -16 7 -27 c0 -12 0 -57 -79 -74c-30 0 -76 26 -76 94c0 66 81 135 197 135c72 0 181 -32 181 -150c0 -53 -32 -95 -113 -133l-91 -41c-26 -11 -45 -23 -57 -37l49 7c84 0 115 -41 148 -41c20 0 33 20 39 61h35c0 -152 -68 -168 -114 -168c-17 0 -65 0 -79 7h10l-28 17 c-49 37 -69 40 -87 42z" />
#       </symbol>
#       <symbol id="E084-ulvg93" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M20 -78c84 97 114 180 134 329h170c-13 -32 -82 -132 -99 -151l-84 -97c-33 -36 -59 -63 -80 -81h162v102l127 123v-225h57v-39h-57v-34c0 -43 19 -65 57 -65v-34h-244v36c48 0 60 26 60 70v27h-203v39z" />
#       </symbol>
#       <symbol id="E0A3-ulvg93" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M278 64c0 22 -17 39 -43 39c-12 0 -26 -3 -41 -10c-85 -43 -165 -94 -165 -156c5 -25 15 -32 49 -32c67 11 200 95 200 159zM0 -36c0 68 73 174 200 174c66 0 114 -39 114 -97c0 -84 -106 -173 -218 -173c-64 0 -96 32 -96 96z" />
#       </symbol>
#       <symbol id="E0A2-ulvg93" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M198 133c102 0 207 -45 207 -133c0 -92 -98 -133 -207 -133c-101 0 -198 46 -198 133c0 88 93 133 198 133zM293 -21c0 14 -3 29 -8 44c-7 20 -18 38 -33 54c-20 21 -43 31 -68 31l-20 -2c-15 -5 -27 -14 -36 -28c-4 -9 -6 -17 -8 -24s-3 -16 -3 -27c0 -15 3 -34 9 -57 s18 -41 34 -55c15 -15 36 -23 62 -23c4 0 10 1 18 2c19 5 32 15 40 30s13 34 13 55z" />
#       </symbol>
#       <symbol id="E262-ulvg93" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M136 186v169h17v-164l44 14v-91l-44 -14v-165l44 12v-91l-44 -13v-155h-17v150l-76 -22v-155h-17v149l-43 -13v90l43 14v167l-43 -14v92l43 13v169h17v-163zM60 73v-167l76 22v168z" />
#       </symbol>
#    </defs>
#    <style type="text/css">g.page-margin{font-family:Times;} g.ending, g.fing, g.reh, g.tempo{font-weight:bold;} g.dir, g.dynam, g.mNum{font-style:italic;} g.label{font-weight:normal;}</style>
#    <svg class="definition-scale" color="black" viewBox="0 0 30000 15000">
#       <g class="page-margin" transform="translate(500, 500)">
#          <g id="sa5ccj0" class="score pageMilestone">
#             <title class="labelAttr">[selectionScore]</title>
#          </g>
#          <g id="sb8bqzv" class="system">
#             <path d="M824 540 L824 4860" stroke="currentColor" stroke-width="27" />
#             <g id="giwuafv" class="grpSym">
#                <use xlink:href="#E003-ulvg93" x="631" y="489" height="720px" width="720px" />
#                <use xlink:href="#E004-ulvg93" x="631" y="4911" height="720px" width="720px" />
#                <rect x="631" y="483" height="4434" width="90" />
#             </g>
#             <g id="lo142kj" class="label">
#                <text x="451" y="990" text-anchor="end" font-size="0px">
#                   <tspan id="t5xc6sh" class="text">
#                      <tspan font-size="405px" class="text">T1</tspan>
#                   </tspan>
#                </text>
#             </g>
#             <g id="ljatqdh" class="label">
#                <text x="451" y="2790" text-anchor="end" font-size="0px">
#                   <tspan id="tok5qgg" class="text">
#                      <tspan font-size="405px" class="text">T2</tspan>
#                   </tspan>
#                </text>
#             </g>
#             <g id="lo77qz2" class="label">
#                <text x="451" y="4590" text-anchor="end" font-size="0px">
#                   <tspan id="tdjw2am" class="text">
#                      <tspan font-size="405px" class="text">B</tspan>
#                   </tspan>
#                </text>
#             </g>
#             <g id="mbuw3rr" class="measure">
#                <g id="mgjqmid" class="mNum autogenerated">
#                   <text x="811" y="232" text-anchor="middle" font-size="0px">
#                      <tspan
# Results:
# File Name:  Morley_1597_128_01
# Morley
# Morley_1597_128_01
# Cadence End Measure: 3
# Beat:  2.0
# <svg width="900px" height="450px" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:mei="http://www.music-encoding.org/ns/mei" overflow="visible">
#    <desc>Engraved by Verovio 3.10.0-845ab54</desc>
#    <defs>
#       <symbol id="E004-7ex838" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 0h53c30 0 59 -1 83 -5c206 -95 258 -264 263 -271c0 -1 -14 -7 -15 -6c-88 154 -251 170 -321 170c-1 0 -63 1 -63 1v111z" />
#       </symbol>
#       <symbol id="E003-7ex838" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 -0v111c0 0 62 1 63 1c70 0 233 16 321 170c1 1 15 -5 15 -6c-5 -7 -57 -176 -263 -271c-24 -4 -53 -5 -83 -5h-53z" />
#       </symbol>
#       <symbol id="E052-7ex838" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M382 117c-72 -2 -128 -47 -128 -120v-7c2 -46 43 -99 75 -115c-3 -2 -7 -5 -10 -10c-70 33 -116 88 -123 172v11c0 68 44 126 88 159c23 17 49 29 78 36l-29 170c-21 -13 -52 -37 -92 -73c-50 -44 -86 -84 -109 -119c-45 -69 -67 -130 -67 -182v-13 c5 -68 35 -127 93 -176s125 -73 203 -73c25 0 50 3 75 9c-19 111 -36 221 -54 331zM406 119l54 -326c73 25 110 78 110 161c0 7 0 15 -1 23c-7 95 -57 142 -151 142h-12zM461 939c-95 0 -135 -175 -135 -286c0 -24 2 -48 5 -71c50 39 92 82 127 128c40 53 60 100 60 140v8 c-4 53 -22 81 -55 81h-2zM441 -245c-23 -4 -48 -6 -76 -6c-59 0 -102 7 -130 20c-88 42 -150 93 -187 154c-26 44 -43 103 -48 176c0 6 -1 13 -1 19c0 54 15 111 45 170c29 57 65 106 110 148s96 85 153 127c-3 16 -8 46 -13 92c-4 43 -5 73 -5 89c0 117 16 172 69 257 c34 54 64 82 89 82c21 0 43 -30 69 -92s39 -115 41 -159v-15c0 -109 -21 -162 -67 -241c-13 -20 -63 -90 -98 -118c-13 -9 -25 -19 -37 -29l31 -181c8 1 18 2 28 2c58 0 102 -12 133 -35c59 -43 92 -104 98 -184c1 -7 1 -15 1 -22c0 -123 -87 -209 -181 -248 c8 -57 17 -110 25 -162c5 -31 6 -58 6 -80c0 -30 -5 -53 -14 -70c-25 -46 -59 -77 -102 -92c21 -1 85 -13 85 -60c0 -35 -22 -43 -31 -50c-6 -5 -8 -10 -8 -16s0 -11 4 -16c6 -11 9 -22 9 -34c0 -27 -18 -53 -46 -65c-11 -4 -27 -6 -41 -6c-34 0 -82 21 -90 58 c-1 5 -2 8 -2 12c0 28 25 57 51 66c4 1 6 2 6 5c0 2 -1 3 -2 3c-11 13 -16 27 -16 41c0 21 11 40 30 51h-5c-5 0 -11 -1 -16 -1c-37 0 -72 10 -108 27c-50 24 -77 59 -80 105v11c0 29 7 55 20 76c18 28 45 42 79 44h6c49 0 93 -42 97 -87v-9c0 -51 -34 -86 -105 -106 c17 -24 51 -36 102 -36c62 0 116 43 140 85c9 16 13 41 13 74c0 20 -1 42 -5 67c-8 53 -18 106 -26 159zM315 -781c-3 -2 -6 -5 -7 -8c-6 -8 -10 -19 -10 -30c0 -2 0 -4 1 -7c7 -32 34 -52 53 -52c20 0 37 20 37 36c0 5 -2 9 -4 14c-5 13 -14 24 -25 34c-6 5 -11 10 -17 14 c-4 2 -9 6 -14 6c-6 0 -11 -3 -14 -7zM349 -685c0 -14 10 -25 18 -34c8 -8 16 -18 26 -25c5 -2 10 -4 13 -4c17 0 22 30 23 48c0 9 -3 20 -9 26c-8 9 -23 14 -40 14c-15 -1 -29 -8 -31 -25z" />
#       </symbol>
#       <symbol id="E062-7ex838" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M582 -120c0 32 26 58 58 58s58 -26 58 -58s-26 -58 -58 -58s-58 26 -58 58zM582 120c0 32 26 58 58 58s58 -26 58 -58s-26 -58 -58 -58s-58 26 -58 58zM158 96c51 0 73 -14 88 -49l16 -39c0 -17 -2 -30 -7 -40c-3 -11 -10 -21 -19 -31c-17 -18 -49 -43 -84 -43 c-55 0 -77 13 -112 44c-24 21 -35 55 -35 100c0 46 14 81 32 112c30 52 71 79 137 93l36 6l26 2c154 0 235 -68 274 -182c11 -32 18 -68 18 -107c0 -103 -26 -182 -68 -250c-89 -145 -234 -230 -412 -288l-30 -5c-9 0 -14 3 -14 8c3 10 5 11 10 16c35 15 70 30 96 44l78 43 c96 57 162 136 197 258c9 33 17 60 22 100c3 22 5 35 6 39c-7 69 -16 115 -23 140s-4 22 -16 40c-8 12 -19 23 -31 34c-24 21 -62 44 -118 44c-48 0 -84 -8 -113 -28c-28 -19 -42 -44 -42 -73v-16c2 -5 3 -9 4 -11c24 22 52 39 84 39z" />
#       </symbol>
#       <symbol id="E0A4-7ex838" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 -39c0 68 73 172 200 172c66 0 114 -37 114 -95c0 -84 -106 -171 -218 -171c-64 0 -96 30 -96 94z" />
#       </symbol>
#       <symbol id="E082-7ex838" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M124 -185c-18 0 -55 -14 -65 -65h-36l-3 30c0 25 6 45 18 63c11 19 22 30 39 43l121 82l37 29c15 11 27 29 38 54c12 24 18 47 18 70c0 40 -19 88 -94 88c-25 0 -32 0 -50 -8c-14 -5 -23 -12 -26 -22c3 -9 7 -15 10 -18l24 -17c12 -7 17 -11 27 -21c5 -7 7 -16 7 -27 c0 -12 0 -57 -79 -74c-30 0 -76 26 -76 94c0 66 81 135 197 135c72 0 181 -32 181 -150c0 -53 -32 -95 -113 -133l-91 -41c-26 -11 -45 -23 -57 -37l49 7c84 0 115 -41 148 -41c20 0 33 20 39 61h35c0 -152 -68 -168 -114 -168c-17 0 -65 0 -79 7h10l-28 17 c-49 37 -69 40 -87 42z" />
#       </symbol>
#       <symbol id="E084-7ex838" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M20 -78c84 97 114 180 134 329h170c-13 -32 -82 -132 -99 -151l-84 -97c-33 -36 -59 -63 -80 -81h162v102l127 123v-225h57v-39h-57v-34c0 -43 19 -65 57 -65v-34h-244v36c48 0 60 26 60 70v27h-203v39z" />
#       </symbol>
#       <symbol id="E0A3-7ex838" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M278 64c0 22 -17 39 -43 39c-12 0 -26 -3 -41 -10c-85 -43 -165 -94 -165 -156c5 -25 15 -32 49 -32c67 11 200 95 200 159zM0 -36c0 68 73 174 200 174c66 0 114 -39 114 -97c0 -84 -106 -173 -218 -173c-64 0 -96 32 -96 96z" />
#       </symbol>
#       <symbol id="E0A2-7ex838" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M198 133c102 0 207 -45 207 -133c0 -92 -98 -133 -207 -133c-101 0 -198 46 -198 133c0 88 93 133 198 133zM293 -21c0 14 -3 29 -8 44c-7 20 -18 38 -33 54c-20 21 -43 31 -68 31l-20 -2c-15 -5 -27 -14 -36 -28c-4 -9 -6 -17 -8 -24s-3 -16 -3 -27c0 -15 3 -34 9 -57 s18 -41 34 -55c15 -15 36 -23 62 -23c4 0 10 1 18 2c19 5 32 15 40 30s13 34 13 55z" />
#       </symbol>
#       <symbol id="E262-7ex838" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M136 186v169h17v-164l44 14v-91l-44 -14v-165l44 12v-91l-44 -13v-155h-17v150l-76 -22v-155h-17v149l-43 -13v90l43 14v167l-43 -14v92l43 13v169h17v-163zM60 73v-167l76 22v168z" />
#       </symbol>
#    </defs>
#    <style type="text/css">g.page-margin{font-family:Times;} g.ending, g.fing, g.reh, g.tempo{font-weight:bold;} g.dir, g.dynam, g.mNum{font-style:italic;} g.label{font-weight:normal;}</style>
#    <svg class="definition-scale" color="black" viewBox="0 0 30000 15000">
#       <g class="page-margin" transform="translate(500, 500)">
#          <g id="sptrnex" class="score pageMilestone">
#             <title class="labelAttr">[selectionScore]</title>
#          </g>
#          <g id="sdxpk78" class="system">
#             <path d="M824 540 L824 4860" stroke="currentColor" stroke-width="27" />
#             <g id="ghoyskn" class="grpSym">
#                <use xlink:href="#E003-7ex838" x="631" y="489" height="720px" width="720px" />
#                <use xlink:href="#E004-7ex838" x="631" y="4911" height="720px" width="720px" />
#                <rect x="631" y="483" height="4434" width="90" />
#             </g>
#             <g id="l31n3fw" class="label">
#                <text x="451" y="990" text-anchor="end" font-size="0px">
#                   <tspan id="t9ls4t1" class="text">
#                      <tspan font-size="405px" class="text">T1</tspan>
#                   </tspan>
#                </text>
#             </g>
#             <g id="lc4fb2e" class="label">
#                <text x="451" y="2790" text-anchor="end" font-size="0px">
#                   <tspan id="txbe7iq" class="text">
#                      <tspan font-size="405px" class="text">T2</tspan>
#                   </tspan>
#                </text>
#             </g>
#             <g id="lnu16sh" class="label">
#                <text x="451" y="4590" text-anchor="end" font-size="0px">
#                   <tspan id="t3g87iu" class="text">
#                      <tspan font-size="405px" class="text">B</tspan>
#                   </tspan>
#                </text>
#             </g>
#             <g id="mbuw3rr" class="measure">
#                <g id="mgjqmid" class="mNum autogenerated">
#                   <text x="811" y="232" text-anchor="middle" font-size="0px">
#                      <tspan
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
# Results:
# File Name:  Morley_1597_129_6
# Morley
# Morley_1597_129_6
# Cadence End Measure: 3
# Beat:  1.0
# <svg width="900px" height="450px" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:mei="http://www.music-encoding.org/ns/mei" overflow="visible">
#    <desc>Engraved by Verovio 3.10.0-845ab54</desc>
#    <defs>
#       <symbol id="E0A3-o87p0i" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M278 64c0 22 -17 39 -43 39c-12 0 -26 -3 -41 -10c-85 -43 -165 -94 -165 -156c5 -25 15 -32 49 -32c67 11 200 95 200 159zM0 -36c0 68 73 174 200 174c66 0 114 -39 114 -97c0 -84 -106 -173 -218 -173c-64 0 -96 32 -96 96z" />
#       </symbol>
#       <symbol id="E003-o87p0i" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 -0v111c0 0 62 1 63 1c70 0 233 16 321 170c1 1 15 -5 15 -6c-5 -7 -57 -176 -263 -271c-24 -4 -53 -5 -83 -5h-53z" />
#       </symbol>
#       <symbol id="E082-o87p0i" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M124 -185c-18 0 -55 -14 -65 -65h-36l-3 30c0 25 6 45 18 63c11 19 22 30 39 43l121 82l37 29c15 11 27 29 38 54c12 24 18 47 18 70c0 40 -19 88 -94 88c-25 0 -32 0 -50 -8c-14 -5 -23 -12 -26 -22c3 -9 7 -15 10 -18l24 -17c12 -7 17 -11 27 -21c5 -7 7 -16 7 -27 c0 -12 0 -57 -79 -74c-30 0 -76 26 -76 94c0 66 81 135 197 135c72 0 181 -32 181 -150c0 -53 -32 -95 -113 -133l-91 -41c-26 -11 -45 -23 -57 -37l49 7c84 0 115 -41 148 -41c20 0 33 20 39 61h35c0 -152 -68 -168 -114 -168c-17 0 -65 0 -79 7h10l-28 17 c-49 37 -69 40 -87 42z" />
#       </symbol>
#       <symbol id="E052-o87p0i" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M382 117c-72 -2 -128 -47 -128 -120v-7c2 -46 43 -99 75 -115c-3 -2 -7 -5 -10 -10c-70 33 -116 88 -123 172v11c0 68 44 126 88 159c23 17 49 29 78 36l-29 170c-21 -13 -52 -37 -92 -73c-50 -44 -86 -84 -109 -119c-45 -69 -67 -130 -67 -182v-13 c5 -68 35 -127 93 -176s125 -73 203 -73c25 0 50 3 75 9c-19 111 -36 221 -54 331zM406 119l54 -326c73 25 110 78 110 161c0 7 0 15 -1 23c-7 95 -57 142 -151 142h-12zM461 939c-95 0 -135 -175 -135 -286c0 -24 2 -48 5 -71c50 39 92 82 127 128c40 53 60 100 60 140v8 c-4 53 -22 81 -55 81h-2zM441 -245c-23 -4 -48 -6 -76 -6c-59 0 -102 7 -130 20c-88 42 -150 93 -187 154c-26 44 -43 103 -48 176c0 6 -1 13 -1 19c0 54 15 111 45 170c29 57 65 106 110 148s96 85 153 127c-3 16 -8 46 -13 92c-4 43 -5 73 -5 89c0 117 16 172 69 257 c34 54 64 82 89 82c21 0 43 -30 69 -92s39 -115 41 -159v-15c0 -109 -21 -162 -67 -241c-13 -20 -63 -90 -98 -118c-13 -9 -25 -19 -37 -29l31 -181c8 1 18 2 28 2c58 0 102 -12 133 -35c59 -43 92 -104 98 -184c1 -7 1 -15 1 -22c0 -123 -87 -209 -181 -248 c8 -57 17 -110 25 -162c5 -31 6 -58 6 -80c0 -30 -5 -53 -14 -70c-25 -46 -59 -77 -102 -92c21 -1 85 -13 85 -60c0 -35 -22 -43 -31 -50c-6 -5 -8 -10 -8 -16s0 -11 4 -16c6 -11 9 -22 9 -34c0 -27 -18 -53 -46 -65c-11 -4 -27 -6 -41 -6c-34 0 -82 21 -90 58 c-1 5 -2 8 -2 12c0 28 25 57 51 66c4 1 6 2 6 5c0 2 -1 3 -2 3c-11 13 -16 27 -16 41c0 21 11 40 30 51h-5c-5 0 -11 -1 -16 -1c-37 0 -72 10 -108 27c-50 24 -77 59 -80 105v11c0 29 7 55 20 76c18 28 45 42 79 44h6c49 0 93 -42 97 -87v-9c0 -51 -34 -86 -105 -106 c17 -24 51 -36 102 -36c62 0 116 43 140 85c9 16 13 41 13 74c0 20 -1 42 -5 67c-8 53 -18 106 -26 159zM315 -781c-3 -2 -6 -5 -7 -8c-6 -8 -10 -19 -10 -30c0 -2 0 -4 1 -7c7 -32 34 -52 53 -52c20 0 37 20 37 36c0 5 -2 9 -4 14c-5 13 -14 24 -25 34c-6 5 -11 10 -17 14 c-4 2 -9 6 -14 6c-6 0 -11 -3 -14 -7zM349 -685c0 -14 10 -25 18 -34c8 -8 16 -18 26 -25c5 -2 10 -4 13 -4c17 0 22 30 23 48c0 9 -3 20 -9 26c-8 9 -23 14 -40 14c-15 -1 -29 -8 -31 -25z" />
#       </symbol>
#       <symbol id="E084-o87p0i" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M20 -78c84 97 114 180 134 329h170c-13 -32 -82 -132 -99 -151l-84 -97c-33 -36 -59 -63 -80 -81h162v102l127 123v-225h57v-39h-57v-34c0 -43 19 -65 57 -65v-34h-244v36c48 0 60 26 60 70v27h-203v39z" />
#       </symbol>
#       <symbol id="E004-o87p0i" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 0h53c30 0 59 -1 83 -5c206 -95 258 -264 263 -271c0 -1 -14 -7 -15 -6c-88 154 -251 170 -321 170c-1 0 -63 1 -63 1v111z" />
#       </symbol>
#       <symbol id="E0A1-o87p0i" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 165c0 5 6 5 12 5s13 0 13 -5v-40h298v40c0 5 7 5 13 5s12 0 12 -5v-330c0 -5 -6 -5 -12 -5s-13 0 -13 5v40h-298v-40c0 -5 -7 -5 -13 -5s-12 0 -12 5v330zM25 0c0 -29 1 -55 25 -55h248c24 0 25 26 25 55s-1 55 -25 55h-248c-24 0 -25 -26 -25 -55z" />
#       </symbol>
#       <symbol id="E0A2-o87p0i" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M198 133c102 0 207 -45 207 -133c0 -92 -98 -133 -207 -133c-101 0 -198 46 -198 133c0 88 93 133 198 133zM293 -21c0 14 -3 29 -8 44c-7 20 -18 38 -33 54c-20 21 -43 31 -68 31l-20 -2c-15 -5 -27 -14 -36 -28c-4 -9 -6 -17 -8 -24s-3 -16 -3 -27c0 -15 3 -34 9 -57 s18 -41 34 -55c15 -15 36 -23 62 -23c4 0 10 1 18 2c19 5 32 15 40 30s13 34 13 55z" />
#       </symbol>
#       <symbol id="E050-o87p0i" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M441 -245c-23 -4 -48 -6 -76 -6c-59 0 -102 7 -130 20c-88 42 -150 93 -187 154c-26 44 -43 103 -48 176c0 6 -1 13 -1 19c0 54 15 111 45 170c29 57 65 106 110 148s96 85 153 127c-3 16 -8 46 -13 92c-4 43 -5 73 -5 89c0 117 16 172 69 257c34 54 64 82 89 82 c21 0 43 -30 69 -92s39 -115 41 -159v-15c0 -109 -21 -162 -67 -241c-13 -20 -63 -90 -98 -118c-13 -9 -25 -19 -37 -29l31 -181c8 1 18 2 28 2c58 0 102 -12 133 -35c59 -43 92 -104 98 -184c1 -7 1 -15 1 -22c0 -123 -87 -209 -181 -248c8 -57 17 -110 25 -162 c5 -31 6 -58 6 -80c0 -30 -5 -53 -14 -70c-35 -64 -88 -99 -158 -103c-5 0 -11 -1 -16 -1c-37 0 -72 10 -108 27c-50 24 -77 59 -80 105v11c0 29 7 55 20 76c18 28 45 42 79 44h6c49 0 93 -42 97 -87v-9c0 -51 -34 -86 -105 -106c17 -24 51 -36 102 -36c62 0 116 43 140 85 c9 16 13 41 13 74c0 20 -1 42 -5 67c-8 53 -18 106 -26 159zM461 939c-95 0 -135 -175 -135 -286c0 -24 2 -48 5 -71c50 39 92 82 127 128c40 53 60 100 60 140v8c-4 53 -22 81 -55 81h-2zM406 119l54 -326c73 25 110 78 110 161c0 7 0 15 -1 23c-7 95 -57 142 -151 142h-12 zM382 117c-72 -2 -128 -47 -128 -120v-7c2 -46 43 -99 75 -115c-3 -2 -7 -5 -10 -10c-70 33 -116 88 -123 172v11c0 68 44 126 88 159c23 17 49 29 78 36l-29 170c-21 -13 -52 -37 -92 -73c-50 -44 -86 -84 -109 -119c-45 -69 -67 -130 -67 -182v-13c5 -68 35 -127 93 -176 s125 -73 203 -73c25 0 50 3 75 9c-19 111 -36 221 -54 331z" />
#       </symbol>
#       <symbol id="E0A4-o87p0i" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 -39c0 68 73 172 200 172c66 0 114 -37 114 -95c0 -84 -106 -171 -218 -171c-64 0 -96 30 -96 94z" />
# ...
#    <defs>
#       <symbol id="E003-9ifubm" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 -0v111c0 0 62 1 63 1c70 0 233 16 321 170c1 1 15 -5 15 -6c-5 -7 -57 -176 -263 -271c-24 -4 -53 -5 -83 -5h-53z" />
#       </symbol>
#       <symbol id="E0A4-9ifubm" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 -39c0 68 73 172 200 172c66 0 114 -37 114 -95c0 -84 -106 -171 -218 -171c-64 0 -96 30 -96 94z" />
#       </symbol>
#       <symbol id="E062-9ifubm" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M582 -120c0 32 26 58 58 58s58 -26 58 -58s-26 -58 -58 -58s-58 26 -58 58zM582 120c0 32 26 58 58 58s58 -26 58 -58s-26 -58 -58 -58s-58 26 -58 58zM158 96c51 0 73 -14 88 -49l16 -39c0 -17 -2 -30 -7 -40c-3 -11 -10 -21 -19 -31c-17 -18 -49 -43 -84 -43 c-55 0 -77 13 -112 44c-24 21 -35 55 -35 100c0 46 14 81 32 112c30 52 71 79 137 93l36 6l26 2c154 0 235 -68 274 -182c11 -32 18 -68 18 -107c0 -103 -26 -182 -68 -250c-89 -145 -234 -230 -412 -288l-30 -5c-9 0 -14 3 -14 8c3 10 5 11 10 16c35 15 70 30 96 44l78 43 c96 57 162 136 197 258c9 33 17 60 22 100c3 22 5 35 6 39c-7 69 -16 115 -23 140s-4 22 -16 40c-8 12 -19 23 -31 34c-24 21 -62 44 -118 44c-48 0 -84 -8 -113 -28c-28 -19 -42 -44 -42 -73v-16c2 -5 3 -9 4 -11c24 22 52 39 84 39z" />
#       </symbol>
#       <symbol id="E0A1-9ifubm" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 165c0 5 6 5 12 5s13 0 13 -5v-40h298v40c0 5 7 5 13 5s12 0 12 -5v-330c0 -5 -6 -5 -12 -5s-13 0 -13 5v40h-298v-40c0 -5 -7 -5 -13 -5s-12 0 -12 5v330zM25 0c0 -29 1 -55 25 -55h248c24 0 25 26 25 55s-1 55 -25 55h-248c-24 0 -25 -26 -25 -55z" />
#       </symbol>
#       <symbol id="E004-9ifubm" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 0h53c30 0 59 -1 83 -5c206 -95 258 -264 263 -271c0 -1 -14 -7 -15 -6c-88 154 -251 170 -321 170c-1 0 -63 1 -63 1v111z" />
#       </symbol>
#       <symbol id="E084-9ifubm" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M20 -78c84 97 114 180 134 329h170c-13 -32 -82 -132 -99 -151l-84 -97c-33 -36 -59 -63 -80 -81h162v102l127 123v-225h57v-39h-57v-34c0 -43 19 -65 57 -65v-34h-244v36c48 0 60 26 60 70v27h-203v39z" />
#       </symbol>
#       <symbol id="E050-9ifubm" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M441 -245c-23 -4 -48 -6 -76 -6c-59 0 -102 7 -130 20c-88 42 -150 93 -187 154c-26 44 -43 103 -48 176c0 6 -1 13 -1 19c0 54 15 111 45 170c29 57 65 106 110 148s96 85 153 127c-3 16 -8 46 -13 92c-4 43 -5 73 -5 89c0 117 16 172 69 257c34 54 64 82 89 82 c21 0 43 -30 69 -92s39 -115 41 -159v-15c0 -109 -21 -162 -67 -241c-13 -20 -63 -90 -98 -118c-13 -9 -25 -19 -37 -29l31 -181c8 1 18 2 28 2c58 0 102 -12 133 -35c59 -43 92 -104 98 -184c1 -7 1 -15 1 -22c0 -123 -87 -209 -181 -248c8 -57 17 -110 25 -162 c5 -31 6 -58 6 -80c0 -30 -5 -53 -14 -70c-35 -64 -88 -99 -158 -103c-5 0 -11 -1 -16 -1c-37 0 -72 10 -108 27c-50 24 -77 59 -80 105v11c0 29 7 55 20 76c18 28 45 42 79 44h6c49 0 93 -42 97 -87v-9c0 -51 -34 -86 -105 -106c17 -24 51 -36 102 -36c62 0 116 43 140 85 c9 16 13 41 13 74c0 20 -1 42 -5 67c-8 53 -18 106 -26 159zM461 939c-95 0 -135 -175 -135 -286c0 -24 2 -48 5 -71c50 39 92 82 127 128c40 53 60 100 60 140v8c-4 53 -22 81 -55 81h-2zM406 119l54 -326c73 25 110 78 110 161c0 7 0 15 -1 23c-7 95 -57 142 -151 142h-12 zM382 117c-72 -2 -128 -47 -128 -120v-7c2 -46 43 -99 75 -115c-3 -2 -7 -5 -10 -10c-70 33 -116 88 -123 172v11c0 68 44 126 88 159c23 17 49 29 78 36l-29 170c-21 -13 -52 -37 -92 -73c-50 -44 -86 -84 -109 -119c-45 -69 -67 -130 -67 -182v-13c5 -68 35 -127 93 -176 s125 -73 203 -73c25 0 50 3 75 9c-19 111 -36 221 -54 331z" />
#       </symbol>
#       <symbol id="E0A3-9ifubm" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M278 64c0 22 -17 39 -43 39c-12 0 -26 -3 -41 -10c-85 -43 -165 -94 -165 -156c5 -25 15 -32 49 -32c67 11 200 95 200 159zM0 -36c0 68 73 174 200 174c66 0 114 -39 114 -97c0 -84 -106 -173 -218 -173c-64 0 -96 32 -96 96z" />
#       </symbol>
#       <symbol id="E082-9ifubm" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M124 -185c-18 0 -55 -14 -65 -65h-36l-3 30c0 25 6 45 18 63c11 19 22 30 39 43l121 82l37 29c15 11 27 29 38 54c12 24 18 47 18 70c0 40 -19 88 -94 88c-25 0 -32 0 -50 -8c-14 -5 -23 -12 -26 -22c3 -9 7 -15 10 -18l24 -17c12 -7 17 -11 27 -21c5 -7 7 -16 7 -27 c0 -12 0 -57 -79 -74c-30 0 -76 26 -76 94c0 66 81 135 197 135c72 0 181 -32 181 -150c0 -53 -32 -95 -113 -133l-91 -41c-26 -11 -45 -23 -57 -37l49 7c84 0 115 -41 148 -41c20 0 33 20 39 61h35c0 -152 -68 -168 -114 -168c-17 0 -65 0 -79 7h10l-28 17 c-49 37 -69 40 -87 42z" />
#       </symbol>
#       <symbol id="E052-9ifubm" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M382 117c-72 -2 -128 -47 -128 -120v-7c2 -46 43 -99 75 -115c-3 -2 -7 -5 -10 -10c-70 33 -116 88 -123 172v11c0 68 44 126 88 159c23 17 49 29 78 36l-29 170c-21 -13 -52 -37 -92 -73c-50 -44 -86 -84 -109 -119c-45 -69 -67 -130 -67 -182v-13 c5 -68 35 -127 93 -176s125 -73 203 -73c25 0 50 3 75 9c-19 111 -36 221 -54 331zM406 119l54 -326c73 25 110 78 110 161c0 7 0 15 -1 23c-7 95 -57 142 -151 142h-12zM461 939c-95 0 -135 -175 -135 -286c0 -24 2 -48 5 -71c50 39 92 82 127 128c40 53 60 100 60 140v8 c-4 53 -22 81 -55 81h-2zM441 -245c-23 -4 -48 -6 -76 -6c-59 0 -102 7 -130 20c-88 42 -150 93 -187 154c-26 44 -43 103 -48 176c0 6 -1 13 -1 19c0 54 15 111 45 170c29 57 65 106 110 148s96 85 153 127c-3 16 -8 46 -13 92c-4 43 -5 73 -5 89c0 117 16 172 69 257 c34 54 64 82 89 82c21 0 43 -30 69 -92s39 -115 41 -159v-15c0 -109 -21 -162 -67 -241c-13 -20 -63 -90 -98 -118c-13 -9 -25 -19 -37 -29l31 -181c8 1 18 2 28 2c58 0 102 -12 133 -35c59 -43 92 -104 98 -184c1 -7 1 -15 1 -22c0 -123 -87 -209 -181 -248 c8 -57 17 -110 25 -162c5 -31 6 -58 6 -80c0 -30 -5 -53 -14 -70c-25 -46 -59 -77 -102 -92c21 -1 85 -13 85 -60c0 -35 -22 -43 -31 -50c-6 -5 -8 -10 -8 -16s0 -11 4 -16c6 -11 9 -22 9 -34c0 -27 -18 -53 -46 -65c-11 -4 -27 -6 -41 -6c-34 0 -82 21 -90 58 c-1 5 -2 8 -2 12c0 28 25 57 51 66c4 1 6 2 6 5c0 2 -1 3 -2 3c-11 13 -16 27 -16 41c0 21 11 40 30 51h-5c-5 0 -11 -1 -16 -1c-37 0 -72 10 -108 27c-50 24 -77 59 -80 105v11c0 29 7 55 20 76c18 28 45 42 79 44h6c49 0 93 -42 97 -87v-9c0 -51 -34 -86 -105 -106 c17 -24 51 -36 102 -36c62 0 116 43 140 85c9 16 13 41 13 74c0 20 -1 42 -5 67c-8 53 -18 106 -26 159zM315 -781c-3 -2 -6 -5 -7 -8c-6 -8 -10 -19 -10 -30c0 -2 0 -4 1 -7c7 -32 34 -52 53 -52c20 0 37 20 37 36c0 5 -2 9 -4 14c-5 13 -14 24 -25 34c-6 5 -11 10 -17 14 c-4 2 -9 6 -14 6c-6 0 -11 -3 -14 -7zM349 -685c0 -14 10 -25 18 -34c8 -8 16 -18 26 -25c5 -2 10 -4 13 -4c17 0 22 30 23 48c0 9 -3 20 -9 26c-8 9 -23 14 -40 14c-15 -1 -29 -8 -31 -25z" />
#       </symbol>
#       <symbol id="E0A2-9ifubm" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M198 133c102 0 207 -45 207 -133c0 -92 -98 -133 -207 -133c-101 0 -198 46 -198 133c0 88 93 133 198 133zM293 -21c0 14 -3 29 -8 44c-7 20 -18 38 -33 54c-20 21 -43 31 -68 31l-20 -2c-15 -5 -27 -14 -36 -28c-4 -9 -6 -17 -8 -24s-3 -16 -3 -27c0 -15 3 -34 9 -57 s18 -41 34 -55c15 -15 36 -23 62 -23c4 0 10 1 18 2c19 5 32 15 40 30s13 34 13 55z" />
#       </symbol>
#    </defs>
#    <style type="text/css">g.page-margin{font-family:Times;} g.ending, g.fing, g.reh, g.tempo{font-weight:bold;} g.dir, g.dynam, g.mNum{font-style:italic;} g.label{font-weight:normal;}</style>
#    <svg class="definition-scale" color="black" viewBox="0 0 30000 15000">
#       <g class="page-margin" transform="translate(500, 500)">
#          <g id="me7dqnt" class="mdiv pageMilestone" />
#          <g id="s9cdu29" class="score pageMilestone" />
#          <g id="s1hbcc6" class="system">
#             <path d="M653 1636
# Previously imported piece detected.
# Results:
# File Name:  Morley_1597_129_3
# Morley
# Morley_1597_129_3
# Cadence End Measure: 2
# Beat:  3.0
# <svg width="900px" height="450px" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:mei="http://www.music-encoding.org/ns/mei" overflow="visible">
#    <desc>Engraved by Verovio 3.10.0-845ab54</desc>
#    <defs>
#       <symbol id="E4E4-isf36o" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 10v105c0 9 1 10 10 10h280c9 0 10 -1 10 -10v-105c0 -9 -1 -10 -10 -10h-280c-9 0 -10 1 -10 10z" />
#       </symbol>
#       <symbol id="E084-isf36o" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M20 -78c84 97 114 180 134 329h170c-13 -32 -82 -132 -99 -151l-84 -97c-33 -36 -59 -63 -80 -81h162v102l127 123v-225h57v-39h-57v-34c0 -43 19 -65 57 -65v-34h-244v36c48 0 60 26 60 70v27h-203v39z" />
#       </symbol>
#       <symbol id="E082-isf36o" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M124 -185c-18 0 -55 -14 -65 -65h-36l-3 30c0 25 6 45 18 63c11 19 22 30 39 43l121 82l37 29c15 11 27 29 38 54c12 24 18 47 18 70c0 40 -19 88 -94 88c-25 0 -32 0 -50 -8c-14 -5 -23 -12 -26 -22c3 -9 7 -15 10 -18l24 -17c12 -7 17 -11 27 -21c5 -7 7 -16 7 -27 c0 -12 0 -57 -79 -74c-30 0 -76 26 -76 94c0 66 81 135 197 135c72 0 181 -32 181 -150c0 -53 -32 -95 -113 -133l-91 -41c-26 -11 -45 -23 -57 -37l49 7c84 0 115 -41 148 -41c20 0 33 20 39 61h35c0 -152 -68 -168 -114 -168c-17 0 -65 0 -79 7h10l-28 17 c-49 37 -69 40 -87 42z" />
#       </symbol>
#       <symbol id="E050-isf36o" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M441 -245c-23 -4 -48 -6 -76 -6c-59 0 -102 7 -130 20c-88 42 -150 93 -187 154c-26 44 -43 103 -48 176c0 6 -1 13 -1 19c0 54 15 111 45 170c29 57 65 106 110 148s96 85 153 127c-3 16 -8 46 -13 92c-4 43 -5 73 -5 89c0 117 16 172 69 257c34 54 64 82 89 82 c21 0 43 -30 69 -92s39 -115 41 -159v-15c0 -109 -21 -162 -67 -241c-13 -20 -63 -90 -98 -118c-13 -9 -25 -19 -37 -29l31 -181c8 1 18 2 28 2c58 0 102 -12 133 -35c59 -43 92 -104 98 -184c1 -7 1 -15 1 -22c0 -123 -87 -209 -181 -248c8 -57 17 -110 25 -162 c5 -31 6 -58 6 -80c0 -30 -5 -53 -14 -70c-35 -64 -88 -99 -158 -103c-5 0 -11 -1 -16 -1c-37 0 -72 10 -108 27c-50 24 -77 59 -80 105v11c0 29 7 55 20 76c18 28 45 42 79 44h6c49 0 93 -42 97 -87v-9c0 -51 -34 -86 -105 -106c17 -24 51 -36 102 -36c62 0 116 43 140 85 c9 16 13 41 13 74c0 20 -1 42 -5 67c-8 53 -18 106 -26 159zM461 939c-95 0 -135 -175 -135 -286c0 -24 2 -48 5 -71c50 39 92 82 127 128c40 53 60 100 60 140v8c-4 53 -22 81 -55 81h-2zM406 119l54 -326c73 25 110 78 110 161c0 7 0 15 -1 23c-7 95 -57 142 -151 142h-12 zM382 117c-72 -2 -128 -47 -128 -120v-7c2 -46 43 -99 75 -115c-3 -2 -7 -5 -10 -10c-70 33 -116 88 -123 172v11c0 68 44 126 88 159c23 17 49 29 78 36l-29 170c-21 -13 -52 -37 -92 -73c-50 -44 -86 -84 -109 -119c-45 -69 -67 -130 -67 -182v-13c5 -68 35 -127 93 -176 s125 -73 203 -73c25 0 50 3 75 9c-19 111 -36 221 -54 331z" />
#       </symbol>
#       <symbol id="E003-isf36o" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 -0v111c0 0 62 1 63 1c70 0 233 16 321 170c1 1 15 -5 15 -6c-5 -7 -57 -176 -263 -271c-24 -4 -53 -5 -83 -5h-53z" />
#       </symbol>
#       <symbol id="E052-isf36o" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M382 117c-72 -2 -128 -47 -128 -120v-7c2 -46 43 -99 75 -115c-3 -2 -7 -5 -10 -10c-70 33 -116 88 -123 172v11c0 68 44 126 88 159c23 17 49 29 78 36l-29 170c-21 -13 -52 -37 -92 -73c-50 -44 -86 -84 -109 -119c-45 -69 -67 -130 -67 -182v-13 c5 -68 35 -127 93 -176s125 -73 203 -73c25 0 50 3 75 9c-19 111 -36 221 -54 331zM406 119l54 -326c73 25 110 78 110 161c0 7 0 15 -1 23c-7 95 -57 142 -151 142h-12zM461 939c-95 0 -135 -175 -135 -286c0 -24 2 -48 5 -71c50 39 92 82 127 128c40 53 60 100 60 140v8 c-4 53 -22 81 -55 81h-2zM441 -245c-23 -4 -48 -6 -76 -6c-59 0 -102 7 -130 20c-88 42 -150 93 -187 154c-26 44 -43 103 -48 176c0 6 -1 13 -1 19c0 54 15 111 45 170c29 57 65 106 110 148s96 85 153 127c-3 16 -8 46 -13 92c-4 43 -5 73 -5 89c0 117 16 172 69 257 c34 54 64 82 89 82c21 0 43 -30 69 -92s39 -115 41 -159v-15c0 -109 -21 -162 -67 -241c-13 -20 -63 -90 -98 -118c-13 -9 -25 -19 -37 -29l31 -181c8 1 18 2 28 2c58 0 102 -12 133 -35c59 -43 92 -104 98 -184c1 -7 1 -15 1 -22c0 -123 -87 -209 -181 -248 c8 -57 17 -110 25 -162c5 -31 6 -58 6 -80c0 -30 -5 -53 -14 -70c-25 -46 -59 -77 -102 -92c21 -1 85 -13 85 -60c0 -35 -22 -43 -31 -50c-6 -5 -8 -10 -8 -16s0 -11 4 -16c6 -11 9 -22 9 -34c0 -27 -18 -53 -46 -65c-11 -4 -27 -6 -41 -6c-34 0 -82 21 -90 58 c-1 5 -2 8 -2 12c0 28 25 57 51 66c4 1 6 2 6 5c0 2 -1 3 -2 3c-11 13 -16 27 -16 41c0 21 11 40 30 51h-5c-5 0 -11 -1 -16 -1c-37 0 -72 10 -108 27c-50 24 -77 59 -80 105v11c0 29 7 55 20 76c18 28 45 42 79 44h6c49 0 93 -42 97 -87v-9c0 -51 -34 -86 -105 -106 c17 -24 51 -36 102 -36c62 0 116 43 140 85c9 16 13 41 13 74c0 20 -1 42 -5 67c-8 53 -18 106 -26 159zM315 -781c-3 -2 -6 -5 -7 -8c-6 -8 -10 -19 -10 -30c0 -2 0 -4 1 -7c7 -32 34 -52 53 -52c20 0 37 20 37 36c0 5 -2 9 -4 14c-5 13 -14 24 -25 34c-6 5 -11 10 -17 14 c-4 2 -9 6 -14 6c-6 0 -11 -3 -14 -7zM349 -685c0 -14 10 -25 18 -34c8 -8 16 -18 26 -25c5 -2 10 -4 13 -4c17 0 22 30 23 48c0 9 -3 20 -9 26c-8 9 -23 14 -40 14c-15 -1 -29 -8 -31 -25z" />
#       </symbol>
#       <symbol id="E062-isf36o" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M582 -120c0 32 26 58 58 58s58 -26 58 -58s-26 -58 -58 -58s-58 26 -58 58zM582 120c0 32 26 58 58 58s58 -26 58 -58s-26 -58 -58 -58s-58 26 -58 58zM158 96c51 0 73 -14 88 -49l16 -39c0 -17 -2 -30 -7 -40c-3 -11 -10 -21 -19 -31c-17 -18 -49 -43 -84 -43 c-55 0 -77 13 -112 44c-24 21 -35 55 -35 100c0 46 14 81 32 112c30 52 71 79 137 93l36 6l26 2c154 0 235 -68 274 -182c11 -32 18 -68 18 -107c0 -103 -26 -182 -68 -250c-89 -145 -234 -230 -412 -288l-30 -5c-9 0 -14 3 -14 8c3 10 5 11 10 16c35 15 70 30 96 44l78 43 c96 57 162 136 197 258c9 33 17 60 22 100c3 22 5 35 6 39c-7 69 -16 115 -23 140s-4 22 -16 40c-8 12 -19 23 -31 34c-24 21 -62 44 -118 44c-48 0 -84 -8 -113 -28c-28 -19 -42 -44 -42 -73v-16c2 -5 3 -9 4 -11c24 22 52 39 84 39z" />
#       </symbol>
#       <symbol id="E004-isf36o" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M0 0h53c30 0 59 -1 83 -5c206 -95 258 -264 263 -271c0 -1 -14 -7 -15 -6c-88 154 -251 170 -321 170c-1 0 -63 1 -63 1v111z" />
#       </symbol>
#       <symbol id="E0A2-isf36o" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M198 133c102 0 207 -45 207 -133c0 -92 -98 -133 -207 -133c-101 0 -198 46 -198 133c0 88 93 133 198 133zM293 -21c0 14 -3 29 -8 44c-7 20 -18 38 -33 54c-20 21 -43 31 -68 31l-20 -2c-15 -5 -27 -14 -36 -28c-4 -9 -6 -17 -8 -24s-3 -16 -3 -27c0 -15 3 -34 9 -57 s18 -41 34 -55c15 -15 36 -23 62 -23c4 0 10 1 18 2c19 5 32 15 40 30s13 34 13 55z" />
#       </symbol>
#       <symbol id="E0A3-isf36o" viewBox="0 0 1000 1000" overflow="inherit">
#          <path transform="scale(1,-1)" d="M278 64c0 22 -17 39 -43 39c-12 0 -26 -3 -41 -10c-85 -43 -165 -94 -165 -156c5 -25 15 -32 49 -32c67 11 200 95 200 159zM0 -36c0 68 73 174 200 174c66 0 114 -39 114 -97c0 -84 -106 -173 -218 -173c-64 0 -96 32 -96 96z" />
#       </symbol>
#    </defs>
#    <style type="text/css">g.page-margin{font-family:Times;} g.ending, g.fing, g.reh, g.tempo{font-weight:bold;} g.dir, g.dynam, g.mNum{font-style:italic;} g.label{font-weight:normal;}</style>
#    <svg class="definition-scale" color="black" viewBox="0 0 30000 15000">
#       <g class="page-margin" transform="translate(500, 500)">
#          <g id="sxit354" class="score pageMilestone">
#             <title class="labelAttr">[selectionScore]</title>
#          </g>
#          <g id="s1zui0e" class="system">
#             <path d="M653 540 L653 4860" stroke="currentColor" stroke-width="27" />
#             <g id="gt7l370" class="grpSym">
#                <use xlink:href="#E003-isf36o" x="460" y="489" height="720px" width="720px" />
#                <use xlink:href="#E004-isf36o" x="460" y="4911" height="720px" width="720px" />
#                <rect x="460" y="483" height="4434" width="90" />
# Previously imported piece detected.
# Previously imported piece detected.
# Previously imported piece detected.
